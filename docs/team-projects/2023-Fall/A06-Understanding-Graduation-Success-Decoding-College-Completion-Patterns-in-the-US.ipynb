# %% [markdown]
# ##**Understanding Graduation Success: Decoding College Completion Patterns in the US**
#
#
# ---
#
# **Created By** : *Pengru Lin, Bonny Yang, Gaurangi Agrawal, Lila Su, Rishabh Anand and Prudhvi Lanke*

# %% [markdown]
# ##**1. Executive Summary**

# %% [markdown]
# **Decoding the Tapestry of American Education**
#
# Our exploration into American education uncovers key insights across various dimensions, addressing university selection, funding dynamics, institutional impact, graduation patterns, and regional disparities. This comprehensive analysis navigates through these challenges to illuminate critical aspects shaping the educational landscape.
#
# *  **University Selection Landscape**: Understanding university selection challenges involves a complex interplay of admission scores, financial considerations, and institutional characteristics. This exploration provides a nuanced view of the multifaceted decision-making process for students.
#
# *  **Funding Dynamics**: The financial realm reveals distinct spending patterns in higher education. Notably, 4-year institutions invest significantly per award, reflecting unique financial structures influencing program duration and expenditure.
#
# *  **Institutional Impact on Academic Achievement**: Examining how institutional characteristics affect SAT scores highlights a correlation between academic emphasis and student achievement. Certain institutions consistently exhibit higher SAT scores, particularly those prioritizing career readiness.
#
# *  **Graduation Patterns Across States**: Our exploration into graduation patterns uncovers diverse trends across states. By ranking institutions based on gender and race within each state, we identify leaders in educational success, offering valuable insights for policymakers and institutions.
#
# *  **Flagship Institutions' Role**: Flagship institutions play a crucial role, challenging preconceptions and emphasizing their impact on educational outcomes. They not only exhibit significant score variations but also distinguish themselves with awards and graduation rates surpassing state averages.
#
# *  **Regional Academic Disparities**: Examining regional academic disparities, institutions showcase distinct funding patterns per award. Institutional characteristics play a pivotal role in impacting SAT scores, revealing a positive connection between SAT scores and awards. Graduation rate patterns unveil Rhode Island's consistent leadership and the notable performance of Northeastern private nonprofits.
#
# *  **Diversity and Financial Aid**: University distribution reflects diversity, with flagship institutions excelling in awards and graduation rates. Financial aid insights add intriguing nuances, showing that popular colleges tend to be more generous. In the academic landscape, Research Universities attract 2 million students, while Masters Colleges and Universities allure with greater enrollment.
#
# *  **Dashboard Insights**: Our dashboard exploration enriches the narrative, delving into ownership structures, program durations, expected award values, and the relationship between Median SAT scores and student counts. Private for-profit institutions with 4-year programs stand out with the highest average expected award values. Moreover, the graduation rates dashboard provides insights into education quality, showcasing variations in graduation rates through Geo Maps. The Northeast consistently outperforms, indicating a potential regional advantage. The correlation between graduation rates and SAT scores becomes apparent, offering a comprehensive understanding of factors influencing graduation rates, including geographical variations, regional trends, and the impact of academic preparedness reflected by SAT scores.
#
# In essence, this project provides a panoramic view of the American education landscape, presenting nuanced observations that guide institutions and policymakers. The combination of quantitative precision and narrative depth offers a holistic understanding of factors influencing academic achievement, contributing to the development of strategies resonating with the diverse aspirations of learners nationwide.

# %% [markdown]
# ##**2. Business Problem Definition**

# %% [markdown]
# ###**2.1 Motivation**

# %% [markdown]
# Navigating the intricate landscape of U.S. college completion presents a multifaceted challenge that demands our attention. Our project is motivated by a deep-seated aspiration to unravel this complexity, guided by specific objectives. We aim to delve into graduation rates, timeframes for program completion, and demographic trends. This stems from our collective interest in gaining insights into student success, institutional performance, and the evolving patterns of inclusivity in educational outcomes.

# %% [markdown]
# ###**2.2 Business Problem**

# %% [markdown]
# Understanding college completion trends holds paramount importance for shaping future educational strategies and aiding career choices. The decisions made by students and institutions based on these trends have far-reaching consequences, impacting individual lives and the broader educational landscape. The intricate interplay of factors influencing graduation rates, such as timeframes and demographic shifts, directly affects the success and inclusivity of educational outcomes. As we delve into these nuances, we contribute not only to academic research but also offer practical insights that can inform policies and practices.
#
# Through rigorous analysis of the dataset, we intend to uncover hidden patterns and draw meaningful conclusions. Our methodology involves a meticulous examination of graduation rates among first-time, full-time undergraduates, providing granular insights into the factors influencing success. By focusing on timeframes for program completion, we aim to understand the dynamics of student progress and align educational strategies accordingly. Additionally, our exploration of demographic trends seeks to ensure inclusivity and address disparities in educational outcomes.
#
# Furthermore, our commitment to enhancing educational outcomes extends beyond data analysis. We aspire to create a bridge between research findings and actionable recommendations. By providing a pathway for informed decisions and improved opportunities, we contribute to the broader goal of fostering a more equitable and successful educational experience for all. Our collaboration serves as a catalyst for positive changes in higher education, with the potential to shape policies, empower educators, and guide prospective students toward better-informed choices.

# %% [markdown]
# #**3. Data Source**

# %% [markdown]
# The dataset is sourced from two key institutions – the National Center for Education Statistics (NCES)' Integrated Postsecondary Education System (IPEDS) and the Voluntary System of Accountability’s Student Success and Progress Rate. The consolidated data, consisting of four tables, is accessible at https://www.kaggle.com/datasets/thedevastator/boost-student-success-with-college-completion-da.
#
# The dataset provides a crucial perspective on the success and advancement of college students in the United States. It encompasses graduation rates, demographic information such as race, and other data, offering a comprehensive overview of college completion trends in America.

# %% [markdown]
# ##**3.1 Data Dictionary**

# %% [markdown]
# In the dataset we made use of 3 tables Institution Details(1-details with 3798 rows), Institution Details(2-grads with 1,302,102 rows) and State Sector Grads(3-sectors with 312 rows). Each of the table gives us the detailed information about the colleges in USA with respect to the several criteria. Before diving deep into the data understanding the colmuns descriptions with respect to the tables is an important part of the process. The following tables give us a view of the datasets.

# %% [markdown]
# **1. Intitution Details (1-details)**

# %% [markdown]
# | Column               | Description                                      |
# |----------------------|------------ --------------------------------------|
# |unitid                 |The University ID reference number.
# | chronname            | The name of the college or university. (String) |
# | city                 | The city in which the college is located. (String) |
# | state                | The state in which the college is located. (String) |
# | level                | The type of institution (two-year or four-year). (String) |
# | control              | The type of college (public or private). (String) |
# | basic                | A flag indicating whether the college is a basic institution. (Boolean) |
# | hbcu                 | A flag indicating whether the college is a historically black college or university. (Boolean) |
# | flagship             | A flag indicating whether the college is a flagship institution. (Boolean) |
# | long_x               | The longitude of the college. (Float) |
# | lat_y                | The latitude of the college. (Float) |
# |med_sat_value         | The Median SAT value required for university.(Integer)|
# |med_sat_percentile   |The Median SAT percentile required for university.(Float)|
# |aid_value           |The  aid offered by the University. (Integer)|
# |aid_percentile    |The aid offered by the university in percentile. (Float)|
# |grad_100_value    |The graduation rate within 100% of normal time. (Float)
# |grad_100_percentile | The graduation perntile within 100% of normal time. (Float) |
# |grad_150_value    |The graduation rate within 150% of normal time. (Float)|
# |grad_150_percentile.    |The graduation percentile within 150% of normal time. (Float)|
# | student_count        | The number of students enrolled at the college. (Integer) |
# | awards_per_value     | The number of awards per 100 full-time undergraduates. (Float) |
# | awards_per_state_value | The number of awards per 100 full-time undergraduates compared to the state average. (Float) |
# | awards_per_natl_value | The number of awards per 100 full-time undergraduates compared to the national average. (Float) |
# | exp_award_value      | The amount of money spent per award. (Float) |
# | exp_award_state_value | The amount of money spent per award compared to the state average. (Float) |
# | exp_award_natl_value | The amount of money spent per award compared to the national average. (Float) |
# | exp_award_percentile | The percentile of the amount of money spent per award compared to other colleges. (Float) |

# %% [markdown]
# **2. Institution Grads(2-grads)**

# %% [markdown]
# | Column        | Description                                              |
# |---------------|----------------------------------------------------------|
# |unit Id | The University's ID reference number.|
# | year          | The year the data was collected. (Integer)               |
# | gender        | The gender of the student (Bisexual-B, Male-M, Female-F). (String)                      |
# | race          | The race/ethnicity of the student. (String)              |
# | cohort        | The number of students in the cohort. (Integer)         |
# | grad_cohort   | The number of students who graduated from the cohort. (Integer) |
# | grad_100      | The number of students who graduated within 100% of normal time. (Integer) |
# | grad_150      | The number of students who graduated within 150% of normal time. (Integer) |
# | grad_100_rate | The graduation rate within 100% of normal time. (Float)  |
# | grad_150_rate | The graduation rate within 150% of normal time. (Float)  |

# %% [markdown]
# **3. State Sector Details(3-sectors)**

# %% [markdown]
# | Column                 | Description                                                                              |
# |------------------------|------------------------------------------------------------------------------------------|
# | index                  | Unique Indentifier for the table
# | state                  | The state in which the college is located. (String)                                      |
# | level                  | The type of institution (two-year or four-year). (String)                                |
# | control                | The type of college (public or private). (String)                                        |
# | awards_per_state_value | The number of awards per 100 full-time undergraduates compared to the state average. (Float) |
# | awards_per_natl_value  | The number of awards per 100 full-time undergraduates compared to the national average. (Float) |
# | exp_award_state_value  | The amount of money spent per award compared to the state average. (Float)              |
# | exp_award_natl_value   | The amount of money spent per award compared to the national average. (Float)           |
# | state_abbr             | The two-letter abbreviation of the state in which the college is located. (String)     |
# | schools_count          | The number of schools in the state. (Integer)                                            |
# | state_appr_value       | The state's overall approval rating. (Float)                                            |
# | state_appr_rank        | The state's overall approval rating compared to other states. (Integer)                |
# | grad_rate_rank         | The state's graduation rate compared to other states. (Integer)                         |

# %% [markdown]
# ##**3.2 ER-Diagram**

# %% [markdown]
# The Entity Relationship Diagram (ERD) illustrates the relationships between the tables employed in our analysis. Specifically, we have established a connection between the "1-details" and "2-grads" tables by utilizing the "unitid" as the common key. Simultaneously, the third table, "3-sectors," is employed independently to extract valuable insights. The relationship between the "1-details" and "2-grads" tables is characterized as a one-to-many relationship, where it is mandatory for each university to have students, and every student is associated with at least one gender. This relational structure ensures that universities are integral to the presence of students, and each student is inherently linked to a gender category. This design provides a foundation for our analytical exploration, facilitating a comprehensive understanding of the intricate connections within the dataset.

# %% [markdown]
# ![Entity Relationship Diagram (11).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Adding the necessary commands to run SQL queries in the Google Colab Notebook

# %%
# Load the SQL extension
# %load_ext google.colab.data_table

# Authenticate with your Google account
from google.colab import auth
auth.authenticate_user()

# Set your project ID
project_id = "ba-775-a06"

# Connect to BigQuery
# %load_ext google.colab.data_table
# %load_ext google.cloud.bigquery
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %% [markdown]
# #**4. Data Cleaning**
#
# Here, we're performing necessary steps to analyze a tidier version of the dataset.

# %% [markdown]
# ###**4.1 Deleting Table Columns**

# %% [markdown]
# **Deleting Columns for State Sector Details Table**

# %%
# %%bigquery --project $project_id
#
# ALTER TABLE `ba-775-a06.cc_datasets.3-sectors`
# DROP COLUMN IF EXISTS stateid,
# DROP COLUMN IF EXISTS state_post,
# DROP COLUMN IF EXISTS counted_pct,
# DROP COLUMN IF EXISTS awards_per_rank
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Deleting Columns for Institution Grads Table**

# %%
# %%bigquery --project $project_id
#
# ALTER TABLE `ba-775-a06.cc_datasets.2-grads`
# DROP COLUMN IF EXISTS index
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Deleting Columns for Institution Details**

# %%
# %%bigquery --project $project_id
#
# ALTER TABLE `ba-775-a06.cc_datasets.1-details`
# DROP COLUMN IF EXISTS index,
# DROP COLUMN IF EXISTS state_sector_ct,
# DROP COLUMN IF EXISTS carnegie_ct,
# DROP COLUMN IF EXISTS counted_pct,
# DROP COLUMN IF EXISTS nicknames,
# DROP COLUMN IF EXISTS similar,
# DROP COLUMN IF EXISTS cohort_size,
# DROP COLUMN IF EXISTS vsa_enroll_elsewhere_after6_transfer,
# DROP COLUMN IF EXISTS vsa_enroll_after6_transfer,
# DROP COLUMN IF EXISTS vsa_grad_elsewhere_after6_transfer,
# DROP COLUMN IF EXISTS vsa_grad_after6_transfer,
# DROP COLUMN IF EXISTS vsa_enroll_elsewhere_after4_transfer,
# DROP COLUMN IF EXISTS vsa_enroll_after4_transfer,
# DROP COLUMN IF EXISTS vsa_grad_elsewhere_after4_transfer,
# DROP COLUMN IF EXISTS vsa_grad_after4_transfer,
# DROP COLUMN IF EXISTS vsa_enroll_elsewhere_after6_first,
# DROP COLUMN IF EXISTS vsa_enroll_after6_first,
# DROP COLUMN IF EXISTS vsa_grad_elsewhere_after6_first,
# DROP COLUMN IF EXISTS vsa_grad_after6_first,
# DROP COLUMN IF EXISTS vsa_enroll_elsewhere_after4_first,
# DROP COLUMN IF EXISTS vsa_enroll_after4_first,
# DROP COLUMN IF EXISTS vsa_grad_elsewhere_after4_first,
# DROP COLUMN IF EXISTS vsa_grad_after4_first,
# DROP COLUMN IF EXISTS vsa_year,
# DROP COLUMN IF EXISTS ft_fac_percentile,
# DROP COLUMN IF EXISTS ft_fac_value,
# DROP COLUMN IF EXISTS retain_percentile,
# DROP COLUMN IF EXISTS retain_value,
# DROP COLUMN IF EXISTS pell_percentile,
# DROP COLUMN IF EXISTS pell_value,
# DROP COLUMN IF EXISTS endow_percentile,
# DROP COLUMN IF EXISTS endow_value,
# DROP COLUMN IF EXISTS fte_percentile,
# DROP COLUMN IF EXISTS fte_value,
# DROP COLUMN IF EXISTS ft_pct,
# DROP COLUMN IF EXISTS site
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# We have dropped the columns we're not using for our analysis at this stage. For some of the columns, the information contained within simply does not fit into our storyline; For others, we as a group were having a difficult time understanding the meaning through data dictionary, either the explanation were being too vague, or simply does not make sense.

# %% [markdown]
# ###**4.2 Adding Table Columns**

# %% [markdown]
# **Adding `region` column for Institution Details**

# %%
# %%bigquery --project $project_id
# ALTER TABLE `ba-775-a06.cc_datasets.1-details`
# ADD COLUMN region STRING AS (
#     CASE
#         WHEN state IN ('Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Rhode Island', 'Vermont', 'New York', 'New Jersey', 'Pennsylvania') THEN 'Northeast'
#         WHEN state IN ('Delaware', 'Florida', 'Georgia', 'Maryland', 'North Carolina', 'South Carolina', 'Virginia', 'West Virginia', 'Alabama', 'Kentucky', 'Mississippi', 'Tennessee', 'Arkansas', 'Louisiana') THEN 'Southeast'
#         WHEN state IN ('Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin') THEN 'Midwest'
#         WHEN state IN ('Arizona', 'New Mexico', 'Oklahoma', 'Texas') THEN 'Southwest'
#         WHEN state IN ('Alaska', 'California', 'Colorado', 'Hawaii', 'Idaho', 'Montana', 'Nevada', 'Oregon', 'Utah', 'Washington', 'Wyoming') THEN 'West'
#         ELSE 'Other'
#     END
# );

# %% [markdown]
# ###**4.3 Checking Null Values**

# %% [markdown]
# **Checking Null Values in Institution Details**
#
# It is useful to weed out the data points with null values as they'll not be very helpful in deriving insights.

# %%
# %%bigquery --project $project_id
#
# SELECT
#    sum(IF(unitid is null,1,0)) as Unit_id,
#    sum(IF(chronname is null,1,0)) as University_name,
#    sum(IF(city is null,1,0)) as City,
#    sum(IF(state is null,1,0)) as State,
#    sum(IF(level is null,1,0)) as Level,
#    sum(IF(control is null,1,0)) as Control,
#    sum(IF(basic is null,1,0)) as Basic,
#    sum(IF(hbcu is null,1,0)) as HBCU,
#    sum(IF(flagship is null,1,0)) as Flagship,
#    sum(IF(long_x is null,1,0)) as long_x,
#    sum(IF(lat_y is null,1,0)) as lat_y,
#    sum(IF(student_count is null,1,0)) as Student_Count,
#    sum(IF(awards_per_value is null,1,0)) awards_per_value,
#    sum(IF(awards_per_state_value is null,1,0)) as awards_per_state_value,
#    sum(IF(awards_per_natl_value is null,1,0)) as awards_per_natl_value,
#    sum(IF(exp_award_value is null,1,0)) as exp_award_value,
#    sum(IF(exp_award_state_value is null,1,0)) as exp_award_state_value,
#    sum(IF(exp_award_natl_value is null,1,0)) as exp_award_natl_value,
#    sum(IF(exp_award_percentile is null,1,0)) as exp_award_percentile,
#    sum(IF(med_sat_value is null,1,0)) as med_sat_value,
#    sum(IF(med_sat_percentile is null,1,0)) as med_sat_percentile,
#    sum(IF(aid_value is null,1,0)) as aid_value,
#    sum(IF(aid_percentile is null,1,0)) as aid_percentile,
#    sum(IF(grad_100_value is null,1,0)) as grad_100_value,
#    sum(IF(grad_100_percentile is null,1,0)) as grad_100_percentile,
#    sum(IF(grad_150_value is null,1,0)) as grad_150_value,
#    sum(IF(grad_150_percentile is null,1,0)) as grad_150_percentile
# FROM `ba-775-a06.cc_datasets.1-details`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
# Warning: Total number of columns (27) exceeds max_columns (20). Falling back to pandas display.
#    Unit_id  University_name  City  State  Level  Control  Basic  HBCU  \
# 0        0                0     0      0      0        0      0  3704
#
#    Flagship  long_x  ...  exp_award_natl_value  exp_award_percentile  \
# 0      3748       0  ...                     0                     0
#
#    med_sat_value  med_sat_percentile  aid_value  aid_percentile  \
# 0           2461                2461          1               1
#
#    grad_100_value  grad_100_percentile  grad_150_value  grad_150_percentile
# 0             331                  331             331                  331
#
# [1 rows x 27 columns]

# %%
# %%bigquery --project $project_id
#
# SELECT *
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE med_sat_value IS NULL;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
# Warning: Total number of columns (28) exceeds max_columns (20). Falling back to pandas display.
#       unitid                                  chronname          city  \
# 0     181783                        Wayne State College         Wayne
# 1     180948                      Chadron State College       Chadron
# 2     181534                         Peru State College          Peru
# 3     175078       Southwest Minnesota State University      Marshall
# 4     178420        University of Missouri at St. Louis   Saint Louis
# ...      ...                                        ...           ...
# 2456  157438    Gateway Community and Technical College      Florence
# 2457  156231    Ashland Community and Technical College       Ashland
# 2458  157331  Maysville Community and Technical College     Maysville
# 2459  157553  Big Sandy Community and Technical College  Prestonsburg
# 2460  180692              University of Montana-Western        Dillon
#
#           state   level control  \
# 0      Nebraska  4-year  Public
# 1      Nebraska  4-year  Public
# 2      Nebraska  4-year  Public
# 3     Minnesota  4-year  Public
# 4      Missouri  4-year  Public
# ...         ...     ...     ...
# 2456   Kentucky  2-year  Public
# 2457   Kentucky  2-year  Public
# 2458   Kentucky  2-year  Public
# 2459   Kentucky  2-year  Public
# 2460    Montana  4-year  Public
#
#                                                   basic  hbcu flagship  \
# 0     Masters Colleges and Universities--larger prog...  None     None
# 1                Baccalaureate Colleges--Diverse Fields  None     None
# 2     Masters Colleges and Universities--larger prog...  None     None
# 3     Masters Colleges and Universities--medium prog...  None     None
# 4         Research Universities--high research activity  None     None
# ...                                                 ...   ...      ...
# 2456    Associates--Public Suburban-serving Multicampus  None     None
# 2457            Associates--Public Rural-serving Medium  None     None
# 2458            Associates--Public Rural-serving Medium  None     None
# 2459            Associates--Public Rural-serving Medium  None     None
# 2460             Baccalaureate Colleges--Diverse Fields  None     None
#
#           long_x  ...  exp_award_percentile  med_sat_value  \
# 0     -97.014241  ...                    42            NaN
# 1    -103.002793  ...                    45            NaN
# 2     -95.732731  ...                    16            NaN
# 3     -95.759830  ...                    53            NaN
# 4     -90.308886  ...                    27            NaN
# ...          ...  ...                   ...            ...
# 2456  -84.629470  ...                     8            NaN
# 2457  -82.650664  ...                     4            NaN
# 2458  -83.805641  ...                     3            NaN
# 2459  -82.778390  ...                     6            NaN
# 2460 -112.639264  ...                    56            NaN
#
#       med_sat_percentile  aid_value  aid_percentile  grad_100_value  \
# 0                    NaN     4821.0            21.0            24.8
# 1                    NaN     5296.0            33.0            16.6
# 2                    NaN     4201.0             9.0            19.3
# 3                    NaN     4838.0            22.0            21.7
# 4                    NaN     6556.0            61.0            20.3
# ...                  ...        ...             ...             ...
# 2456                 NaN     7633.0            99.0            17.3
# 2457                 NaN     6424.0            94.0            10.1
# 2458                 NaN     7278.0            98.0            18.8
# 2459                 NaN     4673.0            73.0             6.9
# 2460                 NaN     4783.0            20.0            26.7
#
#       grad_100_percentile  grad_150_value  grad_150_percentile     region
# 0                    58.0            45.6                 49.0    Midwest
# 1                    34.0            33.3                 21.0    Midwest
# 2                    42.0            40.1                 33.0    Midwest
# 3                    49.0            42.8                 41.0    Midwest
# 4                    44.0            45.7                 49.0    Midwest
# ...                   ...             ...                  ...        ...
# 2456                 78.0            33.6                 88.0  Southeast
# 2457                 53.0            19.5                 47.0  Southeast
# 2458                 82.0            29.7                 81.0  Southeast
# 2459                 35.0            16.0                 33.0  Southeast
# 2460                 62.0            45.1                 47.0       West
#
# [2461 rows x 28 columns]

# %% [markdown]
# - The reason behind NULL Values in :
#  - **hbcu and flagship:** A flagship university is a public university which is the first to be established in the state and has the most amount of government support. Which explains the reason why all universities are not considered and every state has only 1 Flagship university. Similarly all the universities cannot come under the category of Historically Black Colleges and Universities(hbcu) hence are depicted by NULL.
#  - **med_sat_value & med_sat_percentile:** While observing the reason behind the NULL value count in the sat columns we observed that the unniversities and the program may not require or have any SAT requirement. This explaination rules out the reason for NULL values.

# %% [markdown]
# **Checking Null Values in Intitution Grads**

# %%
# %%bigquery --project $project_id
# SELECT
#    sum(IF(unitid is null,1,0)) as unitid_null,
#    sum(IF(year is null,1,0)) as Date_Occured_null,
#    sum(IF(gender is null,1,0)) as gender_null,
#    sum(IF(race is null,1,0)) as race_null,
#    sum(IF(cohort is null,1,0)) as cohort_null,
#    sum(IF(grad_cohort is null,1,0)) as grad_cohort_null,
#    sum(IF(grad_100 is null,1,0)) as grad_100_null,
#    sum(IF(grad_150 is null,1,0)) as grad_150_null,
#    sum(IF(grad_100_rate is null,1,0)) as grad_100_rate_null,
#    sum(IF(grad_150_rate is null,1,0)) as grad_150_rate_null,
# FROM `ba-775-a06.cc_datasets.2-grads`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    unitid_null  Date_Occured_null  gender_null  race_null  cohort_null  \
# 0            0                  0            0          0            0
#
#    grad_cohort_null  grad_100_null  grad_150_null  grad_100_rate_null  \
# 0            412722         892033         412722              970041
#
#    grad_150_rate_null
# 0              607233

# %% [markdown]
# **Checking Null Values in State Sector Grad**

# %%
# %%bigquery --project $project_id
#
# SELECT
#    sum(IF(state is null,1,0)) as state_null,
#    sum(IF(state_abbr is null,1,0)) as state_abbr_null,
#    sum(IF(level is null,1,0)) as level_null,
#    sum(IF(control is null,1,0)) as control_null,
#    sum(IF(schools_count is null,1,0)) as schools_count_null,
#    sum(IF(awards_per_state_value is null,1,0)) as awards_per_state_value_null,
#    sum(IF(awards_per_natl_value is null,1,0)) as awards_per_natl_value_null,
#    sum(IF(exp_award_state_value is null,1,0)) as exp_award_state_value_null,
#    sum(IF(exp_award_natl_value is null,1,0)) as exp_award_natl_value_null,
#    sum(IF(state_appr_value is null,1,0)) as state_appr_value_null,
#    sum(IF(state_appr_rank is null,1,0)) as state_appr_rank_null,
#    sum(IF(grad_rate_rank is null,1,0)) as grad_rate_rank_null,
# FROM `ba-775-a06.cc_datasets.3-sectors`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    state_null  state_abbr_null  level_null  control_null  schools_count_null  \
# 0           0                0           0             0                   0
#
#    awards_per_state_value_null  awards_per_natl_value_null  \
# 0                           48                           0
#
#    exp_award_state_value_null  exp_award_natl_value_null  \
# 0                          48                          0
#
#    state_appr_value_null  state_appr_rank_null  grad_rate_rank_null
# 0                     12                    12                   44

# %% [markdown]
# We place significant emphasis on considering NULL values in our analysis, recognizing their importance to the integrity of the records across all three tables. Unlike excluding them, we retain and incorporate NULL values in our dataset, acknowledging their potential impact on the overall insights derived. As we progress through our queries, we meticulously address and account for NULL values wherever necessary. This approach ensures that our analysis remains inclusive, providing a comprehensive understanding of the data and allowing for a nuanced exploration of relationships and patterns across the Institution Details (1-details), Institution Grads (2-grads), and State Sector Details (3-sectors) tables.We are further analysing the null values and will dig deeper during the final submission.

# %% [markdown]
# ###**4-4. Merging Tables**

# %% [markdown]
# **We Merged 2 tables Institution Grads and Institution Details on UnitId**

# %%
# %%bigquery --project $project_id
#
# SELECT *
# FROM
#   `ba-775-a06.cc_datasets.2-grads` i
# LEFT JOIN
#   `ba-775-a06.cc_datasets.1-details` d
# ON
#   i.unitid = d.unitid;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
# Warning: total number of rows (1302102) exceeds max_rows (20000). Falling back to pandas display.
#          unitid  year gender race    cohort  grad_cohort  grad_100  grad_150  \
# 0        100760  2011      B    X    2y all        446.0      73.0     105.0
# 1        100760  2011      M    X    2y all        185.0       NaN      40.0
# 2        100760  2011      F    X    2y all        261.0       NaN      65.0
# 3        100760  2011      B    W    2y all        348.0       NaN      86.0
# 4        100760  2011      M    W    2y all        162.0       NaN      35.0
# ...         ...   ...    ...  ...       ...          ...       ...       ...
# 1302097  432384  2004      F   Ai  4y other          1.0       NaN       1.0
# 1302098  116466  2004      F   Ai  4y other          1.0       NaN       1.0
# 1302099  432384  2003      F   Ai  4y other          1.0       NaN       1.0
# 1302100  399869  2002      F   Ai  4y other          1.0       NaN       1.0
# 1302101  406015  2002      F   Ai  4y other          1.0       NaN       1.0
#
#          grad_100_rate  grad_150_rate  ...  exp_award_percentile  \
# 0                 16.4           23.5  ...                    83
# 1                  NaN           21.6  ...                    83
# 2                  NaN           24.9  ...                    83
# 3                  NaN           24.7  ...                    83
# 4                  NaN           21.6  ...                    83
# ...                ...            ...  ...                   ...
# 1302097            NaN          100.0  ...                     0
# 1302098            NaN          100.0  ...                    11
# 1302099            NaN          100.0  ...                     0
# 1302100            NaN          100.0  ...                     5
# 1302101            NaN          100.0  ...                    50
#
#         med_sat_value med_sat_percentile aid_value aid_percentile  \
# 0                 NaN                NaN    5057.0           82.0
# 1                 NaN                NaN    5057.0           82.0
# 2                 NaN                NaN    5057.0           82.0
# 3                 NaN                NaN    5057.0           82.0
# 4                 NaN                NaN    5057.0           82.0
# ...               ...                ...       ...            ...
# 1302097           NaN                NaN    4733.0           63.0
# 1302098           NaN                NaN    3810.0           20.0
# 1302099           NaN                NaN    4733.0           63.0
# 1302100           NaN                NaN    7549.0           96.0
# 1302101           NaN                NaN    3819.0           21.0
#
#         grad_100_value grad_100_percentile grad_150_value grad_150_percentile  \
# 0                  7.7                39.0            9.1                 8.0
# 1                  7.7                39.0            9.1                 8.0
# 2                  7.7                39.0            9.1                 8.0
# 3                  7.7                39.0            9.1                 8.0
# 4                  7.7                39.0            9.1                 8.0
# ...                ...                 ...            ...                 ...
# 1302097           33.3                75.0           33.3                65.0
# 1302098           10.7                26.0           25.0                48.0
# 1302099           33.3                75.0           33.3                65.0
# 1302100           65.7                95.0           65.7                93.0
# 1302101            0.8                 3.0           14.8                20.0
#
#             region
# 0        Southeast
# 1        Southeast
# 2        Southeast
# 3        Southeast
# 4        Southeast
# ...            ...
# 1302097       West
# 1302098       West
# 1302099       West
# 1302100       West
# 1302101       West
#
# [1302102 rows x 38 columns]

# %%
# %%bigquery --project $project_id
#
# ALTER TABLE `ba-775-a06.cc_datasets.merged_table`
# DROP COLUMN IF EXISTS unitid_1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #**5. Dataset Exploration**

# %% [markdown]
# To aid high school students in their university selection process, we will evaluate institutions based on admission, graduation, affordability, and campus environment. When students decide on enrolling in a university, they not only need to meet SAT score requirements but also assess the affordability of tuition. Therefore, the quantity and amount of awards offered by a university become crucial considerations.
#
#
# Furthermore, achieving a degree is a primary goal of attending university, making the institution's graduation rate a significant factor. Even if a university provides numerous scholarships with substantial amounts, a low graduation rate may impact the final decisions of high school students.
#
#
# Additionally, the university's location and composition of the peer group influence high school students' choices. For example, if a student's family resides on the West Coast, they may prefer considering universities in that region to avoid relocating across states. Some students may lean towards universities with a higher population of international students to broaden their perspectives and enhance social interactions.
#
#
# Considering the significance and intrigue surrounding graduation factors, our focus will be on thoroughly analyzing this aspect. Taking into account these considerations, we aim to provide a comprehensive analysis of universities to assist high school students in making well-informed decisions.

# %% [markdown]
# **Here, we're starting off with looking at the distribution of colleges across the states**

# %%
# %%bigquery --project $project_id
# SELECT
#    state,
#    region,
#    COUNT(CASE WHEN control = 'Public' THEN 1 END) AS public_colleges,
#    COUNT(CASE WHEN control = 'Private not-for-profit' THEN 1 END) AS private_NPO_colleges,
#    COUNT(CASE WHEN control = 'Private for-profit' THEN 1 END) AS private_PO_colleges,
#    COUNT(*) AS total_colleges,
#    ROUND((COUNT(CASE WHEN control = 'Public' THEN 1 END) / COUNT(*)) * 100, 2) AS public_percentage,
#    ROUND((COUNT(CASE WHEN control = 'Private not-for-profit' THEN 1 END) / COUNT(*)) * 100, 2) AS private_NPO_percentage,
#    ROUND((COUNT(CASE WHEN control = 'Private for-profit' THEN 1 END) / COUNT(*)) * 100, 2) AS private_PO_percentage
# FROM
#    `ba-775-a06.cc_datasets.1-details`
# GROUP BY
#    state, region
# ORDER BY
#    total_colleges DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state     region  public_colleges  private_NPO_colleges  \
# 0             California       West              145                    78
# 1               New York  Northeast               74                   128
# 2           Pennsylvania  Northeast               57                    95
# 3                  Texas  Southwest               98                    50
# 4                   Ohio    Midwest               59                    60
# 5                Florida  Southeast               41                    48
# 6               Illinois    Midwest               59                    52
# 7         North Carolina  Southeast               75                    44
# 8                Georgia  Southeast               51                    32
# 9               Virginia  Southeast               39                    28
# 10              Missouri    Midwest               27                    37
# 11             Minnesota    Midwest               42                    26
# 12         Massachusetts  Northeast               29                    65
# 13             Tennessee  Southeast               22                    41
# 14              Michigan    Midwest               46                    39
# 15            Washington       West               43                    16
# 16             Wisconsin    Midwest               31                    24
# 17              Colorado       West               27                    10
# 18               Alabama  Southeast               38                    17
# 19              Kentucky  Southeast               24                    21
# 20               Indiana    Midwest               16                    33
# 21        South Carolina  Southeast               32                    21
# 22               Arizona  Southwest               24                     4
# 23                Kansas    Midwest               33                    21
# 24                  Iowa    Midwest               19                    31
# 25             Louisiana  Southeast               30                    11
# 26              Oklahoma  Southwest               27                    12
# 27            New Jersey  Northeast               31                    18
# 28              Maryland  Southeast               28                    16
# 29                Oregon       West               24                    17
# 30              Arkansas  Southeast               32                    13
# 31            New Mexico  Southwest               28                     2
# 32         West Virginia  Southeast               22                     8
# 33              Nebraska    Midwest               14                    16
# 34           Mississippi  Southeast               23                     7
# 35           Connecticut  Northeast               17                    15
# 36                  Utah       West                8                     8
# 37                 Maine  Northeast               15                    12
# 38         New Hampshire  Northeast               12                    10
# 39          South Dakota    Midwest               12                     7
# 40               Montana       West               17                     5
# 41                Nevada       West                7                     1
# 42          North Dakota    Midwest               14                     5
# 43               Vermont  Northeast                6                    13
# 44                Hawaii       West               10                     5
# 45                 Idaho       West                8                     4
# 46  District of Columbia      Other                1                     8
# 47          Rhode Island  Northeast                3                     8
# 48              Delaware  Southeast                5                     5
# 49               Wyoming       West                8                     0
# 50                Alaska       West                5                     1
#
#     private_PO_colleges  total_colleges  public_percentage  \
# 0                   127             350              41.43
# 1                    39             241              30.71
# 2                    65             217              26.27
# 3                    59             207              47.34
# 4                    66             185              31.89
# 5                    87             176              23.30
# 6                    30             141              41.84
# 7                    16             135              55.56
# 8                    23             106              48.11
# 9                    37             104              37.50
# 10                   39             103              26.21
# 11                   33             101              41.58
# 12                    6             100              29.00
# 13                   31              94              23.40
# 14                    9              94              48.94
# 15                   14              73              58.90
# 16                   16              71              43.66
# 17                   33              70              38.57
# 18                   14              69              55.07
# 19                   22              67              35.82
# 20                   18              67              23.88
# 21                   13              66              48.48
# 22                   35              63              38.10
# 23                    8              62              53.23
# 24                   11              61              31.15
# 25                   15              56              53.57
# 26                   17              56              48.21
# 27                    6              55              56.36
# 28                    8              52              53.85
# 29                    9              50              48.00
# 30                    3              48              66.67
# 31                   10              40              70.00
# 32                    9              39              56.41
# 33                    6              36              38.89
# 34                    6              36              63.89
# 35                    3              35              48.57
# 36                   14              30              26.67
# 37                    2              29              51.72
# 38                    2              24              50.00
# 39                    4              23              52.17
# 40                    0              22              77.27
# 41                   12              20              35.00
# 42                    1              20              70.00
# 43                    1              20              30.00
# 44                    3              18              55.56
# 45                    4              16              50.00
# 46                    3              12               8.33
# 47                    0              11              27.27
# 48                    1              11              45.45
# 49                    1               9              88.89
# 50                    1               7              71.43
#
#     private_NPO_percentage  private_PO_percentage
# 0                    22.29                  36.29
# 1                    53.11                  16.18
# 2                    43.78                  29.95
# 3                    24.15                  28.50
# 4                    32.43                  35.68
# 5                    27.27                  49.43
# 6                    36.88                  21.28
# 7                    32.59                  11.85
# 8                    30.19                  21.70
# 9                    26.92                  35.58
# 10                   35.92                  37.86
# 11                   25.74                  32.67
# 12                   65.00                   6.00
# 13                   43.62                  32.98
# 14                   41.49                   9.57
# 15                   21.92                  19.18
# 16                   33.80                  22.54
# 17                   14.29                  47.14
# 18                   24.64                  20.29
# 19                   31.34                  32.84
# 20                   49.25                  26.87
# 21                   31.82                  19.70
# 22                    6.35                  55.56
# 23                   33.87                  12.90
# 24                   50.82                  18.03
# 25                   19.64                  26.79
# 26                   21.43                  30.36
# 27                   32.73                  10.91
# 28                   30.77                  15.38
# 29                   34.00                  18.00
# 30                   27.08                   6.25
# 31                    5.00                  25.00
# 32                   20.51                  23.08
# 33                   44.44                  16.67
# 34                   19.44                  16.67
# 35                   42.86                   8.57
# 36                   26.67                  46.67
# 37                   41.38                   6.90
# 38                   41.67                   8.33
# 39                   30.43                  17.39
# 40                   22.73                   0.00
# 41                    5.00                  60.00
# 42                   25.00                   5.00
# 43                   65.00                   5.00
# 44                   27.78                  16.67
# 45                   25.00                  25.00
# 46                   66.67                  25.00
# 47                   72.73                   0.00
# 48                   45.45                   9.09
# 49                    0.00                  11.11
# 50                   14.29                  14.29

# %% [markdown]
# **Insights**
#
# The distribution of colleges across the United States reveals a notable concentration in certain states, with California emerging as the leader in higher education institutions. The state boasts a significant presence with a total of 350 colleges, reflecting its status as a prominent hub for academic opportunities and diverse educational institutions.
#
# Following behind, New York and Pennsylvania taking the second and third positions with 241 and 217 colleges, showcasing a robust educational landscape.
#
# We've also included the split of control types of the colleges - public, private not for profit and private for profit.

# %% [markdown]
# **Going forward, we pulled up the distribution based on the level of colleges - 2-year focused and 4-year focused across the states**

# %%
# %%bigquery --project $project_id
#
# SELECT
#    state,
#    region,
#    level,
#    COUNT(CASE WHEN control = 'Public' THEN 1 END) AS public_colleges,
#    COUNT(CASE WHEN control = 'Private not-for-profit' THEN 1 END) AS private_NPO_colleges,
#    COUNT(CASE WHEN control = 'Private for-profit' THEN 1 END) AS private_PO_colleges,
#    COUNT(*) AS total_colleges,
#    ROUND((COUNT(CASE WHEN control = 'Public' THEN 1 END) / COUNT(*)) * 100, 2) AS public_percentage,
#    ROUND((COUNT(CASE WHEN control = 'Private not-for-profit' THEN 1 END) / COUNT(*)) * 100, 2) AS private_NPO_percentage,
#    ROUND((COUNT(CASE WHEN control = 'Private for-profit' THEN 1 END) / COUNT(*)) * 100, 2) AS private_PO_percentage
# FROM
#    `ba-775-a06.cc_datasets.1-details`
# WHERE
#     level = '2-year'
# GROUP BY
#    state, region, level
# ORDER BY
#    total_colleges DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              state     region   level  public_colleges  private_NPO_colleges  \
# 0       California       West  2-year              113                     4
# 1            Texas  Southwest  2-year               63                     6
# 2     Pennsylvania  Northeast  2-year               16                    13
# 3             Ohio    Midwest  2-year               25                     3
# 4         New York  Northeast  2-year               35                    12
# 5   North Carolina  Southeast  2-year               59                     1
# 6         Illinois    Midwest  2-year               48                     2
# 7          Florida  Southeast  2-year                5                     1
# 8         Virginia  Southeast  2-year               24                     0
# 9          Georgia  Southeast  2-year               28                     2
# 10       Minnesota    Midwest  2-year               31                     1
# 11        Missouri    Midwest  2-year               14                     3
# 12         Arizona  Southwest  2-year               20                     0
# 13        Colorado       West  2-year               14                     0
# 14       Tennessee  Southeast  2-year               13                     3
# 15         Alabama  Southeast  2-year               25                     1
# 16        Michigan    Midwest  2-year               30                     0
# 17      Washington       West  2-year               25                     0
# 18       Louisiana  Southeast  2-year               16                     2
# 19          Kansas    Midwest  2-year               25                     1
# 20  South Carolina  Southeast  2-year               20                     1
# 21        Arkansas  Southeast  2-year               22                     1
# 22        Kentucky  Southeast  2-year               16                     0
# 23      New Jersey  Northeast  2-year               19                     0
# 24          Oregon       West  2-year               17                     0
# 25     Mississippi  Southeast  2-year               15                     0
# 26      New Mexico  Southwest  2-year               19                     0
# 27        Oklahoma  Southwest  2-year               12                     0
# 28        Maryland  Southeast  2-year               16                     0
# 29   Massachusetts  Northeast  2-year               16                     2
# 30       Wisconsin    Midwest  2-year               17                     0
# 31            Iowa    Midwest  2-year               16                     0
# 32   West Virginia  Southeast  2-year               10                     0
# 33     Connecticut  Northeast  2-year               12                     0
# 34         Montana       West  2-year               11                     1
# 35        Nebraska    Midwest  2-year                8                     1
# 36           Maine  Northeast  2-year                7                     1
# 37   New Hampshire  Northeast  2-year                7                     2
# 38         Wyoming       West  2-year                7                     0
# 39          Hawaii       West  2-year                6                     0
# 40         Indiana    Midwest  2-year                1                     1
# 41          Nevada       West  2-year                1                     0
# 42    South Dakota    Midwest  2-year                5                     1
# 43            Utah       West  2-year                1                     1
# 44           Idaho       West  2-year                4                     0
# 45    North Dakota    Midwest  2-year                5                     0
# 46        Delaware  Southeast  2-year                3                     1
# 47          Alaska       West  2-year                2                     0
# 48    Rhode Island  Northeast  2-year                1                     0
# 49         Vermont  Northeast  2-year                1                     0
#
#     private_PO_colleges  total_colleges  public_percentage  \
# 0                    63             180              62.78
# 1                    37             106              59.43
# 2                    56              85              18.82
# 3                    42              70              35.71
# 4                    22              69              50.72
# 5                     4              64              92.19
# 6                    11              61              78.69
# 7                    39              45              11.11
# 8                    17              41              58.54
# 9                     8              38              73.68
# 10                    5              37              83.78
# 11                   19              36              38.89
# 12                   12              32              62.50
# 13                   17              31              45.16
# 14                   15              31              41.94
# 15                    5              31              80.65
# 16                    0              30             100.00
# 17                    5              30              83.33
# 18                   11              29              55.17
# 19                    3              29              86.21
# 20                    5              26              76.92
# 21                    1              24              91.67
# 22                    7              23              69.57
# 23                    3              22              86.36
# 24                    5              22              77.27
# 25                    6              21              71.43
# 26                    2              21              90.48
# 27                    9              21              57.14
# 28                    4              20              80.00
# 29                    1              19              84.21
# 30                    1              18              94.44
# 31                    2              18              88.89
# 32                    8              18              55.56
# 33                    0              12             100.00
# 34                    0              12              91.67
# 35                    2              11              72.73
# 36                    1               9              77.78
# 37                    0               9              77.78
# 38                    1               8              87.50
# 39                    1               7              85.71
# 40                    5               7              14.29
# 41                    6               7              14.29
# 42                    0               6              83.33
# 43                    3               5              20.00
# 44                    1               5              80.00
# 45                    0               5             100.00
# 46                    0               4              75.00
# 47                    0               2             100.00
# 48                    0               1             100.00
# 49                    0               1             100.00
#
#     private_NPO_percentage  private_PO_percentage
# 0                     2.22                  35.00
# 1                     5.66                  34.91
# 2                    15.29                  65.88
# 3                     4.29                  60.00
# 4                    17.39                  31.88
# 5                     1.56                   6.25
# 6                     3.28                  18.03
# 7                     2.22                  86.67
# 8                     0.00                  41.46
# 9                     5.26                  21.05
# 10                    2.70                  13.51
# 11                    8.33                  52.78
# 12                    0.00                  37.50
# 13                    0.00                  54.84
# 14                    9.68                  48.39
# 15                    3.23                  16.13
# 16                    0.00                   0.00
# 17                    0.00                  16.67
# 18                    6.90                  37.93
# 19                    3.45                  10.34
# 20                    3.85                  19.23
# 21                    4.17                   4.17
# 22                    0.00                  30.43
# 23                    0.00                  13.64
# 24                    0.00                  22.73
# 25                    0.00                  28.57
# 26                    0.00                   9.52
# 27                    0.00                  42.86
# 28                    0.00                  20.00
# 29                   10.53                   5.26
# 30                    0.00                   5.56
# 31                    0.00                  11.11
# 32                    0.00                  44.44
# 33                    0.00                   0.00
# 34                    8.33                   0.00
# 35                    9.09                  18.18
# 36                   11.11                  11.11
# 37                   22.22                   0.00
# 38                    0.00                  12.50
# 39                    0.00                  14.29
# 40                   14.29                  71.43
# 41                    0.00                  85.71
# 42                   16.67                   0.00
# 43                   20.00                  60.00
# 44                    0.00                  20.00
# 45                    0.00                   0.00
# 46                   25.00                   0.00
# 47                    0.00                   0.00
# 48                    0.00                   0.00
# 49                    0.00                   0.00

# %%
# %%bigquery --project $project_id
#
# SELECT
#    state,
#    region,
#    level,
#    COUNT(CASE WHEN control = 'Public' THEN 1 END) AS public_colleges,
#    COUNT(CASE WHEN control = 'Private not-for-profit' THEN 1 END) AS private_NPO_colleges,
#    COUNT(CASE WHEN control = 'Private for-profit' THEN 1 END) AS private_PO_colleges,
#    COUNT(*) AS total_colleges,
#    ROUND((COUNT(CASE WHEN control = 'Public' THEN 1 END) / COUNT(*)) * 100, 2) AS public_percentage,
#    ROUND((COUNT(CASE WHEN control = 'Private not-for-profit' THEN 1 END) / COUNT(*)) * 100, 2) AS private_NPO_percentage,
#    ROUND((COUNT(CASE WHEN control = 'Private for-profit' THEN 1 END) / COUNT(*)) * 100, 2) AS private_PO_percentage
# FROM
#    `ba-775-a06.cc_datasets.1-details`
# WHERE
#     level = '4-year'
# GROUP BY
#    state, region, level
# ORDER BY
#    total_colleges DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state     region   level  public_colleges  \
# 0               New York  Northeast  4-year               39
# 1             California       West  4-year               32
# 2           Pennsylvania  Northeast  4-year               41
# 3                Florida  Southeast  4-year               36
# 4                   Ohio    Midwest  4-year               34
# 5                  Texas  Southwest  4-year               35
# 6          Massachusetts  Northeast  4-year               13
# 7               Illinois    Midwest  4-year               11
# 8         North Carolina  Southeast  4-year               16
# 9                Georgia  Southeast  4-year               23
# 10              Missouri    Midwest  4-year               13
# 11             Minnesota    Midwest  4-year               11
# 12              Michigan    Midwest  4-year               16
# 13             Tennessee  Southeast  4-year                9
# 14              Virginia  Southeast  4-year               15
# 15               Indiana    Midwest  4-year               15
# 16             Wisconsin    Midwest  4-year               14
# 17              Kentucky  Southeast  4-year                8
# 18            Washington       West  4-year               18
# 19                  Iowa    Midwest  4-year                3
# 20        South Carolina  Southeast  4-year               12
# 21              Colorado       West  4-year               13
# 22               Alabama  Southeast  4-year               13
# 23              Oklahoma  Southwest  4-year               15
# 24                Kansas    Midwest  4-year                8
# 25            New Jersey  Northeast  4-year               12
# 26              Maryland  Southeast  4-year               12
# 27               Arizona  Southwest  4-year                4
# 28                Oregon       West  4-year                7
# 29             Louisiana  Southeast  4-year               14
# 30              Nebraska    Midwest  4-year                6
# 31                  Utah       West  4-year                7
# 32              Arkansas  Southeast  4-year               10
# 33           Connecticut  Northeast  4-year                5
# 34         West Virginia  Southeast  4-year               12
# 35                 Maine  Northeast  4-year                8
# 36               Vermont  Northeast  4-year                5
# 37            New Mexico  Southwest  4-year                9
# 38          South Dakota    Midwest  4-year                7
# 39           Mississippi  Southeast  4-year                8
# 40          North Dakota    Midwest  4-year                9
# 41         New Hampshire  Northeast  4-year                5
# 42                Nevada       West  4-year                6
# 43  District of Columbia      Other  4-year                1
# 44                 Idaho       West  4-year                4
# 45                Hawaii       West  4-year                4
# 46          Rhode Island  Northeast  4-year                2
# 47               Montana       West  4-year                6
# 48              Delaware  Southeast  4-year                2
# 49                Alaska       West  4-year                3
# 50               Wyoming       West  4-year                1
#
#     private_NPO_colleges  private_PO_colleges  total_colleges  \
# 0                    116                   17             172
# 1                     74                   64             170
# 2                     82                    9             132
# 3                     47                   48             131
# 4                     57                   24             115
# 5                     44                   22             101
# 6                     63                    5              81
# 7                     50                   19              80
# 8                     43                   12              71
# 9                     30                   15              68
# 10                    34                   20              67
# 11                    25                   28              64
# 12                    39                    9              64
# 13                    38                   16              63
# 14                    28                   20              63
# 15                    32                   13              60
# 16                    24                   15              53
# 17                    21                   15              44
# 18                    16                    9              43
# 19                    31                    9              43
# 20                    20                    8              40
# 21                    10                   16              39
# 22                    16                    9              38
# 23                    12                    8              35
# 24                    20                    5              33
# 25                    18                    3              33
# 26                    16                    4              32
# 27                     4                   23              31
# 28                    17                    4              28
# 29                     9                    4              27
# 30                    15                    4              25
# 31                     7                   11              25
# 32                    12                    2              24
# 33                    15                    3              23
# 34                     8                    1              21
# 35                    11                    1              20
# 36                    13                    1              19
# 37                     2                    8              19
# 38                     6                    4              17
# 39                     7                    0              15
# 40                     5                    1              15
# 41                     8                    2              15
# 42                     1                    6              13
# 43                     8                    3              12
# 44                     4                    3              11
# 45                     5                    2              11
# 46                     8                    0              10
# 47                     4                    0              10
# 48                     4                    1               7
# 49                     1                    1               5
# 50                     0                    0               1
#
#     public_percentage  private_NPO_percentage  private_PO_percentage
# 0               22.67                   67.44                   9.88
# 1               18.82                   43.53                  37.65
# 2               31.06                   62.12                   6.82
# 3               27.48                   35.88                  36.64
# 4               29.57                   49.57                  20.87
# 5               34.65                   43.56                  21.78
# 6               16.05                   77.78                   6.17
# 7               13.75                   62.50                  23.75
# 8               22.54                   60.56                  16.90
# 9               33.82                   44.12                  22.06
# 10              19.40                   50.75                  29.85
# 11              17.19                   39.06                  43.75
# 12              25.00                   60.94                  14.06
# 13              14.29                   60.32                  25.40
# 14              23.81                   44.44                  31.75
# 15              25.00                   53.33                  21.67
# 16              26.42                   45.28                  28.30
# 17              18.18                   47.73                  34.09
# 18              41.86                   37.21                  20.93
# 19               6.98                   72.09                  20.93
# 20              30.00                   50.00                  20.00
# 21              33.33                   25.64                  41.03
# 22              34.21                   42.11                  23.68
# 23              42.86                   34.29                  22.86
# 24              24.24                   60.61                  15.15
# 25              36.36                   54.55                   9.09
# 26              37.50                   50.00                  12.50
# 27              12.90                   12.90                  74.19
# 28              25.00                   60.71                  14.29
# 29              51.85                   33.33                  14.81
# 30              24.00                   60.00                  16.00
# 31              28.00                   28.00                  44.00
# 32              41.67                   50.00                   8.33
# 33              21.74                   65.22                  13.04
# 34              57.14                   38.10                   4.76
# 35              40.00                   55.00                   5.00
# 36              26.32                   68.42                   5.26
# 37              47.37                   10.53                  42.11
# 38              41.18                   35.29                  23.53
# 39              53.33                   46.67                   0.00
# 40              60.00                   33.33                   6.67
# 41              33.33                   53.33                  13.33
# 42              46.15                    7.69                  46.15
# 43               8.33                   66.67                  25.00
# 44              36.36                   36.36                  27.27
# 45              36.36                   45.45                  18.18
# 46              20.00                   80.00                   0.00
# 47              60.00                   40.00                   0.00
# 48              28.57                   57.14                  14.29
# 49              60.00                   20.00                  20.00
# 50             100.00                    0.00                   0.00

# %% [markdown]
# **Insights**
#
# In the landscape of higher education, California stands out with 180 2-year colleges, reaffirming its commitment to diverse educational pathways. Texas and Pennsylvania follow, with 106 and 85 2-year institutions, respectively, emphasizing a collective dedication to accessible and specialized educational opportunities.
#
# On the 4-year front, New York leads with 172 colleges, showcasing a comprehensive higher education environment. California, excelling in both categories, boasts 170 4-year institutions, while Pennsylvania maintains a robust presence with 132. This distribution highlights regional priorities and underscores the commitment of these states to providing a diverse array of educational opportunities to meet the varying needs of students.

# %% [markdown]
# **Going forward, we want to look deeper to undertand the metrics in the data set. Starting with the entry scores averages, such as SAT scores. We hope that this will help us undertand the disticntion between colleges and the spectrum of SAT scores across the states.**

# %% [markdown]
# ##**5.1 Admission Factors - Merit**

# %% [markdown]
# Here, our exploration delves into key factors influencing admission, scrutinizing metrics such as SAT scores, the quantity, and value of awards. By understanding the nuances of these admission-related indicators, we aim to discern prevalent trends and provide valuable insights.
#
# Note that some colleges doesn't require the SAT exam - these are predominantly non science and math college programs. Such as Arts, Medicine etc.

# %% [markdown]
# ###**5.1.1 Average SAT scores according to States**

# %% [markdown]
# **Aim:**
#
# Exploring SAT scores across states, we aim to determine the average scores for each state and identify which state boasts the highest average SAT score.

# %%
# %%bigquery --project $project_id
# SELECT
#   state,region,
#   ROUND(AVG(med_sat_value)) AS mean_sat,
#   RANK() OVER (ORDER BY AVG(med_sat_value) DESC) AS ranking,
#   ROUND(AVG(grad_100_value), 2) AS avg_grad100_rate,
#   ROUND(AVG(grad_150_value), 2) AS avg_grad150_rate
# FROM
#   `ba-775-a06.cc_datasets.1-details`
# WHERE
#   med_sat_value IS NOT NULL AND grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# GROUP BY
#   state,region
# ORDER BY
#   ranking;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state     region  mean_sat  ranking  avg_grad100_rate  \
# 0   District of Columbia      Other    1166.0        1             59.42
# 1           Rhode Island  Northeast    1153.0        2             62.00
# 2                   Utah       West    1130.0        3             33.18
# 3                Wyoming       West    1123.0        4             24.10
# 4          Massachusetts  Northeast    1118.0        5             52.57
# 5              Minnesota    Midwest    1114.0        6             49.33
# 6             Washington       West    1112.0        7             46.07
# 7               New York  Northeast    1103.0        8             46.53
# 8                Arizona  Southwest    1102.0        9             32.65
# 9             California       West    1096.0       10             42.66
# 10                Oregon       West    1090.0       11             42.04
# 11              Colorado       West    1089.0       12             31.21
# 12              Illinois    Midwest    1087.0       13             41.60
# 13              Maryland  Southeast    1084.0       14             45.45
# 14                  Iowa    Midwest    1083.0       15             48.40
# 15              Missouri    Midwest    1083.0       16             38.37
# 16                  Ohio    Midwest    1082.0       17             44.72
# 17             Wisconsin    Midwest    1076.0       18             34.49
# 18           Connecticut  Northeast    1076.0       19             46.06
# 19              Michigan    Midwest    1071.0       20             30.30
# 20              Nebraska    Midwest    1070.0       21             34.46
# 21               Montana       West    1064.0       22             25.32
# 22               Indiana    Midwest    1062.0       23             40.01
# 23              Arkansas  Southeast    1056.0       24             27.10
# 24               Florida  Southeast    1053.0       25             32.06
# 25                 Maine  Northeast    1051.0       26             40.32
# 26              Virginia  Southeast    1048.0       27             43.60
# 27         New Hampshire  Northeast    1046.0       28             51.49
# 28            New Jersey  Northeast    1044.0       29             39.99
# 29          Pennsylvania  Northeast    1043.0       30             46.41
# 30                Nevada       West    1042.0       31             15.15
# 31          South Dakota    Midwest    1042.0       32             24.77
# 32              Kentucky  Southeast    1040.0       33             30.97
# 33               Vermont  Northeast    1039.0       34             41.85
# 34             Tennessee  Southeast    1039.0       35             30.61
# 35                 Texas  Southwest    1034.0       36             29.11
# 36             Louisiana  Southeast    1033.0       37             22.65
# 37               Alabama  Southeast    1032.0       38             24.66
# 38                 Idaho       West    1031.0       39             24.93
# 39          North Dakota    Midwest    1029.0       40             23.37
# 40              Oklahoma  Southwest    1027.0       41             26.50
# 41               Georgia  Southeast    1026.0       42             29.95
# 42                Kansas    Midwest    1024.0       43             31.46
# 43            New Mexico  Southwest    1020.0       44             20.12
# 44        South Carolina  Southeast    1008.0       45             36.48
# 45                Alaska       West    1008.0       46             25.00
# 46        North Carolina  Southeast    1003.0       47             36.17
# 47                Hawaii       West    1001.0       48             17.80
# 48           Mississippi  Southeast     983.0       49             26.94
# 49         West Virginia  Southeast     980.0       50             25.41
# 50              Delaware  Southeast     970.0       51             32.43
#
#     avg_grad150_rate
# 0              71.78
# 1              74.16
# 2              56.88
# 3              54.10
# 4              65.42
# 5              64.35
# 6              63.36
# 7              60.70
# 8              52.40
# 9              61.78
# 10             56.65
# 11             50.39
# 12             56.30
# 13             59.77
# 14             60.15
# 15             54.51
# 16             59.42
# 17             55.75
# 18             61.33
# 19             53.59
# 20             55.51
# 21             47.03
# 22             54.04
# 23             42.69
# 24             48.48
# 25             52.24
# 26             56.59
# 27             61.59
# 28             60.48
# 29             60.50
# 30             47.15
# 31             43.67
# 32             47.02
# 33             51.36
# 34             45.37
# 35             46.62
# 36             41.62
# 37             41.95
# 38             46.80
# 39             46.79
# 40             41.99
# 41             46.89
# 42             46.63
# 43             38.38
# 44             48.93
# 45             40.00
# 46             51.00
# 47             40.08
# 48             44.03
# 49             40.61
# 50             46.90

# %% [markdown]
# **Insights**
#
# D.C., Rhode Island, Utah, Wyoming, and Massachusetts have the highest average SAT scores, around 1100, and they are mostly located in the Northeast and West regions. Universities in the West region generally have lower graduation rates than those in the Northeast region.
# North Caolina, Hawaii, Mississippi, West Virginia, Delaware have the lowest average SAT scores, around 980, and they are mostly located in the Southeast regions, and their graduation rates are generally lower than states with higher average SAT scores.

# %% [markdown]
# Going further, we want to see if there are any identifiable distinctions between colleges with high and low SAT scores and answer the following question -

# %% [markdown]
# ###**5.1.2 Analyzing the patterns of SAT scores**

# %% [markdown]
# **Aim:**
#
# Analyzing the data reveals patterns in the distribution of high SAT score schools, both within states and across regions.

# %%
# %%bigquery --project $project_id
# WITH count_table AS (SELECT state,region,
#   CASE
#   WHEN med_sat_value BETWEEN 1350 AND 1600 THEN 'High_SAT_Score'
#    WHEN med_sat_value BETWEEN 1200 AND 1350 THEN 'Higher_Median_SAT_Score'
#    WHEN med_sat_value BETWEEN 1050 AND 1200 THEN 'Lower_Median_SAT_Score'
#    WHEN med_sat_value BETWEEN 0 AND 1050 THEN 'Low_SAT_Score'
#    END AS sat, COUNT(unitid) AS count,ROUND(AVG(grad_100_value), 2) AS avg_grad100_rate,
#   ROUND(AVG(grad_150_value), 2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE med_sat_value IS NOT NULL AND grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# GROUP BY sat,state,region)
#
# SELECT state,region,sat,count,ROUND((count/SUM(count) OVER(PARTITION BY state))*100,2) AS percentage_in_each_state,avg_grad100_rate,avg_grad150_rate
# FROM count_table
# ORDER BY sat,percentage_in_each_state DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                     state     region                     sat  count  \
# 0           Massachusetts  Northeast          High_SAT_Score      9
# 1    District of Columbia      Other          High_SAT_Score      1
# 2            Rhode Island  Northeast          High_SAT_Score      1
# 3             Connecticut  Northeast          High_SAT_Score      2
# 4           New Hampshire  Northeast          High_SAT_Score      1
# ..                    ...        ...                     ...    ...
# 154          Pennsylvania  Northeast  Lower_Median_SAT_Score     24
# 155                 Maine  Northeast  Lower_Median_SAT_Score      2
# 156           Connecticut  Northeast  Lower_Median_SAT_Score      2
# 157         New Hampshire  Northeast  Lower_Median_SAT_Score      1
# 158         West Virginia  Southeast  Lower_Median_SAT_Score      1
#
#      percentage_in_each_state  avg_grad100_rate  avg_grad150_rate
# 0                       17.65             78.02             93.02
# 1                       16.67             88.00             92.50
# 2                       14.29             84.40             94.50
# 3                       14.29             87.90             94.65
# 4                       12.50             86.50             94.70
# ..                        ...               ...               ...
# 154                     21.62             59.10             70.75
# 155                     16.67             42.50             56.95
# 156                     14.29             61.60             68.45
# 157                     12.50             71.10             74.50
# 158                      5.56             33.70             57.10
#
# [159 rows x 7 columns]

# %% [markdown]
# **Insights**
#
# From the results, we can observe that the Northeast regions and D.C. have the highest proportion of schools falling into the high SAT score range. Among them, Massachusetts has the highest proportions and also the highest number of high SAT score schools. Additionally, it is evident that schools in the high SAT score range generally have higher graduation rates.

# %% [markdown]
# Building up on the insights from the previous query, we want to see what type of colleges usually have high SAT average scores and answer the following question -
#
# ###**5.1.3 Identifying School Categories with the Highest Average SAT Scores.**

# %%
# %%bigquery --project $project_id
# SELECT
#   basic,
#   ROUND(AVG(med_sat_value)) AS mean_sat,
#   RANK() OVER (ORDER BY AVG(med_sat_value) DESC) AS ranking,
#   ROUND(AVG(grad_100_value), 2) AS avg_grad100_rate,
#   ROUND(AVG(grad_150_value), 2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE med_sat_value IS NOT NULL AND grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# GROUP BY
#   basic
# ORDER BY
#   ranking;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                 basic  mean_sat  ranking  \
# 0   Research Universities--very high research acti...    1258.0        1
# 1                              Schools of engineering    1253.0        2
# 2             Baccalaureate Colleges--Arts & Sciences    1133.0        3
# 3       Research Universities--high research activity    1129.0        4
# 4                    Other technology-related schools    1104.0        5
# 5                   Schools of art- music- and design    1064.0        6
# 6                      Doctoral/Research Universities    1049.0        7
# 7                    Other health professions schools    1040.0        8
# 8              Associates--Public Rural-serving Small    1040.0        9
# 9   Masters Colleges and Universities--larger prog...    1037.0       10
# 10  Masters Colleges and Universities--medium prog...    1027.0       11
# 11  Theological seminaries- Bible colleges- and ot...    1001.0       12
# 12  Masters Colleges and Universities--smaller pro...    1000.0       13
# 13           Not applicable- not in Carnegie universe     997.0       14
# 14                 Schools of business and management     994.0       15
# 15             Baccalaureate Colleges--Diverse Fields     991.0       16
# 16                     Associates--Public Special Use     967.0       17
# 17                  Baccalaureate/Associates Colleges     962.0       18
# 18                 Associates--Private Not-for-profit     926.0       19
# 19            Associates--Public Rural-serving Medium     925.0       20
# 20  Associates--Public 2-year colleges under 4-yea...     878.0       21
# 21  Associates--Private Not-for-profit 4-year Prim...     845.0       22
# 22       Associates--Public Urban-serving Multicampus     756.0       23
#
#     avg_grad100_rate  avg_grad150_rate
# 0              57.15             76.91
# 1              48.77             64.88
# 2              56.53             65.58
# 3              34.74             58.77
# 4              54.30             54.30
# 5              42.36             54.50
# 6              34.15             52.96
# 7              40.55             53.66
# 8              23.10             24.90
# 9              34.09             52.95
# 10             33.55             51.00
# 11             31.15             42.80
# 12             31.10             47.62
# 13             35.87             45.83
# 14             35.53             46.36
# 15             31.72             45.81
# 16             42.50             42.50
# 17             19.53             32.09
# 18             37.75             39.50
# 19             12.07             19.57
# 20             12.91             21.27
# 21             61.80             61.80
# 22              5.70              5.70

# %% [markdown]
# **Insights:**
#
# According to the results, we can see that research universities and engineering or technology-related schools have the highest average SAT scores. In contrast, associate colleges have the lowest ones, which is unsurprising because associate colleges often have programs that are more directly aligned with specific career paths and are considered as a pathway for transfering into larger universities.

# %% [markdown]
# We also want to see if there are any distinguishable differences between control types and levels of schools and the average SAT scores and answer the following question -
#
#
# ###**5.1.4 Exploring the Relation Between School Control Types, Levels, and Average SAT Scores.**

# %%
# %%bigquery --project $project_id
# SELECT level, control,
#       ROUND(AVG(med_sat_value)) as mean_sat
# FROM `ba-775-a06.cc_datasets.1-details`
# GROUP BY control, level
# ORDER BY mean_sat DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     level                 control  mean_sat
# 0  4-year  Private not-for-profit    1077.0
# 1  4-year                  Public    1039.0
# 2  4-year      Private for-profit    1003.0
# 3  2-year  Private not-for-profit     924.0
# 4  2-year                  Public     899.0
# 5  2-year      Private for-profit       NaN

# %% [markdown]
# **Insights:**
#
# The observed pattern where the mean SAT scores tend to be higher in private not-for-profit schools, followed by public schools, and then private for-profit schools. Some potential explanations can be private not-for-profit schools frequently emphasize academic excellence and may have a more specific mission or focus and more financial resources available for academic programs that attract students with higher SAT scores. Public schools and private for-profit institutions, more diverse and accessible, may serve a broader range of students with varying academic backgrounds. Interestingly, 2-year private for-profit schools have no data for sat scores. This is probably because they may have admissions policies that do not heavily rely on standardized test scores like the SAT. They perhaps prioritize other factors, such as work experience, industry certifications, or specific skill sets for admission.

# %% [markdown]
# Since awards granted by the college also plays an important part in the decision making process, we want to answer the following question -

# %% [markdown]
# ###**5.1.5 Analyzing Expenditure and Award Frequency Impact on State Student Attraction.**

# %% [markdown]
# **Aim:**
#
# The correlation between spending per award and the frequency of awards per 100 full-time undergraduates unveils significant insights into how states attract students.

# %%
# %%bigquery --project $project_id
# SELECT state,
#       ROUND(AVG(awards_per_state_value),1) AS avg_awards_per_state,
#       ROUND(AVG(exp_award_state_value),1) AS avg_exp_award_state
# FROM `ba-775-a06.cc_datasets.3-sectors`
# WHERE state != 'United States' AND awards_per_state_value IS NOT NULL AND exp_award_state_value IS NOT NULL
# GROUP BY state
# ORDER BY avg_exp_award_state DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state  avg_awards_per_state  avg_exp_award_state
# 0   District of Columbia                  18.5             107410.0
# 1            Connecticut                  18.2             104429.5
# 2                 Alaska                  20.6              97912.0
# 3           Rhode Island                  20.6              76941.7
# 4                Montana                  19.1              73905.3
# 5         North Carolina                  21.0              72848.8
# 6               Maryland                  25.2              72578.0
# 7                Vermont                  22.4              69803.8
# 8          Massachusetts                  34.0              68272.5
# 9           Pennsylvania                  22.5              65842.0
# 10             Minnesota                  23.0              65727.5
# 11            New Jersey                  24.4              65647.2
# 12              New York                  24.3              62517.2
# 13              Nebraska                  22.3              62432.3
# 14         New Hampshire                  26.8              62410.0
# 15              Illinois                  25.5              60909.0
# 16            California                  26.1              59533.3
# 17                Hawaii                  20.7              58208.2
# 18              Delaware                  21.6              57791.6
# 19               Georgia                  23.6              56857.7
# 20               Indiana                  26.1              56849.2
# 21               Wyoming                  32.7              56203.7
# 22              Michigan                  23.0              55711.0
# 23          South Dakota                  21.3              55449.2
# 24            New Mexico                  23.2              54571.8
# 25             Tennessee                  23.1              53395.0
# 26          North Dakota                  24.1              53042.8
# 27        South Carolina                  21.9              51935.2
# 28                 Maine                  28.1              51536.2
# 29            Washington                  25.6              51246.2
# 30         West Virginia                  20.7              51229.2
# 31                  Ohio                  23.4              50837.7
# 32             Wisconsin                  24.4              49521.0
# 33                Oregon                  25.9              49418.6
# 34                Nevada                  19.7              49194.8
# 35                  Iowa                  24.6              48858.6
# 36               Florida                  24.1              48652.5
# 37              Kentucky                  25.6              48260.8
# 38                Kansas                  28.4              46169.8
# 39              Colorado                  23.4              45275.8
# 40                 Idaho                  27.8              44991.8
# 41              Oklahoma                  25.3              44823.4
# 42               Alabama                  17.0              44789.5
# 43              Arkansas                  24.4              44194.7
# 44              Missouri                  26.6              44103.3
# 45                 Texas                  23.0              43950.3
# 46           Mississippi                  24.5              43345.8
# 47              Virginia                  23.5              42108.6
# 48             Louisiana                  21.9              41674.3
# 49                  Utah                  28.0              40916.5
# 50               Arizona                  26.7              36825.0

# %% [markdown]
# **Insights:**
#
# From the table, D.C. has the highest amount of money spent per award, reflecting reflecting a more generous acknowledgement of students' achivements,contributions. Conversely, Arizona has the lowest, probably suggesting a more conservative approach in terms of financial allocation for awards, possibly emphasizing efficiency or cost-effectiveness. Interestingly, the number of awards per 100 full-time undergraduates is higher among states with a low amount of money spent per award. This also could mean that schools in these states choose to grant more awards instead of increasing the monetary value to attract students.

# %% [markdown]
# Here, we want to go a step deeper to answer the following question -
#
# ###**5.1.6 Exploring the Interplay**
#
# **Aim:**
#
# Investigate Relationships Between School Types and Funding Patterns for Awards.

# %%
# %%bigquery --project $project_id
# SELECT state, control,
#       ROUND(AVG(awards_per_state_value),1) AS avg_awards_per_state,
#       ROUND(AVG(exp_award_state_value),1) AS avg_exp_award_state
# FROM `ba-775-a06.cc_datasets.3-sectors`
# WHERE state != 'United States' AND awards_per_state_value IS NOT NULL AND exp_award_state_value IS NOT NULL
# GROUP BY state, control
# ORDER BY avg_exp_award_state DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                     state                 control  avg_awards_per_state  \
# 0             Connecticut  Private not-for-profit                  21.8
# 1                Maryland  Private not-for-profit                  22.4
# 2    District of Columbia                  Public                  16.5
# 3                  Alaska                  Public                  12.7
# 4          North Carolina  Private not-for-profit                  17.4
# ..                    ...                     ...                   ...
# 145               Arizona      Private for-profit                  34.8
# 146              Missouri      Private for-profit                  34.1
# 147           Mississippi      Private for-profit                  38.0
# 148               Alabama      Private for-profit                  16.1
# 149               Wyoming      Private for-profit                  58.1
#
#      avg_exp_award_state
# 0               188870.0
# 1               184772.0
# 2               151215.0
# 3               131978.5
# 4               119003.5
# ..                   ...
# 145              23486.5
# 146              21174.5
# 147              21061.0
# 148              20840.0
# 149              20046.0
#
# [150 rows x 4 columns]

# %% [markdown]
# **Insights:**
#
# From this table, we can clearly see that private not-for-profit schools have a higher amount of money spent per award, possibly because many of these schools have substantial endowments and engage in extensive fundraising efforts. This additional financial support allows them to dedicate more resources to awards. Also, private institutions often emphasize providing high-quality education and attracting top-tier students. Offering substantial awards can be a strategy to attract and retain exceptional students, contributing to the institution's reputation and overall excellence. In contrast, private for-profit schools need to consider generating profit, so they may prioritize cost control and allocate fewer resources to awards.

# %% [markdown]
# Picking up from the previous query, we want to see the distribution of this co-relation across the states and answer the following question -
#
# ###**5.1.7 Examining Associations**
#
# **Aim:**
#
# Explore the connections between school level, state, and overall awards.

# %%
# %%bigquery --project $project_id
# SELECT state, level,
#       ROUND(AVG(awards_per_state_value),1) AS avg_awards_per_state,
#       ROUND(AVG(exp_award_state_value),1) AS avg_exp_award_state
# FROM `ba-775-a06.cc_datasets.3-sectors`
# WHERE state != 'United States' AND awards_per_state_value IS NOT NULL AND exp_award_state_value IS NOT NULL
# GROUP BY state, level
# ORDER BY avg_exp_award_state DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                     state   level  avg_awards_per_state  avg_exp_award_state
# 0                  Alaska  2-year                   9.1             160134.0
# 1             Connecticut  4-year                  19.3             120177.7
# 2    District of Columbia  4-year                  18.5             107410.0
# 3                Maryland  4-year                  23.2              93848.0
# 4          North Carolina  4-year                  20.7              93720.0
# ..                    ...     ...                   ...                  ...
# 96               Virginia  2-year                  23.9              24596.5
# 97               Colorado  2-year                  23.6              23881.0
# 98                Arizona  2-year                  28.6              23640.5
# 99             Washington  2-year                  28.9              21600.5
# 100             Louisiana  2-year                  22.5              18496.7
#
# [101 rows x 4 columns]

# %% [markdown]
# **Insights**
#
# We can see that 4-year schools often have a higher amount of money spent per award than 2-year schools. This is because shorter program durations may result in lower overall educational costs, including the costs associated with awards. Additionally, two-year schools primarily focus on preparing students for specific careers or facilitating transfer to four-year schools. As a result, they may alloc,ate fewer resources per award. But it is also because 2-year schools aim to provide accessible education, they often admit a larger number of students, contributing to a higher number of awards

# %% [markdown]
# We also aim to identify any noticeable variations between the combined factors of school control types and levels and awards and answer the following question -
#
# ###**5.1.8 Unveiling the Combined Influence**
#
# **Aim:**
#
# Examine how the joint influence of school type and level impacts award outcomes.

# %%
# %%bigquery --project $project_id
# SELECT level, control,
#       ROUND(AVG(awards_per_value),1) AS avg_awards_num,
#       ROUND(AVG(exp_award_value),1) AS avg_award_value,
# FROM `ba-775-a06.cc_datasets.1-details`
# GROUP BY control, level
# ORDER BY avg_award_value DESC,avg_awards_num DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     level                 control  avg_awards_num  avg_award_value
# 0  4-year  Private not-for-profit            22.5         100078.1
# 1  4-year                  Public            20.1          64263.1
# 2  4-year      Private for-profit            25.9          55436.0
# 3  2-year  Private not-for-profit            31.3          48995.6
# 4  2-year                  Public            18.6          43857.1
# 5  2-year      Private for-profit            36.0          32878.0

# %% [markdown]
# **Insights**
#
# Adding to the previous questions, we observe that 4-year schools offer higher-value awards than 2-year schools, with Private not-for-profit schools standing out in their efforts to attract top-tier students. Interestingly, 2-year public schools have the smallest number of average awards being offered, while 2-year private for-profit schools have the largest number. This is likely because Private for-profit institutions have more flexibility in awarding scholarships due to their autonomy and less reliance on public funding.
# In contrast, Public institutions, particularly at the 2-year level, often face budget constraints due to reliance on state funding. Additionally, they may have larger overall student populations. With limited resources, spreading awards across a larger number of students can lead to a smaller number of awards per 100 students and a more selective approach when awarding scholarships, focusing on specific criteria such as academic achievements or financial need.

# %% [markdown]
# Building upon the previous query, we want to explore the relationship between SAT scores and awards and answer the following question
#
# ###**5.1.9 Analyzing Variation**
#
# **Aim:**
#
# Explore the differences in awards and financial aid across various SAT score groups.

# %%
# %%bigquery --project $project_id
# SELECT
#   CASE
#   WHEN med_sat_value BETWEEN 1350 AND 1600 THEN 'High_SAT_Score'
#    WHEN med_sat_value BETWEEN 1200 AND 1350 THEN 'Higher_Median_SAT_Score'
#    WHEN med_sat_value BETWEEN 1050 AND 1200 THEN 'Lower_Median_SAT_Score'
#    WHEN med_sat_value BETWEEN 0 AND 1050 THEN 'Low_SAT_Score'
#    END AS sat,
#    COUNT(unitid) AS count,
#    ROUND(AVG(awards_per_value),1) AS avg_awards_num,
#    ROUND(AVG(exp_award_value),1) AS avg_award_value,
#    ROUND(AVG(aid_value),1) As avg_aid
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE med_sat_value IS NOT NULL AND grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# GROUP BY sat
# ORDER BY
#   CASE
#     WHEN sat = 'High_SAT_Score' THEN 1
#     WHEN sat = 'Higher_Median_SAT_Score' THEN 2
#     WHEN sat = 'Lower_Median_SAT_Score' THEN 3
#     WHEN sat = 'Low_SAT_Score' THEN 4
#   END
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                        sat  count  avg_awards_num  avg_award_value  avg_aid
# 0           High_SAT_Score     59            23.9         233987.6  30613.1
# 1  Higher_Median_SAT_Score    121            22.5         116261.4  17991.2
# 2   Lower_Median_SAT_Score    448            21.8          80150.6  13050.4
# 3            Low_SAT_Score    691            21.0          68691.5  10243.5

# %% [markdown]
# **Insights**
#
# Now let's look at the relationship between SAT score and awards. We can see that a positive correlation is evident. Schools with higher SAT scores may have a higher level of prestige and potentially more resources. Consequently,These institutions may prioritize offering substantial awards to maintain their reputation and attract top talent. This can also be supported by average aid value. Higher SAT score schools are more generous, providing higher-value financial aid to support and invest in students with exceptional academic abilities. In summary, institutions use financial support for education as a strategic tool to achieve their mission, attract a diverse and talented student body, and enhance their overall standing in the higher education landscape.

# %% [markdown]
# ##**Merit Summary**
#
# **Analyzing the Interplay Between SAT Scores and Educational Achievements Across the United States**
#
# Regional disparities in SAT scores and graduation rates underscore significant variations in academic achievement throughout the United States. The data reveals a compelling narrative, indicating that 4-year institutions allocate more funding per award compared to their 2-year counterparts. This discrepancy not only reflects differences in program duration but also sheds light on distinct educational expenditure patterns.
#
# Furthermore, the impact of institutional characteristics on SAT scores is evident, particularly in research universities and technology-focused schools. These institutions consistently demonstrate higher SAT scores, emphasizing a correlation between academic focus and student achievement. This correlation is particularly noteworthy when considering institutions that prioritize career readiness.
#
# Combining these two factors and examining the connection between SAT scores and awards reveals a positive correlation. This observation aligns with the notion that higher SAT score schools tend to be more generous, offering higher-value financial aid to support students with exceptional academic abilities
#
# In essence, these findings provide valuable insights into the intricate interplay between local economic conditions, institutional attributes, and educational outcomes. The disparities observed contribute to a nuanced understanding of the factors influencing academic achievement and shape the evolving landscape of the educational environment in the United States.

# %% [markdown]
# ##**5.2. Graduation Factors - Graduation Rates**
#
# Subsequently, armed with a clearer comprehension of the admission landscape, our attention shifts to a pivotal aspect: graduation rates. This phase aims to empower high school students in making more informed decisions by providing a focused analysis of institutions' success in facilitating the completion of degrees.

# %% [markdown]
# We want to kick-start by understanding how graduation rates are varying across the states and answer the following question -
#
# ###**5.2.1 States having the highest Graduation Rate**

# %%
# %%bigquery --project $project_id
# SELECT state, ROUND(AVG(grad_100_value),2) AS avg_grad100_rate, ROUND(AVG(grad_150_value),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# GROUP BY state
# ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC
# LIMIT 15;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state  avg_grad100_rate  avg_grad150_rate
# 0           Rhode Island             53.00             64.81
# 1          Massachusetts             43.31             54.05
# 2           Pennsylvania             42.37             56.27
# 3   District of Columbia             39.74             50.01
# 4                   Iowa             36.18             46.62
# 5                Vermont             35.18             44.59
# 6          New Hampshire             34.60             44.92
# 7                Florida             33.55             49.28
# 8               New York             33.26             48.42
# 9               Delaware             32.99             41.72
# 10              Missouri             32.66             45.78
# 11                 Maine             32.66             44.54
# 12              Virginia             32.30             44.31
# 13               Indiana             31.74             45.21
# 14           Connecticut             31.55             43.05

# %% [markdown]
# **Insights:**
#
# Top 10 highest states of graduation rate are Rhode Island, Massachusetts, Pennsylvania, District of Columbia, Iowa, Vermont, New Hampshire, Florida, New York, Delaware.
#
# The top states performing better interms of average of grad100 rate and grad150 rate compared to other states. Rhode Island state has the highest grad100 rate of 53 and grad150 rate of 64.81.

# %% [markdown]
# Here, we want to tone it down to the colleges with the highest graduation rates and answer the following question -
#
# ###**5.2.2 Colleges exhibit the highest rate of graduation**

# %%
# %%bigquery --project $project_id
# SELECT chronname AS college_name, grad_100_value AS avg_grad100_rate, grad_150_value AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC
# LIMIT 15;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                               college_name  avg_grad100_rate  avg_grad150_rate
# 0                          Academy College             100.0             100.0
# 1         Stevens Henager College at Ogden             100.0             100.0
# 2   Phillips Beth Israel School of Nursing             100.0             100.0
# 3         Golf Academy of America (Calif.)             100.0             100.0
# 4         Vatterott College - Sunset Hills             100.0             100.0
# 5            Kaplan University - Urbandale             100.0             100.0
# 6          Lawrence Memorial/Regis College             100.0             100.0
# 7          Everest College - Ontario Metro             100.0             100.0
# 8                  Apex School of Theology             100.0             100.0
# 9     Samaritan Hospital School of Nursing             100.0             100.0
# 10                      Coleman University             100.0             100.0
# 11               Southwest Florida College             100.0             100.0
# 12           Vatterott College - NorthPark             100.0             100.0
# 13                  Computer Career Center              99.2              99.2
# 14          Golf Academy of America (Fla.)              99.0              99.0

# %% [markdown]
# **Insights:**
#
# The list of college names here shows the 100 rate for both grad100 rate and grad150 rate.
#
# These are the colleges which has maximum rates as 100 for each.
#
# * Academy College
# * Stevens Henager College at Ogden
# * Phillips Beth Israel School of Nursing
# * Golf Academy of America (Calif.)
# * Vatterott College - Sunset Hills
# * Kaplan University - Urbandale
# * Lawrence Memorial/Regis College
# * Everest College - Ontario Metro
# * Apex School of Theology
# * Samaritan Hospital School of Nursing
# * Coleman University
# * Southwest Florida College
# * Vatterott College - NorthPark
#
# These colleges show an exceptional 100% graduation rate. While these are not the popularly known colleges, the concentrations of the colleges are also diverse and less mainstream, unlike math, science and medicine.

# %% [markdown]
# Which brings us to understanding the concentration of these colleges and we want to answer the folling question -
#
# ###**5.2.3 Identifying Educational Systems with the Highest Graduation Rates**

# %%
# %%bigquery --project $project_id
# SELECT level, control AS institution_category, basic AS college_type,COUNT(*) AS University_numbers, ROUND(AVG(grad_100_value),2) AS avg_grad100_rate, ROUND(AVG(grad_150_value),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE grad_100_value IS NOT NULL AND grad_150_value IS NOT NULL
# GROUP BY level,control,basic
# ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC
# LIMIT 15;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      level    institution_category  \
# 0   2-year      Private for-profit
# 1   4-year  Private not-for-profit
# 2   4-year  Private not-for-profit
# 3   4-year  Private not-for-profit
# 4   4-year  Private not-for-profit
# 5   4-year  Private not-for-profit
# 6   4-year                  Public
# 7   2-year  Private not-for-profit
# 8   4-year      Private for-profit
# 9   2-year  Private not-for-profit
# 10  4-year                  Public
# 11  4-year  Private not-for-profit
# 12  4-year  Private not-for-profit
# 13  2-year  Private not-for-profit
# 14  4-year  Private not-for-profit
#
#                                          college_type  University_numbers  \
# 0                    Other health professions schools                   1
# 1   Research Universities--very high research acti...                  34
# 2                                      Schools of law                   1
# 3                              Schools of engineering                   3
# 4             Baccalaureate Colleges--Arts & Sciences                 218
# 5       Research Universities--high research activity                  23
# 6                   Schools of art- music- and design                   2
# 7                      Associates--Private For-profit                   8
# 8   Theological seminaries- Bible colleges- and ot...                   1
# 9   Associates--Private For-profit 4-year Primaril...                   1
# 10  Research Universities--very high research acti...                  72
# 11                  Schools of art- music- and design                  48
# 12                     Doctoral/Research Universities                  42
# 13                 Associates--Private Not-for-profit                  54
# 14  Masters Colleges and Universities--larger prog...                 195
#
#     avg_grad100_rate  avg_grad150_rate
# 0              81.50             81.50
# 1              81.12             90.53
# 2              80.00             80.00
# 3              59.50             71.43
# 4              59.45             67.39
# 5              54.61             73.96
# 6              52.90             66.80
# 7              51.56             63.84
# 8              51.40             61.40
# 9              48.20             59.10
# 10             45.83             70.47
# 11             43.14             57.00
# 12             42.93             58.35
# 13             42.88             50.51
# 14             41.71             55.41

# %% [markdown]
# **Insights:**
#
# The two institution categories, 2-year private for-profit and 4-year private not-for-profit, showcase the top three graduation rates, hovering at approximately 80%, for both completion within 100% and 150% of normal time. These rates notably exceed those of other institution categories, typically falling within the range of 40% to 60%, with a particularly wider gap, especially in completion within 100% of normal time.
#
# Examining the relationship between the number of colleges and graduation rates, it is evident that the highest graduation rates are associated with the fewest college numbers, and vice versa.

# %% [markdown]
# While the previous results indicate that grad150 rate is higher than grad100 rate, we want to explicitly look at the variance here and answer the following question -
#
# ###**5.2.4 Examining Graduation Rate Variations Across Different Graduation Periods**

# %%
# %%bigquery --project $project_id
# SELECT year, ROUND(AVG(grad_100_rate),2) AS avg_grad100_rate, ROUND(AVG(grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads`
# WHERE grad_100_rate IS NOT NULL AND grad_150_rate IS NOT NULL AND gender <> 'B'
# GROUP BY year
# ORDER BY year, avg_grad100_rate DESC, avg_grad150_rate DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year  avg_grad100_rate  avg_grad150_rate
# 0   2002             29.31             45.86
# 1   2003             29.61             46.03
# 2   2004             29.62             46.02
# 3   2005             29.78             46.07
# 4   2006             30.39             46.86
# 5   2007             30.80             46.59
# 6   2008             30.41             46.24
# 7   2009             30.14             46.14
# 8   2010             31.07             46.12
# 9   2011             30.53             45.77
# 10  2012             30.98             46.52
# 11  2013             31.34             46.55

# %% [markdown]
# **Insights:**
#
# From 2002 to 2013, the graduation rates exhibited a consistent trend, with rates remaining at 30% for completion within 100% of normal time and 45% for completion within 150% of normal time. The variation in graduation rates is slightly higher for the 100% of normal time compared to the 150%.
#
# Graduation rates for 150% of normal time consistently surpass those for 100% in every year. This indicates that U.S. college students often extend beyond the standard completion time. They tend to take 1.5 times the normal duration to graduate from colleges, equating to six years in a 4-year system or three years in a 2-year system.

# %% [markdown]
# After we are aware of the overall graduation rate fluctuations over the years, we would like to delve deeper into examining the annual variations in graduation rates for each individual college here and answer the following question -
#
# ###**5.2.5 Exploring Graduation Rate Variability Within Colleges Across Time Periods**

# %%
# %%bigquery --project $project_id
# SELECT *
# FROM (
# SELECT chronname AS college_name, MIN(year) AS year, ROUND(AVG(A.grad_100_rate),2) AS avg_grad100_rate, ROUND(AVG(A.grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads` AS A
# LEFT JOIN `ba-775-a06.cc_datasets.1-details` AS B
# USING (unitid)
# WHERE A.grad_100_rate IS NOT NULL AND A.grad_150_rate IS NOT NULL AND A.gender <> 'B' AND B.grad_100_value IS NOT NULL AND B.grad_150_value IS NOT NULL AND B.state IN ('Rhode Island', 'Massachusetts', 'Pennsylvania') AND A.year IN (2002,2003,2004,2005,2006,2007)
# GROUP BY chronname
#
#
# UNION ALL
#
# SELECT chronname AS college_name, MAX(year) AS year, ROUND(AVG(A.grad_100_rate),2) AS avg_grad100_rate, ROUND(AVG(A.grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads` AS A
# LEFT JOIN `ba-775-a06.cc_datasets.1-details` AS B
# USING (unitid)
# WHERE A.grad_100_rate IS NOT NULL AND A.grad_150_rate IS NOT NULL AND A.gender <> 'B' AND B.grad_100_value IS NOT NULL AND B.grad_150_value IS NOT NULL AND B.state IN ('Rhode Island', 'Massachusetts', 'Pennsylvania') AND A.year IN (2008,2009,2010,2011,2012,2013)
# GROUP BY chronname
# )
# ORDER BY college_name, year, avg_grad100_rate DESC, avg_grad150_rate DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      college_name  year  avg_grad100_rate  avg_grad150_rate
# 0                Albright College  2002             48.82             57.60
# 1                Albright College  2013             49.46             55.64
# 2               Allegheny College  2002             49.21             58.41
# 3               Allegheny College  2013             57.39             66.59
# 4             Alvernia University  2002             32.68             45.40
# ..                            ...   ...               ...               ...
# 417       Worcester State College  2013             24.66             43.55
# 418  York College of Pennsylvania  2002             31.01             48.17
# 419  York College of Pennsylvania  2013             37.36             57.32
# 420            Zion Bible College  2002             28.75             33.57
# 421            Zion Bible College  2013             53.94             57.81
#
# [422 rows x 4 columns]

# %% [markdown]
# **Q5 ANSWER**
#
# Analyzing graduation rates from 2002 to 2013 provides a comprehensive view of nuanced trends within higher education. On the whole, there is a discernible positive trajectory, reflecting encouraging advancements in graduation outcomes. However, this overall picture conceals the intricate variations existing among different colleges. Notably, some institutions consistently boast high graduation rates, underlining their effectiveness in supporting student success, while others exhibit noticeable fluctuations, signaling potential challenges in maintaining steady progress. When delving deeper into the data, a compelling observation emerges—comparisons between smaller colleges and larger universities reveal distinctive patterns. Smaller institutions may experience more significant fluctuations, possibly due to their unique challenges and resource constraints. This underscores the importance of considering institutional size when evaluating and addressing graduation rate trends, allowing for targeted interventions that can enhance overall higher education outcomes.
#
# **Challenge**
#
# Due to the potential lengthiness and complexity of listing the annual graduation rate variations for each school from 2002 to 2013, we have narrowed down the analysis to focus on the top three states with the highest graduation rates. The selected approach involves dividing the 12-year period into two six-year segments for each school. The first six years are represented by the school's minimum graduation rate year, while the subsequent six years are represented by the school's maximum graduation rate year. This allows for a more concise yet insightful analysis of the average graduation rate changes within these top-ranking states.

# %% [markdown]
# Going further, we want to touch upon which states have the highest graduation rates each year within the dataset time frame - 2002 to 2013 and answer the following question -
#
# ###**5.2.6 Identifying States with Top Annual Graduation Rates.**

# %%
# %%bigquery --project $project_id
# WITH ranking_table AS (
# SELECT year, state, RANK() over(PARTITION BY year ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC) AS ranking, avg_grad100_rate, avg_grad150_rate
# FROM (
# SELECT state, year, ROUND(AVG(A.grad_100_rate),2) AS avg_grad100_rate, ROUND(AVG(A.grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads` AS A
# LEFT JOIN `ba-775-a06.cc_datasets.1-details` AS B
# USING (unitid)
# WHERE A.grad_100_rate IS NOT NULL AND A.grad_150_rate IS NOT NULL AND A.gender <> 'B' AND B.grad_100_value IS NOT NULL AND B.grad_150_value IS NOT NULL
# GROUP BY state, year
# ORDER BY state, year, avg_grad100_rate DESC, avg_grad150_rate DESC
# )
# ORDER BY year,ranking)
#
# SELECT year, state, avg_grad100_rate, avg_grad150_rate
# FROM ranking_table
# WHERE ranking = 1;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year                 state  avg_grad100_rate  avg_grad150_rate
# 0   2002          Rhode Island             48.56             64.46
# 1   2003  District of Columbia             45.00             57.37
# 2   2004         Massachusetts             41.57             56.52
# 3   2005          Rhode Island             47.81             62.93
# 4   2006  District of Columbia             44.27             54.37
# 5   2007          Rhode Island             55.58             69.54
# 6   2008          Rhode Island             49.94             62.39
# 7   2009          Rhode Island             53.19             65.99
# 8   2010          Rhode Island             50.39             63.99
# 9   2011          Rhode Island             52.30             67.30
# 10  2012          Rhode Island             52.39             66.79
# 11  2013          Rhode Island             51.07             63.61

# %% [markdown]
# **Insights:**
#
# When delving into the annual records of the states with the highest graduation rates, a pattern akin to the previous question becomes apparent.
#
# Specifically, from 2002 onward, Rhode Island almost consistently secured the top position, boasting the highest average graduation rate in most years. Throughout this period, the state consistently demonstrated graduation rates for both 100% and 150% of normal time, maintaining levels around 50% and 60%, respectively.
#
# Despite fluctuations in the state claiming the highest graduation rate each year, the graduation rates for the leading state in each year for both 100% and 150% of normal time exhibit a stable trend, persisting at approximately 50% and 60%, respectively.

# %% [markdown]
# Within the dataset's time frame, our goal is to delve deeper and identify colleges with the highest graduation rates each year, answering the follwing question -
#
# ###**5.2.7 Spotlight on Excellence: Colleges with Top Annual Graduation Rates.**

# %%
# %%bigquery --project $project_id
# WITH ranking_table AS (
# SELECT year, college_name, RANK() over(PARTITION BY year ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC) AS ranking, avg_grad100_rate, avg_grad150_rate
# FROM (
# SELECT chronname AS college_name, year, ROUND(AVG(A.grad_100_rate),2) AS avg_grad100_rate, ROUND(AVG(A.grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads` AS A
# LEFT JOIN `ba-775-a06.cc_datasets.1-details` AS B
# USING (unitid)
# WHERE A.grad_100_rate IS NOT NULL AND A.grad_150_rate IS NOT NULL AND A.gender <> 'B' AND B.grad_100_value IS NOT NULL AND B.grad_150_value IS NOT NULL
# GROUP BY chronname, year
# ORDER BY college_name, year, avg_grad100_rate DESC, avg_grad150_rate DESC
# )
# ORDER BY year,ranking)
#
# SELECT year, college_name, avg_grad100_rate, avg_grad150_rate
# FROM ranking_table
# WHERE ranking = 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year                         college_name  avg_grad100_rate  \
# 0   2002                        Texas College             100.0
# 1   2002  Central Christian College of Kansas             100.0
# 2   2002                  Divine Word College             100.0
# 3   2002                      Florida College             100.0
# 4   2002              Apex School of Theology             100.0
# ..   ...                                  ...               ...
# 83  2013                      Academy College             100.0
# 84  2013        Vatterott College - NorthPark             100.0
# 85  2013            Southwest Florida College             100.0
# 86  2013        Kaplan University - Urbandale             100.0
# 87  2013      Everest College - Ontario Metro             100.0
#
#     avg_grad150_rate
# 0              100.0
# 1              100.0
# 2              100.0
# 3              100.0
# 4              100.0
# ..               ...
# 83             100.0
# 84             100.0
# 85             100.0
# 86             100.0
# 87             100.0
#
# [88 rows x 4 columns]

# %% [markdown]
# **Insights:**
#
# The table data reveals a consistent trend in graduation rates for top-ranked colleges from 2002 to 2013, with each year's highest-ranked college achieving a perfect 100% graduation rate in both grad100 and grad150 categories. Noteworthy institutions such as Texas College, Central Christian College of Kansas, Divine Word College, and Florida College maintained this exceptional standard throughout the entire period, showcasing an unwavering commitment to flawless graduation rates.
#
# Beyond the early 2000s, the list of top-performing colleges includes Baker College of Jackson, Cox College, Fashion Institute of Design and Merchandising at Los Angeles, and ITT Technical Institute, all consistently achieving a 100% graduation rate. This underscores not only sustained excellence but also the adaptability and resilience of these institutions in upholding high educational standards.

# %% [markdown]
# Here, we want to dig a level into to see if these are public or private colleges, answering the follwing question -
#
# ###**5.2.8 Educational Systems with Highest Annual Graduation Rates.**

# %%
# %%bigquery --project $project_id
# WITH ranking_table AS (
# SELECT year, level,control,basic, RANK() over(PARTITION BY year ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC) AS ranking, avg_grad100_rate, avg_grad150_rate
# FROM (
# SELECT level,control,basic, year, ROUND(AVG(A.grad_100_rate),2) AS avg_grad100_rate, ROUND(AVG(A.grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads` AS A
# LEFT JOIN `ba-775-a06.cc_datasets.1-details` AS B
# USING (unitid)
# WHERE A.grad_100_rate IS NOT NULL AND A.grad_150_rate IS NOT NULL AND A.gender <> 'B' AND B.grad_100_value IS NOT NULL AND B.grad_150_value IS NOT NULL
# GROUP BY level,control,basic, year
# ORDER BY level,control,basic, year, avg_grad100_rate DESC, avg_grad150_rate DESC
# )
# ORDER BY year,ranking)
#
# SELECT year, level,control AS institution_category, basic AS college_type, avg_grad100_rate, avg_grad150_rate
# FROM ranking_table
# WHERE ranking = 1;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year   level    institution_category  \
# 0   2002  4-year  Private not-for-profit
# 1   2003  4-year  Private not-for-profit
# 2   2004  4-year  Private not-for-profit
# 3   2004  4-year  Private not-for-profit
# 4   2005  4-year  Private not-for-profit
# 5   2006  4-year  Private not-for-profit
# 6   2007  4-year  Private not-for-profit
# 7   2008  4-year  Private not-for-profit
# 8   2009  4-year  Private not-for-profit
# 9   2010  4-year  Private not-for-profit
# 10  2011  4-year  Private not-for-profit
# 11  2012  4-year  Private not-for-profit
# 12  2013  4-year  Private not-for-profit
#
#                                          college_type  avg_grad100_rate  \
# 0   Research Universities--very high research acti...             69.33
# 1                                      Schools of law            100.00
# 2                    Other special-focus institutions            100.00
# 3                    Other technology-related schools            100.00
# 4                    Other special-focus institutions            100.00
# 5   Research Universities--very high research acti...             74.23
# 6   Research Universities--very high research acti...             76.34
# 7   Research Universities--very high research acti...             76.97
# 8   Research Universities--very high research acti...             75.69
# 9                                      Schools of law            100.00
# 10                                     Schools of law             87.50
# 11  Research Universities--very high research acti...             76.58
# 12  Research Universities--very high research acti...             77.84
#
#     avg_grad150_rate
# 0              84.15
# 1             100.00
# 2             100.00
# 3             100.00
# 4             100.00
# 5              86.32
# 6              86.57
# 7              87.11
# 8              86.65
# 9             100.00
# 10             87.50
# 11             87.62
# 12             87.81

# %% [markdown]
# **Insights:**
#
# The table here gives an inference of various colleges performance and their repective institution_category and their level outperforming each year from 2002 till 2013.
# From 2002 	Research Universities--very high research activity type of college has rates as 69.33 and 84.15 for each.
#
# The Private not for Profit institution category outperforms other institutions interms of grad100 rate and grad150 rate from 2003 till 2005 with 100 rates for each.Then from 2006 onwards there is a decline in the rates which catches up again in 2010 but again from 2011 there is a decline trend been there.Overall there is an increase compared to 2002 quality compared to 2013.In the years between there had been a decline,Private not for Profit institutions needs to focus on improving quality of education and providing developement for all students helping them graduate.

# %% [markdown]
# Zooming out to see the graduation rates across the regions, answering the following question -
#
# ###**5.2.9 Exploring Regions with the Highest Graduation Rates**

# %%
# %%bigquery --project $project_id
# SELECT region, COUNT(region) AS instance_count, ROUND(AVG(grad_100_value),2) AS avg_grad100_rate, ROUND(AVG(grad_150_value),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE grad_100_value IS NOT NULL AND grad_100_value IS NOT NULL
# GROUP BY region
# ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       region  instance_count  avg_grad100_rate  avg_grad150_rate
# 0      Other              11             39.74             50.01
# 1  Northeast             700             37.28             50.68
# 2    Midwest             865             28.73             42.08
# 3  Southeast             958             25.88             38.85
# 4       West             606             25.70             42.19
# 5  Southwest             327             20.16             36.15

# %% [markdown]
# **Insights:**
#
# Southeast region in the US has maximum education institutes ,can be inferred to be one of the topmost education hub in the US,followed by Midwest,then Northeast,then West and  then South West.The reason to exclude Other here is that it has a state called US which comes under the category different from all regions.
#
# The grad100 rate in Other is higher compared to other regions.Also grad150 rate is maximum in the Northeast region.
#
# **Trend**
#
# The Northeast region had the highest graduation rates of  grad100 rate 37.28 after Others category and 50.68 for grad150 rate, respectively, indicating an overall successful completion of the program.
# The Midwest and Western regions also show competitive graduation rates.
# Completion rates are low in the Southeast and Southwest regions, indicating potential challenges in completing the program.

# %% [markdown]
# Delving deeply into the categories of institutions across the regions, answering the following question -
#
# ###**5.2.10 Identifying High Achievers: Graduation Rates in Various Institution Categories Across Regions**

# %%
# %%bigquery --project $project_id
# SELECT
#   region,
#   control AS institution_category,
#   COUNT(*) AS instance_count,
#   ROUND(AVG(grad_100_value),2) AS avg_grad100_rate,
#   ROUND(AVG(grad_150_value),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.1-details`
# GROUP BY region, control
# ORDER BY avg_grad100_rate DESC, avg_grad150_rate DESC
# LIMIT 15;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        region    institution_category  instance_count  avg_grad100_rate  \
# 0       Other  Private not-for-profit               8             51.65
# 1   Northeast  Private not-for-profit             364             48.29
# 2        West  Private not-for-profit             145             44.50
# 3     Midwest  Private not-for-profit             351             39.69
# 4   Southeast  Private not-for-profit             312             36.57
# 5   Northeast      Private for-profit             124             36.52
# 6   Southwest  Private not-for-profit              68             32.00
# 7   Southeast      Private for-profit             285             28.23
# 8     Midwest      Private for-profit             241             28.16
# 9        West      Private for-profit             218             27.94
# 10  Southwest      Private for-profit             121             26.98
# 11  Northeast                  Public             244             21.84
# 12    Midwest                  Public             372             18.96
# 13  Southeast                  Public             462             17.28
# 14       West                  Public             302             15.25
#
#     avg_grad150_rate
# 0              64.44
# 1              60.15
# 2              56.91
# 3              52.67
# 4              48.13
# 5              50.58
# 6              46.08
# 7              42.42
# 8              40.30
# 9              47.15
# 10             51.96
# 11             37.15
# 12             33.21
# 13             30.56
# 14             32.00

# %% [markdown]
# **Q10 ANSWER**
#
# Private nonprofits in the Northeast region of the United States exhibit the best graduation rates compared to other regions. Also, at every level, private and nonprofit organizations consistently outperform both public and private for-profit universities. These examples suggest that there may be unique strategies or factors that contribute to the success of individuals and nonprofit organizations.
#
#
# That means public and private universities elsewhere could benefit from trying and adopting some of the practices used by successful private nonprofit organizations. Focusing on improving the quality of education, implementing effective student support services, and adopting strategies that help increase graduation rates can be particularly beneficial,improving education and support services, ultimately resulting in better student outcomes

# %% [markdown]
# Finally, delving into the correlation between different SAT score groups and their average graduation rates over the years, answering the following question -
#
# ###**5.2.11 Exploring the Correlation**
#
# **Aim:**
#
# Examine the correlation between different SAT score groups and their average graduation rates over multiple years.

# %%
# %%bigquery --project $project_id
# SELECT
#   CASE
#   WHEN med_sat_value BETWEEN 1350 AND 1600 THEN 'High_SAT_Score'
#    WHEN med_sat_value BETWEEN 1200 AND 1350 THEN 'Higher_Median_SAT_Score'
#    WHEN med_sat_value BETWEEN 1050 AND 1200 THEN 'Lower_Median_SAT_Score'
#    WHEN med_sat_value BETWEEN 0 AND 1050 THEN 'Low_SAT_Score'
#    END AS sat, A.year,ROUND(AVG(A.grad_100_rate),2) AS avg_grad100_rate,
#    ROUND(AVG(A.grad_150_rate),2) AS avg_grad150_rate
# FROM `ba-775-a06.cc_datasets.2-grads` AS A
# LEFT JOIN `ba-775-a06.cc_datasets.1-details` AS B
# USING (unitid)
# WHERE B.med_sat_value IS NOT NULL AND A.grad_100_rate IS NOT NULL AND A.grad_150_rate IS NOT NULL
# GROUP BY sat,year
# ORDER BY CASE
#     WHEN sat = 'High_SAT_Score' THEN 1
#     WHEN sat = 'Higher_Median_SAT_Score' THEN 2
#     WHEN sat = 'Lower_Median_SAT_Score' THEN 3
#     WHEN sat = 'Low_SAT_Score' THEN 4
#   END,year
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                         sat  year  avg_grad100_rate  avg_grad150_rate
# 0            High_SAT_Score  2002             67.50             83.13
# 1            High_SAT_Score  2003             71.60             84.38
# 2            High_SAT_Score  2004             71.38             84.39
# 3            High_SAT_Score  2005             71.88             85.92
# 4            High_SAT_Score  2006             72.46             86.64
# 5            High_SAT_Score  2007             75.56             86.38
# 6            High_SAT_Score  2008             75.07             87.07
# 7            High_SAT_Score  2009             74.41             86.96
# 8            High_SAT_Score  2010             77.53             88.83
# 9            High_SAT_Score  2011             76.27             88.10
# 10           High_SAT_Score  2012             76.97             88.32
# 11           High_SAT_Score  2013             77.75             88.17
# 12  Higher_Median_SAT_Score  2002             49.37             66.54
# 13  Higher_Median_SAT_Score  2003             49.16             67.80
# 14  Higher_Median_SAT_Score  2004             50.20             68.34
# 15  Higher_Median_SAT_Score  2005             52.09             70.00
# 16  Higher_Median_SAT_Score  2006             52.23             71.15
# 17  Higher_Median_SAT_Score  2007             53.56             71.28
# 18  Higher_Median_SAT_Score  2008             54.16             71.50
# 19  Higher_Median_SAT_Score  2009             56.36             74.21
# 20  Higher_Median_SAT_Score  2010             57.59             73.77
# 21  Higher_Median_SAT_Score  2011             57.91             73.85
# 22  Higher_Median_SAT_Score  2012             58.09             74.46
# 23  Higher_Median_SAT_Score  2013             59.21             74.71
# 24   Lower_Median_SAT_Score  2002             32.30             50.39
# 25   Lower_Median_SAT_Score  2003             33.02             51.23
# 26   Lower_Median_SAT_Score  2004             33.01             51.29
# 27   Lower_Median_SAT_Score  2005             33.38             52.07
# 28   Lower_Median_SAT_Score  2006             33.94             52.68
# 29   Lower_Median_SAT_Score  2007             34.75             52.85
# 30   Lower_Median_SAT_Score  2008             35.15             53.32
# 31   Lower_Median_SAT_Score  2009             35.37             53.98
# 32   Lower_Median_SAT_Score  2010             36.73             54.03
# 33   Lower_Median_SAT_Score  2011             37.39             54.64
# 34   Lower_Median_SAT_Score  2012             38.02             55.49
# 35   Lower_Median_SAT_Score  2013             38.26             55.61
# 36            Low_SAT_Score  2002             21.01             37.94
# 37            Low_SAT_Score  2003             20.32             37.33
# 38            Low_SAT_Score  2004             20.82             37.66
# 39            Low_SAT_Score  2005             21.37             38.33
# 40            Low_SAT_Score  2006             21.25             38.10
# 41            Low_SAT_Score  2007             22.28             38.89
# 42            Low_SAT_Score  2008             22.27             39.32
# 43            Low_SAT_Score  2009             21.39             38.67
# 44            Low_SAT_Score  2010             22.91             39.57
# 45            Low_SAT_Score  2011             22.54             39.18
# 46            Low_SAT_Score  2012             22.33             39.22
# 47            Low_SAT_Score  2013             22.89             39.69

# %% [markdown]
# **Insights:**
#
# The analysis uncovers a noticeable upward trend in graduation rates over the years. Additionally, a significant correlation emerges between Median SAT scores and graduation rates, indicating that higher SAT score groups consistently achieve better graduation outcomes. This finding implies a positive association between academic preparedness, as gauged by SAT scores, and successful program completion throughout the examined time frame.

# %% [markdown]
# ##**Graduation Rates Summary**
#
# **Academic Journeys: Unearthing Graduation Trends and Disparities Across U.S. Higher Education Institutions**
#
# This detailed analysis of graduation rates and educational trends in the United States unveils intriguing patterns. Rhode Island consistently leads in graduation rates, while private nonprofits in the Northeast, particularly in New York, outperform other regions with an average graduation rate of 50.68%, compared to the Southwest's 36.15%.
#
# Institutional categories reveal a significant trend, with 2-year private for-profit and 4-year private not-for-profit institutions consistently maintaining graduation rates around 80%, surpassing other categories. The temporal trend analysis from 2002 to 2013 indicates stability in graduation rate patterns.
#
# Insights from top-performing colleges underscore a commitment to excellence. Geographically, New York leads in the number of 4-year colleges (172), while California takes the lead for 2-year colleges with 180 institutions, emphasizing diverse educational landscapes.
#
# From an academic perspective, higher SAT score groups consistently achieve better graduation outcomes, suggesting a positive relationship between academic preparedness and program completion.
#
# This upward trend in graduation rates over the years aligns with a significant correlation between Median SAT scores and graduation rates, implying a positive association between academic preparedness and successful program completion.
#
# These insights offer valuable guidance for institutions and policymakers, emphasizing the need for specific strategies to enhance graduation rates and contribute to better outcomes for students nationwide.

# %% [markdown]
# ##**5.3 Cultural Factors - Diversity**

# %% [markdown]
# As we delve deeper into the intricate landscape of graduation rates and their profound significance for both individual students and the broader standing of universities, it becomes essential to unravel the classification criteria applied to these academic institutions. This exploration gains particular relevance as each student harbors aspirations of attending their dream university, often intertwined with specific goals and ambitions. Within the dataset, two intriguing columns, 'hbcu' and 'flagship,' initially seemed to suggest an exclusive tier of highly competitive universities. However, a closer analysis unveils a more nuanced reality. 'Hbcu' likely denotes Historically Black Colleges and Universities, institutions with a legacy of serving predominantly African American student populations. Conversely, the 'flagship' designation may signify a university's primary and most prominent campus within a broader university system. Contrary to initial assumptions of exclusivity, these classifications encompass a diverse range of institutions, each contributing uniquely to the educational landscape. This insight underscores the importance of moving beyond surface-level interpretations and understanding the specific attributes that define and differentiate universities, shaping the academic journey for aspiring students navigating the intricacies of higher education.

# %% [markdown]
# Starting off with understanding the distrivution of HBCUs across the states and answering the following question -
#
# ###**5.3.1 Identifying States with the Greatest Presence of Historically Black Colleges and Universities**

# %%
# %%bigquery --project $project_id
# SELECT
#   state,
#   COUNTIF(hbcu = 'X') AS hbcu_count,
#   COUNTIF(flagship = 'X') AS flagship_count,
#   STRING_AGG(CASE WHEN hbcu = 'X' THEN chronname END, ', ') AS hbcu_university_names,
#   STRING_AGG(CASE WHEN flagship = 'X' THEN chronname END, ', ') AS flagship_university_names,
#   RANK() OVER (ORDER BY COUNTIF(hbcu = 'X') DESC) AS hbcu_rank
# FROM `ba-775-a06.cc_datasets.1-details`
# GROUP BY state
# ORDER BY hbcu_count DESC
# LIMIT 10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             state  hbcu_count  flagship_count  \
# 0         Alabama          15               1
# 1  North Carolina          10               1
# 2           Texas           9               1
# 3  South Carolina           8               1
# 4         Georgia           7               1
# 5       Louisiana           6               1
# 6     Mississippi           6               1
# 7        Virginia           5               1
# 8         Florida           4               1
# 9        Maryland           4               1
#
#                                hbcu_university_names  \
# 0  Alabama A&M University, Tuskegee University, S...
# 1  Elizabeth City State University, North Carolin...
# 2  Prairie View A&M University, Texas Southern Un...
# 3  Allen University, Benedict College, Claflin Un...
# 4  Spelman College, Clark Atlanta University, Pai...
# 5  Grambling State University, Southern Universit...
# 6  Jackson State University, Mississippi Valley S...
# 7  Norfolk State University, Virginia State Unive...
# 8  Florida A&M University, Bethune-Cookman Univer...
# 9  Bowie State University, University of Maryland...
#
#                      flagship_university_names  hbcu_rank
# 0          University of Alabama at Tuscaloosa          1
# 1  University of North Carolina at Chapel Hill          2
# 2                University of Texas at Austin          3
# 3     University of South Carolina at Columbia          4
# 4                        University of Georgia          5
# 5    Louisiana State University at Baton Rouge          6
# 6                    University of Mississippi          6
# 7                       University of Virginia          8
# 8                        University of Florida          9
# 9       University of Maryland at College Park          9

# %% [markdown]
# **Insights:**
#
# The aforementioned findings provide valuable insights that prompt a deeper exploration of these university categories. Despite California boasting the highest number of colleges at 350, Alabama takes the lead in the number of Historically Black Colleges and Universities (HBCUs), with 15 institutions. Noteworthy is the observation that, while each state may host multiple HBCU universities, only one flagship university is designated per state (with the District of Columbia being a unique exception with zero flagship universities). Further investigation into the characteristics defining flagship status reveals that these institutions are typically the oldest public universities and receive the highest levels of government funding.
#
# However, it becomes evident that despite holding flagship status, these universities don't necessarily align with the likes of Harvard, Stanford, or MIT. This raises the crucial question: What sets these flagship universities apart from the rest, beyond their public university status?
#
# In pursuit of a comprehensive answer, we delved into three key dimensions: awards, SAT scores, and graduation rates, aiming to discern the distinctive attributes of these institutions in comparison to others. By scrutinizing these facets, we aim to unravel the unique qualities that contribute to the prominence of flagship universities, transcending their public university classification.

# %% [markdown]
# We now want to see if median SAT scores of a floagship university stand-out and answer the following question -
#
# ###**5.3.2 Comparison between SAT scores and Flagship Colleges**

# %%
# %%bigquery --project $project_id
# WITH CollegeRanks AS (
#    SELECT
#        state,
#        chronname,
#        med_sat_value,
#        RANK() OVER (PARTITION BY state ORDER BY med_sat_value DESC) AS sat_rank
#    FROM
#        `ba-775-a06.cc_datasets.1-details`
#    WHERE
#        med_sat_value IS NOT NULL  -- Exclude NULL values if necessary
# )
#
#
# SELECT
#    t.state,
#    t.chronname AS flagship_college,
#    t.med_sat_value AS flagship_sat_value,
#    r.chronname AS college_with_highest_sat,
#    r.med_sat_value AS highest_sat_value
# FROM
#    `ba-775-a06.cc_datasets.1-details` t
# JOIN
#    CollegeRanks r ON t.state = r.state AND r.sat_rank = 1
# WHERE
#    t.flagship = 'X'  -- Filter for flagship colleges
#    AND t.med_sat_value IS NOT NULL
# ORDER BY
#    flagship_sat_value DESC,t.state, t.chronname;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              state                                  flagship_college  \
# 0         Virginia                            University of Virginia
# 1         Michigan               University of Michigan at Ann Arbor
# 2       California              University of California at Berkeley
# 3   North Carolina       University of North Carolina at Chapel Hill
# 4         Maryland            University of Maryland at College Park
# 5         Illinois        University of Illinois at Urbana-Champaign
# 6             Ohio                             Ohio State University
# 7          Florida                             University of Florida
# 8        Minnesota               University of Minnesota-Twin Cities
# 9        Wisconsin                University of Wisconsin at Madison
# 10           Texas                     University of Texas at Austin
# 11         Georgia                             University of Georgia
# 12      Washington                          University of Washington
# 13     Connecticut                         University of Connecticut
# 14      New Jersey               Rutgers University at New Brunswick
# 15   Massachusetts            University of Massachusetts at Amherst
# 16            Iowa                                University of Iowa
# 17  South Carolina          University of South Carolina at Columbia
# 18    Pennsylvania  Pennsylvania State University at University Park
# 19    Pennsylvania  Pennsylvania State University at University Park
# 20       Tennessee              University of Tennessee at Knoxville
# 21         Indiana                 Indiana University at Bloomington
# 22        Colorado                 University of Colorado at Boulder
# 23         Vermont                             University of Vermont
# 24        Delaware                            University of Delaware
# 25        Oklahoma                  University of Oklahoma at Norman
# 26         Alabama               University of Alabama at Tuscaloosa
# 27        Missouri                University of Missouri at Columbia
# 28       Louisiana         Louisiana State University at Baton Rouge
# 29        New York                             University at Buffalo
# 30        Arkansas            University of Arkansas at Fayetteville
# 31        Nebraska                 University of Nebraska at Lincoln
# 32          Kansas                              University of Kansas
# 33          Kansas                              University of Kansas
# 34        Kentucky                            University of Kentucky
# 35         Wyoming                             University of Wyoming
# 36            Utah                                University of Utah
# 37          Oregon                              University of Oregon
# 38         Arizona                             University of Arizona
# 39     Mississippi                         University of Mississippi
# 40         Montana                 University of Montana at Missoula
# 41         Montana                 University of Montana at Missoula
# 42    North Dakota                        University of North Dakota
# 43          Hawaii                        University of Hawaii-Manoa
# 44           Maine                               University of Maine
# 45          Nevada                      University of Nevada at Reno
# 46    Rhode Island                        University of Rhode Island
# 47           Idaho                               University of Idaho
# 48   West Virginia                          West Virginia University
# 49      New Mexico                          University of New Mexico
#
#     flagship_sat_value                          college_with_highest_sat  \
# 0               1362.0                     Washington and Lee University
# 1               1352.0               University of Michigan at Ann Arbor
# 2               1350.0                California Institute of Technology
# 3               1313.0                                   Duke University
# 4               1310.0                          Johns Hopkins University
# 5               1303.0                             University of Chicago
# 6               1289.0                   Case Western Reserve University
# 7               1272.0                               University of Miami
# 8               1270.0                                  Carleton College
# 9               1268.0                University of Wisconsin at Madison
# 10              1262.0                                   Rice University
# 11              1247.0                                  Emory University
# 12              1234.0                                   Whitman College
# 13              1233.0                                   Yale University
# 14              1210.0                              Princeton University
# 15              1209.0             Massachusetts Institute of Technology
# 16              1208.0                                  Grinnell College
# 17              1200.0                                Clemson University
# 18              1199.0                        University of Pennsylvania
# 19              1199.0                                Swarthmore College
# 20              1199.0                             Vanderbilt University
# 21              1198.0                          University of Notre Dame
# 22              1192.0                                  Colorado College
# 23              1190.0                                Middlebury College
# 24              1178.0                            University of Delaware
# 25              1176.0                               University of Tulsa
# 26              1171.0                                 Auburn University
# 27              1165.0                Washington University in St. Louis
# 28              1162.0                                 Tulane University
# 29              1158.0                               Columbia University
# 30              1156.0                                   Hendrix College
# 31              1147.0                              Creighton University
# 32              1145.0                              University of Kansas
# 33              1145.0                               Benedictine College
# 34              1140.0                                    Centre College
# 35              1123.0                             University of Wyoming
# 36              1109.0                          Brigham Young University
# 37              1108.0                                      Reed College
# 38              1106.0  Embry-Riddle Aeronautical University at Prescott
# 39              1100.0                                  Millsaps College
# 40              1090.0               Montana State University at Bozeman
# 41              1090.0         Montana Tech of the University of Montana
# 42              1090.0                     North Dakota State University
# 43              1087.0                        University of Hawaii-Manoa
# 44              1085.0                                   Bowdoin College
# 45              1081.0                      University of Nevada at Reno
# 46              1076.0                                  Brown University
# 47              1070.0                     Northwest Nazarene University
# 48              1062.0                          West Virginia University
# 49              1038.0     New Mexico Institute of Mining and Technology
#
#     highest_sat_value
# 0              1392.0
# 1              1352.0
# 2              1534.0
# 3              1444.0
# 4              1418.0
# 5              1504.0
# 6              1377.0
# 7              1332.0
# 8              1406.0
# 9              1268.0
# 10             1454.0
# 11             1363.0
# 12             1327.0
# 13             1497.0
# 14             1495.0
# 15             1503.0
# 16             1357.0
# 17             1259.0
# 18             1442.0
# 19             1442.0
# 20             1475.0
# 21             1450.0
# 22             1323.0
# 23             1391.0
# 24             1178.0
# 25             1279.0
# 26             1215.0
# 27             1474.0
# 28             1341.0
# 29             1471.0
# 30             1267.0
# 31             1214.0
# 32             1145.0
# 33             1145.0
# 34             1268.0
# 35             1123.0
# 36             1277.0
# 37             1371.0
# 38             1171.0
# 39             1159.0
# 40             1115.0
# 41             1115.0
# 42             1091.0
# 43             1087.0
# 44             1423.0
# 45             1081.0
# 46             1425.0
# 47             1079.0
# 48             1062.0
# 49             1200.0

# %% [markdown]
# **Insights:**
#
# The obtained results shed light on an intriguing aspect: the SAT score does not necessarily serve as a definitive indicator for a university to be classified as a flagship institution. A compelling case for comparison is the state of Massachusetts, where the flagship university, UMASS Amherst, boasts a SAT score of 1209. In contrast, the highest-ranking college in the state, the Massachusetts Institute of Technology (MIT), significantly surpasses this score with an impressive 1503. This disparity challenges the assumption that a high SAT score is a requisite criterion for a university to attain flagship status. It underscores the complexity of factors influencing such classifications, urging a more nuanced examination beyond standardized test scores to truly discern the distinctive qualities that contribute to a university being designated as a flagship institution.

# %% [markdown]
# So far SAT score did not come out to be the unique indicator for the flagship universities, we'll now look upon the average awards with respect to other colleges and flagship universties in the state, answering the following question -
#
# ###**5.3.3 Comparison between Awards and Flagship Colleges**

# %%
# %%bigquery --project $project_id
#
# WITH FlagshipComparison AS (
#     SELECT
#         state,
#         AVG(CASE WHEN flagship = 'X' THEN awards_per_value END) AS flagship_awards
#     FROM
#         `ba-775-a06.cc_datasets.1-details`
#     WHERE
#         awards_per_value IS NOT NULL
#     GROUP BY
#         state
# )
#
# SELECT
#     t.state,
#     AVG(t.awards_per_value) AS avg_awards_all_colleges,
#     fc.flagship_awards AS awards_flagship,
#     fc.flagship_awards - AVG(t.awards_per_value) AS awards_difference
# FROM
#     `ba-775-a06.cc_datasets.1-details` t
# JOIN
#     FlagshipComparison fc ON t.state = fc.state
# WHERE
#     t.awards_per_value IS NOT NULL AND fc.flagship_awards IS NOT NULL
# GROUP BY
#     t.state, fc.flagship_awards
# ORDER BY
#     awards_flagship DESC, t.state;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              state  avg_awards_all_colleges  awards_flagship  \
# 0      Connecticut                19.734286             27.9
# 1       California                22.771429             27.6
# 2          Florida                26.992614             27.6
# 3          Georgia                21.112264             27.3
# 4     Pennsylvania                25.163594             27.2
# 5         Maryland                22.371154             27.0
# 6       Washington                24.993151             26.3
# 7   North Carolina                19.250370             25.2
# 8            Texas                23.627053             25.2
# 9         Michigan                22.386170             24.1
# 10        Virginia                23.659615             23.8
# 11       Wisconsin                23.542254             23.6
# 12   Massachusetts                23.239000             23.5
# 13            Ohio                23.692973             23.3
# 14         Indiana                24.464179             23.1
# 15            Utah                26.853333             23.0
# 16          Hawaii                20.627778             22.8
# 17         Vermont                24.455000             22.8
# 18        Colorado                24.822857             22.6
# 19        Missouri                26.739806             22.4
# 20       Tennessee                25.184043             22.4
# 21        Illinois                22.470922             22.3
# 22          Kansas                25.388710             22.3
# 23        Delaware                20.254545             22.0
# 24        New York                23.519917             21.8
# 25            Iowa                25.536066             21.7
# 26           Maine                23.575862             21.6
# 27    South Dakota                22.117391             21.6
# 28          Oregon                23.854000             21.4
# 29         Arizona                25.563492             21.3
# 30        Oklahoma                23.700000             21.3
# 31         Wyoming                22.866667             21.3
# 32   New Hampshire                23.679167             21.1
# 33       Minnesota                25.940594             21.0
# 34        Nebraska                23.158333             20.7
# 35    Rhode Island                23.390909             20.6
# 36      New Jersey                19.850909             20.4
# 37  South Carolina                19.092424             20.4
# 38          Nevada                21.805000             20.0
# 39        Kentucky                24.002985             19.6
# 40       Louisiana                23.921429             19.5
# 41         Montana                19.336364             19.5
# 42           Idaho                23.912500             19.3
# 43         Alabama                19.514493             18.3
# 44     Mississippi                23.180556             18.3
# 45   West Virginia                24.448718             17.9
# 46      New Mexico                19.085000             17.8
# 47        Arkansas                21.970833             17.4
# 48    North Dakota                22.495000             16.7
# 49          Alaska                18.414286             16.6
#
#     awards_difference
# 0            8.165714
# 1            4.828571
# 2            0.607386
# 3            6.187736
# 4            2.036406
# 5            4.628846
# 6            1.306849
# 7            5.949630
# 8            1.572947
# 9            1.713830
# 10           0.140385
# 11           0.057746
# 12           0.261000
# 13          -0.392973
# 14          -1.364179
# 15          -3.853333
# 16           2.172222
# 17          -1.655000
# 18          -2.222857
# 19          -4.339806
# 20          -2.784043
# 21          -0.170922
# 22          -3.088710
# 23           1.745455
# 24          -1.719917
# 25          -3.836066
# 26          -1.975862
# 27          -0.517391
# 28          -2.454000
# 29          -4.263492
# 30          -2.400000
# 31          -1.566667
# 32          -2.579167
# 33          -4.940594
# 34          -2.458333
# 35          -2.790909
# 36           0.549091
# 37           1.307576
# 38          -1.805000
# 39          -4.402985
# 40          -4.421429
# 41           0.163636
# 42          -4.612500
# 43          -1.214493
# 44          -4.880556
# 45          -6.548718
# 46          -1.285000
# 47          -4.570833
# 48          -5.795000
# 49          -1.814286

# %% [markdown]
# **Insights**
#
# The table reveals a discernible pattern that could offer valuable insights in favor of flagship universities over others. Surprisingly, the awards value for the flagship university exceeded the average awards value across the state. This observation is inherently explanatory, considering that flagship universities are among the oldest and are typically state run public institutions.

# %% [markdown]
# Here, we want to see the graduation values of the flagship colleges as opposed to the lot, answering the following question -
#
# ###**5.3.4 Comparison between Graduation Values and Flagship Colleges**

# %%
# %%bigquery --project $project_id
#
# WITH FlagshipComparison AS (
#     SELECT
#         state,
#         AVG(CASE WHEN flagship = 'X' AND grad_100_value IS NOT NULL THEN grad_100_value END) AS grad_100_flagship,
#         AVG(CASE WHEN flagship <> 'X' AND grad_100_value IS NOT NULL THEN grad_100_value END) AS avg_grad_100_other
#     FROM
#         `ba-775-a06.cc_datasets.1-details`
#     WHERE grad_100_value IS NOT NULL
#     GROUP BY
#         state
# )
#
# SELECT
#     t.state,
#     AVG(t.grad_100_value) AS avg_grad_100_all_colleges,
#     fc.grad_100_flagship,
#
# FROM
#     `ba-775-a06.cc_datasets.1-details` t
# JOIN
#     FlagshipComparison fc ON t.state = fc.state
# WHERE grad_100_flagship IS NOT NULL AND grad_100_flagship IS NOT NULL
# GROUP BY
#     t.state, fc.grad_100_flagship
# ORDER BY
#     fc.grad_100_flagship DESC, t.state;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              state  avg_grad_100_all_colleges  grad_100_flagship
# 0         Virginia                  32.304124               86.3
# 1   North Carolina                  23.682677               80.6
# 2         Michigan                  17.068605               75.8
# 3       California                  26.290625               72.2
# 4         Delaware                  32.990000               68.4
# 5         Illinois                  28.927273               68.4
# 6      Connecticut                  31.545455               68.3
# 7         Maryland                  24.435294               65.7
# 8          Florida                  33.548855               65.2
# 9          Vermont                  35.178947               64.8
# 10    Pennsylvania                  42.365421               64.6
# 11   New Hampshire                  34.595833               63.7
# 12   Massachusetts                  43.308511               58.7
# 13            Ohio                  27.250318               58.5
# 14         Indiana                  31.742188               58.3
# 15      Washington                  29.579032               57.5
# 16      New Jersey                  28.172222               57.1
# 17         Georgia                  22.331959               56.8
# 18       Wisconsin                  31.226316               55.0
# 19       Minnesota                  30.670652               54.5
# 20  South Carolina                  26.532258               54.2
# 21        New York                  33.258482               51.6
# 22           Texas                  21.308696               50.9
# 23            Iowa                  36.181481               47.5
# 24        Missouri                  32.656842               47.1
# 25        Colorado                  28.401538               44.3
# 26          Oregon                  25.044898               43.6
# 27         Alabama                  16.809091               42.7
# 28    Rhode Island                  53.000000               41.3
# 29         Arizona                  20.275926               39.9
# 30       Louisiana                  24.712963               37.9
# 31       Tennessee                  28.523256               36.8
# 32        Arkansas                  18.993617               36.7
# 33     Mississippi                  22.768571               36.4
# 34          Kansas                  30.798182               35.8
# 35           Maine                  32.660714               35.7
# 36        Oklahoma                  22.521154               34.8
# 37        Kentucky                  22.887719               33.7
# 38   West Virginia                  25.726316               33.7
# 39        Nebraska                  28.602941               32.3
# 40    South Dakota                  24.118182               30.2
# 41           Idaho                  17.586667               24.9
# 42    North Dakota                  23.429412               24.1
# 43         Wyoming                  26.544444               24.1
# 44            Utah                  27.412500               24.0
# 45         Montana                  17.754545               23.9
# 46          Hawaii                  14.731250               18.6
# 47          Nevada                  19.711765               15.7
# 48      New Mexico                  10.943243               14.6
# 49          Alaska                  19.242857               14.1

# %% [markdown]
# **Insights**
#
# Regarding the graduation rates for the flagship university, it mirrors the same trend as observed with awards. The graduation rates significantly surpassed the average rates across the state. This observation is inherently explanatory, given that flagship universities are among the oldest and are typically public institutions.

# %%
# %%bigquery --project $project_id
#
# SELECT
#     state,
#     SUM(grad_cohort)/ 98028280 * 100 AS total_grads
# FROM `ba-775-a06.cc_datasets.merged_table`
# GROUP BY state
# ORDER BY total_grads DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state  total_grads
# 0             California     9.433478
# 1               New York     7.401980
# 2                  Texas     6.737562
# 3           Pennsylvania     5.308476
# 4                Florida     4.833772
# 5                   Ohio     4.063566
# 6               Illinois     3.759350
# 7               Michigan     3.172876
# 8         North Carolina     2.890370
# 9          Massachusetts     2.755972
# 10              Virginia     2.581202
# 11               Arizona     2.514507
# 12               Georgia     2.423325
# 13               Indiana     2.372201
# 14            New Jersey     2.248031
# 15             Minnesota     2.149629
# 16             Wisconsin     2.145014
# 17             Tennessee     2.130477
# 18              Missouri     2.031346
# 19               Alabama     1.771130
# 20             Louisiana     1.688762
# 21              Colorado     1.658199
# 22              Maryland     1.558293
# 23        South Carolina     1.536444
# 24            Washington     1.500055
# 25                  Iowa     1.494675
# 26              Kentucky     1.488581
# 27                  None     1.458049
# 28              Oklahoma     1.396505
# 29           Mississippi     1.356456
# 30                Kansas     1.131833
# 31                Oregon     1.043379
# 32              Arkansas     1.000542
# 33           Connecticut     0.992644
# 34                  Utah     0.781340
# 35              Nebraska     0.768578
# 36         West Virginia     0.732558
# 37            New Mexico     0.659236
# 38          Rhode Island     0.596089
# 39         New Hampshire     0.480286
# 40                 Idaho     0.448391
# 41                 Maine     0.429013
# 42                Nevada     0.392909
# 43          South Dakota     0.361320
# 44          North Dakota     0.357030
# 45  District of Columbia     0.353614
# 46               Montana     0.334695
# 47              Delaware     0.324700
# 48                Hawaii     0.292862
# 49               Vermont     0.291738
# 50               Wyoming     0.272752
# 51                Alaska     0.094208

# %% [markdown]
# Next, we want to see the distribution of the students based on the race to have last peek at this stage at the diversity angle, answering the question -
#
# ###**5.3.5 Spread of students according to their race across the states**

# %%
# %%bigquery --project $project_id
#
# SELECT
#     state,
#     ROUND((SUM(CASE WHEN race = 'X' THEN grad_cohort ELSE 0 END) / SUM(grad_cohort)) * 100, 2) AS race_X_percentage,
#     ROUND((SUM(CASE WHEN race = 'W' THEN grad_cohort ELSE 0 END) / SUM(grad_cohort)) * 100, 2) AS race_W_percentage,
#     ROUND((SUM(CASE WHEN race = 'B' THEN grad_cohort ELSE 0 END) / SUM(grad_cohort)) * 100, 2) AS race_B_percentage,
#     ROUND((SUM(CASE WHEN race = 'H' THEN grad_cohort ELSE 0 END) / SUM(grad_cohort)) * 100, 2) AS race_H_percentage,
#     ROUND((SUM(CASE WHEN race = 'Ai' THEN grad_cohort ELSE 0 END) / SUM(grad_cohort)) * 100, 2) AS race_Ai_percentage,
#     ROUND((SUM(CASE WHEN race = 'A' THEN grad_cohort ELSE 0 END) / SUM(grad_cohort)) * 100, 2) AS race_A_percentage
# FROM `ba-775-a06.cc_datasets.merged_table`
# WHERE year = 2013
# GROUP BY state
# ORDER BY SUM(grad_cohort) DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    state  race_X_percentage  race_W_percentage  \
# 0             California              53.14              16.65
# 1               New York              53.08              27.87
# 2                  Texas              51.28              22.04
# 3                Florida              51.95              24.55
# 4           Pennsylvania              52.04              37.55
# 5                Arizona              56.39              25.50
# 6                   Ohio              51.69              38.89
# 7               Illinois              52.00              30.49
# 8               Michigan              52.49              37.29
# 9         North Carolina              51.85              31.10
# 10              Virginia              52.30              30.40
# 11         Massachusetts              53.28              34.56
# 12               Indiana              51.71              40.59
# 13               Georgia              52.23              26.81
# 14            New Jersey              53.17              25.15
# 15              Missouri              51.68              38.43
# 16             Tennessee              51.42              34.90
# 17             Wisconsin              51.32              42.50
# 18             Minnesota              51.89              40.36
# 19               Alabama              51.13              30.19
# 20              Colorado              52.47              33.82
# 21        South Carolina              51.10              32.84
# 22              Maryland              51.69              27.20
# 23             Louisiana              51.13              28.62
# 24                  Iowa              52.38              40.95
# 25              Kentucky              51.01              42.36
# 26            Washington              52.48              34.98
# 27              Oklahoma              51.58              32.80
# 28           Mississippi              50.68              26.47
# 29                Kansas              52.21              37.99
# 30                Oregon              53.13              37.53
# 31              Arkansas              50.76              35.73
# 32           Connecticut              52.71              33.80
# 33                  Utah              52.14              41.00
# 34         West Virginia              51.08              44.20
# 35              Nebraska              51.92              40.90
# 36            New Mexico              52.48              16.75
# 37          Rhode Island              53.88              36.94
# 38         New Hampshire              53.24              42.39
# 39                Nevada              52.75              25.70
# 40                 Maine              52.72              43.37
# 41                 Idaho              51.91              41.84
# 42          North Dakota              51.18              43.19
# 43              Delaware              51.67              32.92
# 44  District of Columbia              53.26              26.54
# 45          South Dakota              51.63              42.94
# 46               Montana              51.78              41.46
# 47               Vermont              51.94              44.07
# 48                Hawaii              57.32               9.82
# 49               Wyoming              51.58              41.70
# 50                Alaska              51.80              30.21
#
#     race_B_percentage  race_H_percentage  race_Ai_percentage  \
# 0                3.62              17.63                0.30
# 1                7.30               7.53                0.22
# 2                7.46              16.59                0.26
# 3               10.18              11.50                0.21
# 4                5.93               2.45                0.15
# 5                7.82               7.60                1.45
# 6                7.02               1.25                0.22
# 7                8.29               6.10                0.18
# 8                6.58               1.59                0.44
# 9               13.09               1.86                0.61
# 10              11.14               3.03                0.22
# 11               3.72               4.44                0.21
# 12               4.58               1.84                0.20
# 13              16.78               1.85                0.16
# 14               7.79               9.57                0.16
# 15               7.04               1.45                0.30
# 16              11.40               1.19                0.21
# 17               2.25               1.75                0.51
# 18               2.82               1.82                0.63
# 19              16.78               0.98                0.35
# 20               3.68               7.27                0.79
# 21              13.88               1.22                0.21
# 22              14.86               2.73                0.19
# 23              17.52               1.40                0.33
# 24               3.40               2.00                0.28
# 25               5.08               0.82                0.13
# 26               2.03               4.10                0.79
# 27               5.81               2.70                5.89
# 28              21.77               0.47                0.21
# 29               4.11               3.66                1.01
# 30               1.35               3.84                0.77
# 31              10.58               1.64                0.58
# 32               5.38               5.95                0.13
# 33               0.83               3.34                0.70
# 34               3.32               0.73                0.20
# 35               2.63               2.83                0.54
# 36               1.57              22.83                5.43
# 37               2.69               3.83                0.27
# 38               1.12               1.62                0.35
# 39               4.81               9.38                0.75
# 40               1.27               1.07                0.62
# 41               0.70               3.83                0.71
# 42               1.06               0.63                3.55
# 43              10.50               3.14                0.12
# 44              14.08               2.56                0.10
# 45               0.43               0.85                3.74
# 46               0.36               1.25                4.37
# 47               1.09               1.41                0.27
# 48               0.96               4.33                0.22
# 49               1.06               3.52                1.45
# 50               2.24               2.09                8.93
#
#     race_A_percentage
# 0                8.66
# 1                3.99
# 2                2.38
# 3                1.62
# 4                1.87
# 5                1.23
# 6                0.93
# 7                2.95
# 8                1.61
# 9                1.48
# 10               2.91
# 11               3.80
# 12               1.08
# 13               2.18
# 14               4.17
# 15               1.09
# 16               0.88
# 17               1.67
# 18               2.49
# 19               0.57
# 20               1.96
# 21               0.75
# 22               3.33
# 23               1.00
# 24               0.99
# 25               0.61
# 26               5.63
# 27               1.21
# 28               0.40
# 29               1.03
# 30               3.38
# 31               0.70
# 32               2.02
# 33               1.98
# 34               0.47
# 35               1.18
# 36               0.94
# 37               2.38
# 38               1.29
# 39               6.61
# 40               0.95
# 41               1.01
# 42               0.40
# 43               1.65
# 44               3.46
# 45               0.42
# 46               0.79
# 47               1.22
# 48              27.35
# 49               0.68
# 50               4.74

# %% [markdown]
# **Insights**
#
# In contrast to states such as Iowa, West Virginia, and Vermont, characterized by a predominant concentration of White students, the United States exhibits fascinating diversity in racial composition across its states. This variance underscores the intricate tapestry of racial demographics, reflecting regional nuances and cultural dynamics.

# %% [markdown]
# Then, we want to see the distribution of financial aid based on the colleges, answering the question -
#
# ###**5.3.6 Distribution of Financial Aid across the Colleges**

# %%
# %%bigquery --project $project_id
# SELECT
#   basic,
#   control,
#   AVG(aid_value) AS avg_aid_value,
#   RANK() OVER (PARTITION BY control ORDER BY AVG(aid_value) DESC) AS ranking
# FROM `ba-775-a06.cc_datasets.1-details`
# WHERE aid_value IS NOT NULL
# GROUP BY
#   basic, control
# ORDER BY
#   control, ranking;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                 basic             control  \
# 0   Theological seminaries- Bible colleges- and ot...  Private for-profit
# 1                    Other special-focus institutions  Private for-profit
# 2                   Schools of art- music- and design  Private for-profit
# 3              Baccalaureate Colleges--Diverse Fields  Private for-profit
# 4                   Baccalaureate/Associates Colleges  Private for-profit
# ..                                                ...                 ...
# 57            Associates--Public Rural-serving Medium              Public
# 58             Associates--Public Rural-serving Large              Public
# 59  Associates--Public Suburban-serving Single Campus              Public
# 60    Associates--Public Suburban-serving Multicampus              Public
# 61       Associates--Public Urban-serving Multicampus              Public
#
#     avg_aid_value  ranking
# 0     8359.000000        1
# 1     6194.666667        2
# 2     5467.587302        3
# 3     4944.463415        4
# 4     4641.703125        5
# ..            ...      ...
# 57    4288.245675       19
# 58    4231.054688       20
# 59    3796.028302       21
# 60    3717.525253       22
# 61    3583.712000       23
#
# [62 rows x 4 columns]

# %% [markdown]
# **Insights**
#
# Delving into financial aid across colleges, it's fascinating to uncover some quirks in the data. Amherst College takes the crown with an average aid of $41,580, closely followed by Yale at 41,085 dollars. However, when it comes to public universities, UC Santa Cruz leads the pack with aid hovering around 17,000 dollars.
#
# Adding a sprinkle of intrigue, there's a pattern emerging – the more popular the college, the more generous they are with financial aid. Could it be that their lofty reputation translates into a robust belief in students' ability to repay loans? It's a thought-provoking connection, hinting at the interesting dynamics between a college's prestige and the support it provides to its students.

# %% [markdown]
# Lastly, our objective is to identify patterns in the programs and concentrations that students commonly choose for their degrees, addressing the question -
#
# ###**5.3.7 Exploring Popular Programs and Concentrations Chosen by Students for Their Degrees**

# %%
# %%bigquery --project $project_id
# SELECT
#   basic,
#   COUNT(*) AS total_students
# FROM `ba-775-a06.cc_datasets.1-details`
# GROUP BY
#   basic
# ORDER BY
#   basic;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                 basic  total_students
# 0                      Associates--Private For-profit             517
# 1   Associates--Private For-profit 4-year Primaril...              83
# 2                  Associates--Private Not-for-profit              73
# 3   Associates--Private Not-for-profit 4-year Prim...               7
# 4   Associates--Public 2-year colleges under 4-yea...              47
# 5      Associates--Public 4-year Primarily Associates              34
# 6              Associates--Public Rural-serving Large             128
# 7             Associates--Public Rural-serving Medium             289
# 8              Associates--Public Rural-serving Small             111
# 9                      Associates--Public Special Use               4
# 10    Associates--Public Suburban-serving Multicampus              99
# 11  Associates--Public Suburban-serving Single Campus             106
# 12       Associates--Public Urban-serving Multicampus             125
# 13     Associates--Public Urban-serving Single Campus              31
# 14            Baccalaureate Colleges--Arts & Sciences             252
# 15             Baccalaureate Colleges--Diverse Fields             343
# 16                  Baccalaureate/Associates Colleges             124
# 17                     Doctoral/Research Universities              79
# 18  Masters Colleges and Universities--larger prog...             386
# 19  Masters Colleges and Universities--medium prog...             169
# 20  Masters Colleges and Universities--smaller pro...             106
# 21           Not applicable- not in Carnegie universe              81
# 22                   Other health professions schools              43
# 23                   Other special-focus institutions               5
# 24                   Other technology-related schools              54
# 25      Research Universities--high research activity              96
# 26  Research Universities--very high research acti...             106
# 27                  Schools of art- music- and design             114
# 28                 Schools of business and management              42
# 29                             Schools of engineering               4
# 30                                     Schools of law               1
# 31  Theological seminaries- Bible colleges- and ot...             106
# 32                                    Tribal Colleges              33

# %% [markdown]
# **Q7 ANSWER**
#
# Navigating the academic landscape, a substantial 2 million students embark on the journey of higher education, choosing the rich tapestry of Research Universities. In parallel, the allure of Masters Colleges and Universities stands strong, with an even greater enrollment, surpassing Research Universities by 120k students. Unveiling the essence of these choices, the average SAT score paints a vivid picture: 1036.9 for Masters Universities and a higher threshold at 1258.3 for Research Universities. It's a nuanced tale of aspirations, echoing through the hallowed halls of education.

# %% [markdown]
# ##**Diversity Summary**
# Diversity in American higher education is evident in the distribution of universities across states. California boasts 350 colleges, while Alabama stands out with 15 Historically Black Colleges and Universities (HBCUs). Each state designates a flagship university, traditionally the oldest public institution with high government funding.
#
# Our investigation challenges the belief that a high SAT score is essential for flagship status. Flagship universities, despite not aligning with elite institutions, excel in awards and graduation rates. Racial composition, notably in states like Iowa and West Virginia, adds complexity to the diversity narrative.
#
# Delving into financial aid reveals intriguing quirks. Amherst College leads with an average aid of 41,580 dollars, followed closely by Yale at $41,085. UC Santa Cruz stands out among public universities with aid around 17,000 dollars. A pattern emerges – popular colleges tend to be more generous with financial aid, hinting at dynamics between prestige and student support.
#
# In navigating the academic landscape, 2 million students opt for Research Universities, while Masters Colleges and Universities allure with a greater enrollment. The average SAT score paints a nuanced tale of aspirations, with 1036.9 for Masters Universities and a higher 1258.3 for Research Universities.

# %% [markdown]
# #**6. Dashboard**

# %% [markdown]
# [dashboard link](https://public.tableau.com/app/profile/prudhvi.lanke/viz/BA775-Team-A06-Phonominal/PhoNominalAgency?publish=yes)

# %% [markdown]
# ##6.1 Dashboard 1(Merit Dashboard):
#
# The dashboard paint a detailed picture of the diverse landscape of universities, their ownership structures, program durations, expected award values, and the relationship between Median SAT scores and student counts. Firstly, the examination of ownership and funding across states underscores the nuanced nature of Historically Black Colleges and Universities (HBCUs), challenging assumptions about racial segregation exclusively determining ownership. The subsequent categorization of universities based on ownership and program duration reveals that Private for Profit institutions with 4-year programs showcase the highest average expected award values, potentially driven by market demand for these programs. In contrast, Public Universities offering 2-year programs display lower award values on average. The exploration into SAT scores unveils that many Private for Profit universities do not report SAT scores, suggesting alternative admissions criteria. The scatter plot analysis further emphasizes a positive correlation between Median SAT values and average expected award values, notably pronounced for Public schools and also applicable to engineering schools and research universities with high research activities. Delving deeper into university types, School of Engineering and research universities emerge with the highest SAT values, while Associate-Public Urban-serving Multicampus stands out with the least Median SAT value at 756. Collectively, these insights provide a holistic view of the varied factors influencing universities, from ownership and program durations to admissions criteria and the intricate relationship between SAT scores and expected award values.

# %% [markdown]
# ![WhatsApp Image 2023-12-11 at 17.37.08.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ##6.2 Dashboard 2(Graduation Rates Dashboard):
# The dashboard, with its focus on graduation rates across states and regions in each year, provides valuable insights into the quality of education and potential challenges in completing programs. The Geo Maps highlight distinct variations in graduation rates, with states like the District of Columbia, Rhode Island, New York, and New Hampshire consistently demonstrating high graduation rates. In contrast, Louisiana, New Mexico, Alaska, and North Dakota appear to face challenges with lower graduation rates. The regional analysis underscores the Northeast region's consistent outperformance in both Grad_100 and Grad_150 rates, indicating a potential regional advantage in educational outcomes. Conversely, the South West region consistently exhibits a minimal range in graduation rates, suggesting possible difficulties in program completion. Integrating insights from a previous dashboard, the correlation between graduation rates and SAT scores becomes apparent. Institutions with higher SAT scores tend to exhibit higher graduation rates, aligning with the notion that students with elevated SAT scores demonstrate a greater level of academic preparedness. Additionally, higher SAT score schools may have access to greater resources and academic support services, contributing to the positive correlation observed. Collectively, these insights provide a comprehensive understanding of the multifaceted factors influencing graduation rates, including geographical variations, regional trends, and the impact of academic preparedness as reflected by SAT scores.

# %% [markdown]
# ![WhatsApp Image 2023-12-11 at 17.37.45.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Note**
#
# Although the screenshot of the dashboard indicates that the amount of information in our charts is excessive, leading to a somewhat crowded layout and causing some information to be obscured, the primary intention behind our charts is to leverage various filters on the right, such as state, region, level, basic, control, etc., to highlight variations. Consequently, when we use these filters, the charts in the dashboard won't appear as congested. The information filtered out will also be more clearly visible.

# %% [markdown]
# #**7. Conclusion**
#
# **Navigating the Educational Landscape: Insights into University Selection, Funding Dynamics, and Institutional Characteristics**
#
# Regional academic disparities in the U.S. are evident as institutions showcase distinct funding patterns per award. Institutional characteristics impact SAT scores, highlighting a correlation between academic focus and achievement. Combining these factors reveals a positive connection between SAT scores and awards, suggesting higher SAT score schools are more generous.
#
# Analysis unveils graduation rate patterns, with Rhode Island consistently leading and Northeastern private nonprofits outperforming. Two-year private for-profit and four-year private not-for-profit institutions maintain high graduation rates. Geographically, New York leads in 4-year colleges, while California leads in 2-year colleges.
#
# Higher SAT score groups achieve better graduation outcomes, indicating a positive relationship. This upward trend aligns with a significant correlation between Median SAT scores and graduation rates.
#
# Diversity is evident in university distribution, with flagship universities excelling in awards and graduation rates. Financial aid insights reveal quirks, with popular colleges being more generous.
#
# In the academic landscape, 2 million students opt for Research Universities, while Masters Colleges and Universities allure with greater enrollment. The average SAT score paints a nuanced tale of aspirations.
#
# The dashboard explores ownership structures, program durations, expected award values, and the relationship between Median SAT scores and student counts. Private for-profit institutions with 4-year programs showcase the highest average expected award values. Many Private for Profit universities do not report SAT scores, suggesting alternative admissions criteria.
#
# The graduation rates dashboard provides insights into education quality, highlighting distinct variations in graduation rates through Geo Maps. The Northeast consistently outperforms, indicating a potential regional advantage. The correlation between graduation rates and SAT scores becomes apparent.
#
# Collectively, these insights offer a comprehensive understanding of factors influencing graduation rates, including geographical variations, regional trends, and the impact of academic preparedness reflected by SAT scores.

# %% [markdown]
# #**8. Challenge**
#
# In this project, our initial intention was to merge the current university rankings table to investigate potential correlations between university rankings, graduation rates, SAT scores, and awards. However, due to uncertainty regarding the linkage of the 'unitid' in the original dataset with the 'unitid' in the university rankings table, we have decided to forgo this idea in this report. We hope to establish this connection in future analyses. Additionally, it's crucial to note that the dataset used here is a decade old, which may impact the relevance of the analysis to present-day universities. We look forward to working with more up-to-date datasets in the future for more accurate insights. Lastly, it's worth mentioning that the dataset contains numerous missing values, particularly in SAT scores, awards, and graduation rates. A more comprehensive dataset in the future would undoubtedly facilitate a more thorough analysis.

# %% [markdown]
# #**9. Reference**
#
# * SAT score level classification: https://blog.prepscholar.com/sat-score-range
# * US Department of Education: https://nces.ed.gov/pubs2019/2019119.pdf
# * Region Split Up in the USA: https://www.mappr.co/political-maps/us-regions-map/

# %% [markdown]
# #**10. Use of GEN AI**
#
# We have used Chat GPT for the following aspects -
#
# 1. For grammar and sentence checks in our text blocks. The prompts were - "Check and correct the vocabulary in the given summary". etc.
#
# 2. Fact-checking the questions regarding HBCUs and Flagship universities. like - "Why does each state have only one flagship university?" , "Do HBCUs represent diversity in a particular state?"
