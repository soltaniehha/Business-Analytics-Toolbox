# %% [markdown]
#  # **Analyzing Fatal U.S. Traffic Accident Patterns From 2017-2020: Insights for Improved Road Safety**

# %% [markdown]
# # Project Report - Team 1 (Cohort A)
# <font size="4">Amisha Kelkar, Brendan Wilcox, Courtney Vincent, Mohammed Zaid Bin Haris, Siddharth Kant</font>

# %% [markdown]
# ## Executive Summary
# **Introduction**<br>
# This report performs various analyses using the *nhtsa_traffic_fatalities* dataset to provide recommendations to various U.S. government stakeholders that could help prevent and improve the response to fatal traffic accidents.
# The dataset was sourced from the National Highway Traffic Safety Administration (NHTSA). From this dataset, we were able to provide detailed analyses on fatal crashes from 2017-2020 regarding:
# * Demographic factors
# * Date and time
# * Relation between crashes and driving conditions
# * Crash Involvement characteristics (Vehicle and collision type)
# * Weather conditions
# * People involved in crashes
# While the analyses only utilize four years of data, the resulting insights provide a reliable foundation for implementing crash-prevention and response measures. This reliability will only be improved by continuously adding newly available data.
#
#
# **Methodology & Process**<br>
# All project data work and analyses were conducted using SQL within a Jupyter notebook. Visualizations were created using Tableau.
# 1. Cleaning
# 	* The largest challenge with this dataset was choosing the most relevant of the 143 total tables spread across six different years. Multiple hours were spent on establishing the target outcome and the desired approach that allowed the team to key in on the final list of 21 tables used in this report
# 	* The dataset’s cleanliness and workability was assured through the following steps:
# 		1. Counting records across all tables used for each year as a sanity check to ensure their completeness and that their lengths were feasible in comparison to the other years
# 		2. From there, all tables (Including the created “population” table) were checked for “null” values, and none were found in any table
# 2. Merging Tables
# To perform desired analyses, the merging of different table types was necessary to execute integral queries. The tables merged were as follows:
#   * accident, vevent & drimpair tables for the years 2017-2020
#   * accident 2017-2020 & population of states for years 2017-2020
# 3. Analysis & Observations
# 	* The project’s analysis process for the six categories listed in the introduction took place in a two-tiered process:
# 		1. Exploration: The team started their analysis by building on the narratives found in the project's first iteration. This included experimenting with scaled versions of queries from the first iteration (i.e., bringing in the years 2017-2019 and adding additional columns) and looking at interesting trends that manifested in the first iteration
# 		2. Insight Targeting: After finishing the exploration process, the team digested the query outputs and decided which areas would be most relevant to target stakeholders. From there, these chosen query outputs were optimized for stakeholder presentation (Converted to a palatable format for visualization) and synthesized in writing to explain their relevance
# 4. Visualization & Report Preparation
# 	* Selected query data was imported into Tableau to better to convey the project’s key insights and use cases. In Tableau, two dashboards were created:
# 		1. High-level findings for broad applications
# 		2. Tailored findings centering on specific conditions and circumstances
#
# **Key Findings**<br>
# *  Demographic factors
# 	1. The high population States of California, Florida, Texas, New York, and Georgia report the most accidents of any states. California is at the top with 4,881 fatal accidents from 2017-2020
# 	2. The states of North Dakota, Vermont, and Wyoming have the fewest accidents at often less than 50 per year. This is relfective of their lower populations and traffic density
# 	3. The rural states of Wyoming and Montana face elevated fatal accident rates relative to their populations (Despite having low absolute accident counts) due to factors such as limited emergency services, harsh weather, and extensive rural road networks
# 	4. The urbanized states of New York and Massachusetts have low fatal accident rates relative to their populations due to having safer roads through extensive public transportation, better infrastructure, and effective urban design.
# * Date and time
# 	1. An interactive tool was created in Tableau that allows stakeholders to understand when fatal crashes most frequently happen historically by year (2017- 2020 individually and combined), day, hour, and 10-minute block within that hour. For example, “On Sundays from 2017-2020, crashes between 12:00 am and 1:00 am occurred most frequently between 12:00 am and 12:10 am”
# 	2. Higher crash counts in 2020 compared to 2017-2019 (+5.06%) suggest that abnormal situations related to a greater number of drivers on the road lead to more crashes
# 	3. Fatal crashes follow a highly predictable pattern across years, where they are at their peak in the warmer months (June-October) and decrease from there to their lowest numbers in the middle of winter (January & February) before increasing again
# * Relation Between Crashes and Driving Conditions
# 	1. Roadway departures, vehicle rollovers, and motor vehicle collisions are consistently the top causes of crashes from 2017-2020. These trends are often amplified by driver impairment due to alcohol or drugs
# 	2. Weekends account for the majority of drunk driving deaths, where Saturday has the most, followed by Sunday and Friday. This trend aligns with peak social drinking nights, and overall death numbers are in line with increased drunk driving accidents
# *  Crash involvement characteristics (Vehicle and collision type)
# 	1. Parked or stopped vehicles contribute significantly to fatal crashes, and this number has increased over time. This challenges the assumption that most crashes occur between moving vehicles
# * Weather conditions
# 	1.  Cloudy and rainy weather conditions contribute the most to crashes in both urban and rural settings
# 	2. Less frequent conditions such as fog and smog contribute to crashes at a higher rate in urban settings
# 	3. Accidents occur more frequently in the daylight hours due to a higher traffic volume, while many nighttime crashes occur in poorly lit rural areas
# * People involved in crashes
# 	1. Most traffic fatalities occur within the 45-60 age group
# 	2. The under-18 age group experiences the smallest number of traffic fatalities
# 	3. Males account for the majority of fatalities across all age groups
#
#
# **Recommendations**<br>
# * Assign more funding to traffic safety and road infrastructure in states with high accident rates relative to population
# * Emergency services should utilize the “Top Crash Times by Day & Hour (2017-2020)” tool to optimize staffing and road placement to prevent and better repsond to car crashes
# * Increase staffing and road placement of emergency services when factors that increase traffic volume are present
# * Implement strategies to counteract the seasonal increase in fatal crashes during the warmer months, including increased emergency services staffing, higher fines for poor driving, and enhanced driver’s education programs
# * Increase awareness of driving under the influence and increase the severity of punishments for such offenses
# * Promote road safety awareness, and improve road design with construction projects
# * Promote and implement vehicle stability technologies
# * Enforce stricter parking regulations and raise awareness surrounding the dangers presented by parked vehicles
# * Heighten alertness and emergency services availability during adverse weather conditions such as rain, snow, fog, and smog
# * Improve infrastructure to reduce the negative impacts of poor lighting conditions in traffic accidents
#
#
# **Conclusion**<br>
# Overall, in conducting extensive analyses on the 2017-2020 fatal traffic data, the team was able to identify trends in the various conditions, factors, and characteristics of fatal traffic accidents. From this, the team was able to supply a list of key findings and associated recommendations that can help to prevent and improve the response to traffic accidents. While these findings will benefit from additional data in the future, this project has served to provide government stakeholders with foundational insights that can allow them to improve traffic safety, and decrease traffic fatalities.

# %% [markdown]
# ## Entity Relationship Diagram

# %% [markdown]
# ![BA775_ERD[1].png](data:image/png;base64,...)

# %% [markdown]
# The ERD visually represents how different entities (like accidents, pbype, drimpai, parkwork, cevent,  population) in the Fatal Accidents dataset are connected through relationships.It demonstrates the many to many relationship between the consecutive number field throughout all five tables.
# Moreover it also shows the one to many relationship between the state name of the population table and the accident table. There is a union all connection between different years of the same table as well.

# %% [markdown]
# ## Motivation

# %% [markdown]
# Understanding the underlying causes of vehicle accidents is critical for enhancing public safety and reducing the number of injuries and fatalities on the road. By analyzing traffic patterns, role of demographics and the factors influencing accidents, this project aims to provide valuable insights that can inform better safety measures, effective policy changes, and optimized emergency response strategies to improve overall road safety.

# %% [markdown]
# ## Problem Definition
#
# This project aims to analyze traffic patterns and identify the factors contributing to vehicle accidents based on comprehensive traffic accident data for the years 2017 - 2020. Our focus will include:
# - Identify locations and times with the highest frequency and severity of vehicle accidents.
# - Examine the impact of environmental factors (weather, light conditions) and roadway characteristics (type of intersection, land use) on accident rates.
# - Investigate patterns related to the type of collision and the first harmful event that led to accidents.
# - Analyze the demographics of affected individuals and the correlation with accident severity and outcomes.
# - Compare the rates of accidents, fatalities, and drunk driving incidents per 100 people across states to identify variations and trends over the years.

# %% [markdown]
# <font size="4"> **Data Source**<font>

# %% [markdown]
# <font size="4">1. [U.S. Traffic Accident 2017-2020 Data: Big Query Datasets ](https://console.cloud.google.com/bigquery?ws=!1m4!1m3!3m2!1sbigquery-public-data!2snhtsa_traffic_fatalities):<font size>
# * This dataset contains the records of traffic fatalities across the US over the years 2017-2020. This will be the primary source for our analysis on and we will be using various tables within the data set.<br />

# %% [markdown]
# <font size="4">**Data Dictionary**

# %% [markdown]
# **1. accident_2017-2020 :** These tables hold details about accidents, including time of crash, weather conditions, EMS arrival details, and related information for the years 2017 to 2020. Each year is represented as a separate table.
#
# <div style="width:100%;">
#
# | Column | Description | Data Type |
# |:-|:-|:-|
# |light_condition_name   	|This data element records the type/level of light that existed at the time of the crash as indicated in the case material.    	|Object |
# |land_use_name    	|1 (Rural), 2 (Urban), 6 (Trafficway Not in State Inventory), 8 (Not Reported) and 9 (Unknown).    	|Object |
# |atmospheric_conditions_1_name   	|This data element records the prevailing atmospheric conditions that existed at the time of the crash as indicated in the case material.    	|Object
# |state_name    	|This data element identifies the state in which the crash occurred.     	|String
# |state_number    	|This data element identifies the state in which the crash occurred.     	|Integer
# |consecutive_number    	|This data element is the unique case number assigned to each crash. It appears on each data file and is used to merge information from the data files together.    	|Integer
# |number_of_drunk_drivers    	|This data element records the number of drunk drivers involved in the crash. 00-99 Number of Drunk Drivers Involved in the Fatal Crash.    	|Integer
# |day_of_week_name    	|This data element records the day of the week on which the crash occurred. 1 Sunday 2 Monday 3 Tuesday 4 Wednesday 5 Thursday 6 Friday 7 Saturday -- Unknown.    	|String
# |month_of_crash_name    	|This data element records the month in which the crash occurred.    	|String
# |timestamp_of_crash	|This data element records the date and time on which the crash occurred.    	|Time Stamp
# |hour_of_crash    	|This data element records the hour at which the crash occurred. 00-23 Hour -- Not Applicable or Not Notified 99 Unknown    	|Integer |
# |first_harmful_event_name    	|This data element describes the first injury or damage producing event of the crash.    	|Object |
# |number_of_fatalities    	|This data element records the number of fatally injured persons in the crash. 01-99 Number of Fatalities that Occurred in the Crash.    	|Integer
#
#
#  **2. drimpair_2017-2020 :** Contains driver-level impairment information identified during crashes, along with geographic codes, for the years 2017 to 2020. Each year is represented as a separate table.
#
# | Column | Description | Data Type |
# |:-|:-|:-|
# condition_impairment_at_time_of_crash_driver_name_name	|This data element identifies physical impairments to this driver that may have contributed to the crash as identified by law enforcement.	|String
# |consecutive_number	|This data element is the unique case number assigned to each crash. It appears on each data file and is used to merge information from the data files together.	|Integer
#
#
#
#  **3. parkwork_2017-2020 :** Contains vehicle-level crash details such as body type, ownership, and crash time specifics for the years 2017 to 2020. Each year is represented as a separate table.
#
# | Column | Description | Data Type |
# |:-|:-|:-|
# |body_type_name	|This data element identifies a classification of this vehicle based on its general body configuration, size, shape, doors, etc.	|String
# |registered_vehicle_owner_name	|This data element identifies the type of registered owner of the vehicle.	|String
# |consecutive_number	|This data element is the unique case number assigned to each crash.	|Integer
#
#  **4. cevent_2017-2020 :** These tables outline fields describing crash data, including the location (state), unique identifiers for each crash and event, involved vehicles, areas of impact, and sequence of events, with code references from the General Services Administration’s Geographic Location Codes (GLC), spanning the years 2017 to 2020. Each year is represented as a separate table.
#
# | Column | Description | Data Type |
# |:-|:-|:-|
# |sequence_of_events_name    	|This data element describes this event. A motor vehicle traffic crash is a series of events resulting from an unstabilized situation. This series of harmful and non-harmful events is recorded in chronological order based on the PAR narrative and diagram.	|String
# |consecutive_number     	|This data element is the unique case number assigned to each crash. It appears on each data file and is used to merge information from the data files together.	|Integer
#
#
#
#  **5. pbtype_2017-2020 :** These tables provide detailed crash information, including location, demographics, infrastructure presence, crash type, participant roles, and movement direction for crashes involving vehicles, pedestrians, and bicyclists, for the years 2017 to 2020. Each year is represented as a separate table.
#
# | Column | Description | Data Type |
# |:-|:-|:-|
# age	|This data element identifies the person’s age, in years, with respect to the person's last birthday. 000 Less than One Year 001-120 Age of the Individual in Years 998 Not Reported 999 Unknown	|Integer
# state_name	|This data element identifies the state in which the crash occurred. The codes are from the General Services Administration’s (GSA) publication of worldwide Geographic Location Codes (GLC).	|String
# |consecutive_number	|This data element is the unique case number assigned to each crash. It appears on each data file and is used to merge information from the data files together.	|Integer

# %% [markdown]
# <font size="4"> 2. [State Population Totals: 2010-2020](https://www.census.gov/programs-surveys/popest/technical-documentation/research/evaluation-estimates/2020-evaluation-estimates/2010s-state-total.html):
# * This dataset contains the records of population of states in the US for years between 2017-2020. We added this dataset to provide a more granular level of analysis by taking into the wide range of population densities across the country and normalizing them as percentages.<br />
#
# <font size="4">**Data Dictionary**<font> <br>
#
#  **1. population :** These tables provide state-level population data for the years 2017 to 2020, detailing the population count for each state.
#
# | Column | Description | Data Type |
# |:-|:-|:-|
# State	|This data element identifies the name of the U.S. state.	|String
# Year	|This data element represents the year for which the population data is recorded (2017–2020).	|Integer
# Population	|This data element provides the total population of the state for the given year.	|Integer

# %% [markdown]
# ## Data Cleaning & Exploratory Data Analysis:

# %% [markdown]
# The cleaning of explorry analysis of the datasets were done as follows:

# %% [markdown]
# ### Count of Records
# Following are the count of records in each of the tables:

# %%
# %%bigquery
# SELECT
#     CONCAT('accident_', _TABLE_SUFFIX) AS Table_Name,
#     COUNT(*) AS Number_of_Records
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_*`
# WHERE _TABLE_SUFFIX BETWEEN '2017' AND '2020'
# GROUP BY _TABLE_SUFFIX
# ORDER BY _TABLE_SUFFIX;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       Table_Name  Number_of_Records
# 0  accident_2017              34299
# 1  accident_2018              33692
# 2  accident_2019              33242
# 3  accident_2020              35451

# %%
# %%bigquery
# SELECT
#     CONCAT('drimpair_', _TABLE_SUFFIX) AS Table_Name,
#     COUNT(*) AS Number_of_Records
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_*`
# WHERE _TABLE_SUFFIX BETWEEN '2017' AND '2020'
# GROUP BY _TABLE_SUFFIX
# ORDER BY _TABLE_SUFFIX;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       Table_Name  Number_of_Records
# 0  drimpair_2017              53349
# 1  drimpair_2018              52453
# 2  drimpair_2019              51797
# 3  drimpair_2020              54448

# %%
# %%bigquery
# SELECT
#     CONCAT('parkwork_', _TABLE_SUFFIX) AS Table_Name,
#     COUNT(*) AS Number_of_Records
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. parkwork_*`
# WHERE _TABLE_SUFFIX BETWEEN '2017' AND '2020'
# GROUP BY _TABLE_SUFFIX
# ORDER BY _TABLE_SUFFIX;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       Table_Name  Number_of_Records
# 0  parkwork_2017               1383
# 1  parkwork_2018               1328
# 2  parkwork_2019               1365
# 3  parkwork_2020               1527

# %%
# %%bigquery
# SELECT
#     CONCAT('cevent_', _TABLE_SUFFIX) AS Table_Name,
#     COUNT(*) AS Number_of_Records
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. cevent_*`
# WHERE _TABLE_SUFFIX BETWEEN '2017' AND '2020'
# GROUP BY _TABLE_SUFFIX
# ORDER BY _TABLE_SUFFIX;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     Table_Name  Number_of_Records
# 0  cevent_2017             101570
# 1  cevent_2018              96244
# 2  cevent_2019              94082
# 3  cevent_2020             103239

# %%
# %%bigquery
# SELECT
#     CONCAT('pbtype_', _TABLE_SUFFIX) AS Table_Name,
#     COUNT(*) AS Number_of_Records
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_*`
# WHERE _TABLE_SUFFIX BETWEEN '2017' AND '2020'
# GROUP BY _TABLE_SUFFIX
# ORDER BY _TABLE_SUFFIX;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     Table_Name  Number_of_Records
# 0  pbtype_2017               7506
# 1  pbtype_2018               7835
# 2  pbtype_2019               7752
# 3  pbtype_2020               8103

# %%
# %%bigquery
# SELECT
#     'population' AS Table_Name,
#     COUNT(*) AS Number_of_Records
# FROM `ba775-team-project-440113.state_population_2017_2020.population`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    Table_Name  Number_of_Records
# 0  population                204

# %% [markdown]
# ### Checking for Nulls
# All the tables are checked for null values across columns of relevance from each of the table

# %%
# %%bigquery
# SELECT
#   year,
#   COUNTIF(
#     light_condition IS NULL OR
#     land_use_name IS NULL OR
#     atmospheric_conditions_1_name IS NULL OR
#     number_of_fatalities IS NULL OR
#     state_number IS NULL OR
#     consecutive_number IS NULL OR
#     number_of_drunk_drivers IS NULL OR
#     day_of_week_name IS NULL OR
#     month_of_crash_name IS NULL OR
#     timestamp_of_crash IS NULL OR
#     hour_of_crash_name IS NULL
#   ) AS any_column_null
# FROM (
#   SELECT
#     light_condition,
#     land_use_name,
#     atmospheric_conditions_1_name,
#     number_of_fatalities,
#     state_number,
#     consecutive_number,
#     number_of_drunk_drivers,
#     day_of_week_name,
#     month_of_crash_name,
#     timestamp_of_crash,
#     hour_of_crash_name,
#     _TABLE_SUFFIX AS year
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_*`
#   WHERE _TABLE_SUFFIX BETWEEN '2017' AND '2020'
# )
# GROUP BY year
# ORDER BY year;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    year  any_column_null
# 0  2017                0
# 1  2018                0
# 2  2019                0
# 3  2020                0

# %%
# %%bigquery
# SELECT
#   year,
#   COUNTIF(
#     age IS NULL OR
#     state_name IS NULL
#   ) AS any_column_null
# FROM (
#   SELECT age, state_name, 2017 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2017`
#   UNION ALL
#   SELECT age, state_name, 2018 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2018`
#   UNION ALL
#   SELECT age, state_name, 2019 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2019`
#   UNION ALL
#   SELECT age, state_name, 2020 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2020`
# )
# GROUP BY year
# ORDER BY year;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    year  any_column_null
# 0  2017                0
# 1  2018                0
# 2  2019                0
# 3  2020                0

# %%
# %%bigquery
# SELECT
#   year,
#   COUNTIF(sequence_of_events_name IS NULL) AS any_column_null
# FROM (
#   SELECT sequence_of_events_name, 2017 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. cevent_2017`
#   UNION ALL
#   SELECT sequence_of_events_name, 2018 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. cevent_2018`
#   UNION ALL
#   SELECT sequence_of_events_name, 2019 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. cevent_2019`
#   UNION ALL
#   SELECT sequence_of_events_name, 2020 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. cevent_2020`
# )
# GROUP BY year
# ORDER BY year;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    year  any_column_null
# 0  2017                0
# 1  2018                0
# 2  2019                0
# 3  2020                0

# %%
# %%bigquery
# SELECT
#   year,
#   COUNTIF(condition_impairment_at_time_of_crash_driver IS NULL) AS any_column_null
# FROM (
#   SELECT condition_impairment_at_time_of_crash_driver, 2017 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2017`
#   UNION ALL
#   SELECT condition_impairment_at_time_of_crash_driver, 2018 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2018`
#   UNION ALL
#   SELECT condition_impairment_at_time_of_crash_driver, 2019 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2019`
#   UNION ALL
#   SELECT condition_impairment_at_time_of_crash_driver, 2020 AS year FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2020`
# )
# GROUP BY year
# ORDER BY year;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    year  any_column_null
# 0  2017                0
# 1  2018                0
# 2  2019                0
# 3  2020                0

# %%
# %%bigquery
# SELECT
#  COUNTIF(
#     Year IS NULL OR
#     State IS NULL OR
#     Population IS NULL
#   ) AS any_column_null
# FROM `ba775-team-project-440113.state_population_2017_2020.population`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    any_column_null
# 0                0

# %% [markdown]
# From our BigQuery dataset, we initially worked with 17 table types covering the years 2015–2020. After evaluating their relevance, we selected 5 table types that we deemed most insightful for our analysis. We carefully extracted specific columns from these tables to facilitate meaningful queries and enhance data exploration. During the data cleaning process, we examined null values in the datasets used from 2017–2020. Our analysis confirmed that there were no null values in any of the tables we utilized for those years. Additionally, we reviewed state population data we incorporated and verified that it contained no null values.

# %% [markdown]
# ### Merging Tables
# We have joined few of the above tables for some of our analysis. So, those joins were saved as a separate table which we use further along to query.

# %% [markdown]
# **Joining the tables: accident, vevent & drimpair tables for the years 2017-2020**<br>
# We joined the relevant tables to collect the data about the cause of accident and driver conditions at the time of crash together over the years.

# %%
# %%bigquery
# CREATE OR REPLACE TABLE ba775-team-project-440113.ba775_project_join_tables.accident_action_combined AS
# (WITH top_2020 AS (
#   SELECT
#     sequence_of_events_name AS Cause_of_Accident,
#     COUNT(DISTINCT consecutive_number) AS Number_of_Accidents,
#     '2020' AS Year
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020` A
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. vevent_2020` V
#     USING(consecutive_number)
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2020` D
#     USING(consecutive_number)
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY sequence_of_events_name
#   ORDER BY Number_of_Accidents DESC
# ),
# top_2019 AS (
#   SELECT
#     sequence_of_events_name AS Cause_of_Accident,
#     COUNT(DISTINCT consecutive_number) AS Number_of_Accidents,
#     '2019' AS Year
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019` A
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. vevent_2019` V
#     USING(consecutive_number)
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2019` D
#     USING(consecutive_number)
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY sequence_of_events_name
#   ORDER BY Number_of_Accidents DESC
# ),
# top_2018 AS (
#   SELECT
#     sequence_of_events_name AS Cause_of_Accident,
#     COUNT(DISTINCT consecutive_number) AS Number_of_Accidents,
#     '2018' AS Year
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018` A
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. vevent_2018` V
#     USING(consecutive_number)
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2018` D
#     USING(consecutive_number)
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY sequence_of_events_name
#   ORDER BY Number_of_Accidents DESC
# ),
# top_2017 AS (
#   SELECT
#     sequence_of_events_name AS Cause_of_Accident,
#     COUNT(DISTINCT consecutive_number) AS Number_of_Accidents,
#     '2017' AS Year
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017` A
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. vevent_2017` V
#     USING(consecutive_number)
#     LEFT JOIN `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2017` D
#     USING(consecutive_number)
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY sequence_of_events_name
#   ORDER BY Number_of_Accidents DESC
# )
# SELECT
#   Year,Cause_of_Accident,
#   SUM(CASE WHEN Year = '2020' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2020,
#   SUM(CASE WHEN Year = '2019' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2019,
#   SUM(CASE WHEN Year = '2018' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2018,
#   SUM(CASE WHEN Year = '2017' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2017,
#   MAX(SUM(Number_of_Accidents)) OVER (PARTITION BY Cause_of_Accident) AS Total_Number_of_Accidents
# FROM (
#   SELECT * FROM top_2020
#   UNION ALL
#   SELECT * FROM top_2019
#   UNION ALL
#   SELECT * FROM top_2018
#   UNION ALL
#   SELECT * FROM top_2017
# ) AS combined
# GROUP BY Cause_of_Accident,Year
# ORDER BY Total_Number_of_Accidents DESC
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Joining the tables: accident 2017-2020 & population**<br>
# We joined the relevant tables to collect the data about the total number crashes, drunk drivers, fatalities and the population for each state.

# %%
# %%bigquery
# CREATE OR REPLACE TABLE `ba775-team-project-440113.ba775_project_join_tables.state_accident_population` AS
# WITH state_accident_count AS (
#   SELECT * FROM
#   (
#     SELECT
#       '2020' AS Year,
#       state_name,
#       SUM(accident.number_of_fatalities) AS total_fatalities,
#       SUM(accident.number_of_drunk_drivers) AS total_drunk_drivers,
#       COUNT(*) AS total_accidents
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020` AS accident
#     GROUP BY state_name, Year
#
#     UNION ALL
#
#     SELECT
#       '2019' AS Year,
#       state_name,
#       SUM(accident.number_of_fatalities) AS total_fatalities,
#       SUM(accident.number_of_drunk_drivers) AS total_drunk_drivers,
#       COUNT(*) AS total_accidents
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019` AS accident
#     GROUP BY state_name, Year
#
#     UNION ALL
#
#     SELECT
#       '2018' AS Year,
#       state_name,
#       SUM(accident.number_of_fatalities) AS total_fatalities,
#       SUM(accident.number_of_drunk_drivers) AS total_drunk_drivers,
#       COUNT(*) AS total_accidents
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018` AS accident
#     GROUP BY state_name, Year
#
#     UNION ALL
#
#     SELECT
#       '2017' AS Year,
#       state_name,
#       SUM(accident.number_of_fatalities) AS total_fatalities,
#       SUM(accident.number_of_drunk_drivers) AS total_drunk_drivers,
#       COUNT(*) AS total_accidents
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017` AS accident
#     GROUP BY state_name, Year
#   )
# )
# SELECT
#   a.Year,
#   a.state_name,
#   a.total_fatalities,
#   a.total_drunk_drivers,
#   a.total_accidents,
#   p.Population AS population
# FROM
#   state_accident_count AS a
# LEFT JOIN
#   `ba775-team-project-440113.state_population_2017_2020.population` AS p
# ON
#   LOWER(a.state_name) = LOWER(p.State) AND a.Year = CAST(p.Year AS STRING);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Joining the tables: accident & parkwork**<br>
# We joined the relevant tables to collect the data about the vehicle owner type and collision trends across 2017-2020

# %%
# %%bigquery
# CREATE OR REPLACE TABLE
#     `ba775-team-project-440113.ba775_project_join_tables.accident_parkwork_combined` AS
# SELECT
#     '2017' AS year,
#     P.registered_vehicle_owner_name,
#     A.first_harmful_event_name AS collision_type
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. parkwork_2017` P
# JOIN
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017` A
# ON
#     P.consecutive_number = A.consecutive_number
# WHERE
#     P.registered_vehicle_owner_name IS NOT NULL
#
# UNION ALL
#
# SELECT
#     '2018' AS year,
#     P.registered_vehicle_owner_name,
#     A.first_harmful_event_name AS collision_type
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. parkwork_2018` P
# JOIN
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018` A
# ON
#     P.consecutive_number = A.consecutive_number
# WHERE
#     P.registered_vehicle_owner_name IS NOT NULL
#
# UNION ALL
#
# SELECT
#     '2019' AS year,
#     P.registered_vehicle_owner_name,
#     A.first_harmful_event_name AS collision_type
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. parkwork_2019` P
# JOIN
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019` A
# ON
#     P.consecutive_number = A.consecutive_number
# WHERE
#     P.registered_vehicle_owner_name IS NOT NULL
#
# UNION ALL
#
# SELECT
#     '2020' AS year,
#     P.registered_vehicle_owner_name,
#     A.first_harmful_event_name AS collision_type
# FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. parkwork_2020` P
# JOIN
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020` A
# ON
#     P.consecutive_number = A.consecutive_number
# WHERE
#     P.registered_vehicle_owner_name IS NOT NULL;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Analysis & Observation

# %% [markdown]
# ### Role of demographics in crashes recorded

# %% [markdown]
# **Crashes Across the States Over the Years**

# %% [markdown]
# **Total Crashes, Fatalities, and Drunk Drivers per 100 People (Percentage) by State for the Years 2017 to 2020**

# %% [markdown]
# **Refer to Tableau Dashboard 2: Total Crashes, Fatalities, and Drunk Drivers per 100 People (Percentage) by State for the Years 2017 to 2020**

# %%
# %%bigquery
# SELECT
#   Year,
#   state_name,
#   total_fatalities,
#   total_drunk_drivers,
#   total_accidents,
#   population,
#   ROUND((total_fatalities / population) * 100, 4) AS fatalities_percentage,
#   ROUND((total_drunk_drivers / population) * 100, 4) AS drunk_drivers_percentage,
#   ROUND((total_accidents / population) * 100, 4) AS accidents_percentage
# FROM
#   `ba775-team-project-440113.ba775_project_join_tables.state_accident_population`;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Year    state_name  total_fatalities  total_drunk_drivers  \
# 0    2017        Hawaii               104                   35
# 1    2017  Pennsylvania              1137                  277
# 2    2017    California              3807                 1037
# 3    2017         Maine               173                   48
# 4    2017      Nebraska               196                   53
# ..    ...           ...               ...                  ...
# 199  2020       Vermont                60                   18
# 200  2020  North Dakota                93                   32
# 201  2020         Idaho               212                   64
# 202  2020        Hawaii                82                   29
# 203  2020      Oklahoma               635                  171
#
#      total_accidents  population  fatalities_percentage  \
# 0                 94     1427538                 0.0073
# ...

# %% [markdown]
# **Analysis**<br>
# The analysis of U.S. traffic accident data from 2017 to 2020 reveals a complex interplay of regional, demographic, and behavioral factors influencing road safety outcomes. Rural states such as Wyoming, Montana, and South Dakota stand out with disproportionately high percentages of accidents and fatalities relative to their populations. These states often face unique challenges, including limited access to emergency services, extensive rural road networks, and harsh weather conditions, which contribute to elevated risks. Despite having lower absolute counts of accidents compared to populous states, their accident rates are magnified when measured against their smaller populations. On the other hand, states like California, Texas, and Florida exhibit the highest absolute numbers of accidents, fatalities, and drunk driving incidents, primarily due to their large populations and extensive highway systems. However, their percentages remain relatively moderate, reflecting the impact of better infrastructure and urbanization in diffusing risk.
#
# Urban centers such as New York and Massachusetts demonstrate lower accident and fatality percentages, a testament to the positive effects of public transportation systems, traffic regulations, and urban design. These regions benefit from reduced reliance on personal vehicles, leading to safer roads despite their high population density. Conversely, states with mid-sized populations, such as Louisiana and Kentucky, often display accident rates that hover between the extremes, suggesting the influence of mixed factors such as infrastructure quality, enforcement policies, and cultural attitudes toward driving.
#
# The integration of population data into this analysis enables a nuanced understanding of these dynamics. Tableau's visualization highlights distinct regional disparities, with rural states prominently showing higher accident percentages and fatalities, while urbanized states display safer road conditions. Year-over-year trends reveal fluctuations influenced by factors like seasonal weather patterns, economic activities, and policy changes.

# %% [markdown]
# ### Analysis of Crashes with Relation to Day and Time

# %% [markdown]
# **<font size="3">Most Frequent 10-minute Crash Window by Hour by Day (2017-2020)</font>**

# %% [markdown]
# **Refer to Tableau Dashboard 1: Top Crash Times by Day & Hour(2017-2020)**

# %%
# %%bigquery
# WITH combined_data AS (
#   SELECT
#     year,
#     hour_of_crash,
#     minute_of_crash,
#     day_of_week_name
#   FROM (
#     SELECT
#       2017 AS year,
#       hour_of_crash,
#       minute_of_crash,
#       day_of_week_name
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017`
#     UNION ALL
#     SELECT
#       2018 AS year,
#       hour_of_crash,
#       minute_of_crash,
#       day_of_week_name
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018`
#     UNION ALL
#     SELECT
#       2019 AS year,
#       hour_of_crash,
#       minute_of_crash,
#       day_of_week_name
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019`
#     UNION ALL
#     SELECT
#       2020 AS year,
#       hour_of_crash,
#       minute_of_crash,
#       day_of_week_name
#     FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020`
#   )
# ),
# ten_minute_windows AS (
#   SELECT
#     year,
#     day_of_week_name,
#     hour_of_crash,
#     CASE
#       WHEN minute_of_crash >= 0 AND minute_of_crash < 10 THEN '0-10'
#       WHEN minute_of_crash >= 10 AND minute_of_crash < 20 THEN '10-20'
#       WHEN minute_of_crash >= 20 AND minute_of_crash < 30 THEN '20-30'
#       WHEN minute_of_crash >= 30 AND minute_of_crash < 40 THEN '30-40'
#       WHEN minute_of_crash >= 40 AND minute_of_crash < 50 THEN '40-50'
#       WHEN minute_of_crash >= 50 AND minute_of_crash < 60 THEN '50-60'
#     END AS ten_minute_window,
#     COUNT(*) AS crash_count
#   FROM
#     combined_data
#   GROUP BY
#     year, day_of_week_name, hour_of_crash, ten_minute_window
# ),
# ranked_ten_minute_windows AS (
#   SELECT
#     year,
#     day_of_week_name,
#     hour_of_crash,
#     ten_minute_window,
#     crash_count,
#     ROW_NUMBER() OVER (PARTITION BY year, day_of_week_name, hour_of_crash ORDER BY crash_count DESC) AS row_num
#   FROM
#     ten_minute_windows
# ),
# top_ten_minute_each_hour AS (
#   SELECT
#     year,
#     day_of_week_name,
#     hour_of_crash,
#     ten_minute_window
#   FROM
#     ranked_ten_minute_windows
#   WHERE row_num = 1
# ),
# aggregate_ten_minute_windows AS (
#   SELECT
#     day_of_week_name,
#     hour_of_crash,
#     ten_minute_window,
#     SUM(crash_count) AS total_crash_count
#   FROM
#     ten_minute_windows
#   GROUP BY
#     day_of_week_name, hour_of_crash, ten_minute_window
# ),
# ranked_aggregate_ten_minute_windows AS (
#   SELECT
#     day_of_week_name,
#     hour_of_crash,
#     ten_minute_window,
#     total_crash_count,
#     ROW_NUMBER() OVER (PARTITION BY day_of_week_name, hour_of_crash ORDER BY total_crash_count DESC) AS row_num
#   FROM
#     aggregate_ten_minute_windows
# ),
# aggregate_top_ten_minute_each_hour AS (
#   SELECT
#     NULL AS year, -- Null for aggregated results
#     day_of_week_name,
#     hour_of_crash,
#     ten_minute_window
#   FROM
#     ranked_aggregate_ten_minute_windows
#   WHERE row_num = 1
# ),
# combined_results AS (
#   SELECT * FROM top_ten_minute_each_hour
#   UNION ALL
#   SELECT * FROM aggregate_top_ten_minute_each_hour
# )
# SELECT
#   COALESCE(CAST(year AS STRING), "'17-'20 Agg") AS year, -- Replace NULL with '17-'20 Agg
#   hour_of_crash,
#   day_of_week_name AS day,
#   ten_minute_window AS bucket
# FROM
#   combined_results
# ORDER BY
#   year,
#   CASE day_of_week_name
#     WHEN 'Sunday' THEN 1
#     WHEN 'Monday' THEN 2
#     WHEN 'Tuesday' THEN 3
#     WHEN 'Wednesday' THEN 4
#     WHEN 'Thursday' THEN 5
#     WHEN 'Friday' THEN 6
#     WHEN 'Saturday' THEN 7
#   END,
#   hour_of_crash;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             year  hour_of_crash       day bucket
# 0    '17-'20 Agg              0    Sunday   0-10
# 1    '17-'20 Agg              1    Sunday   0-10
# 2    '17-'20 Agg              2    Sunday   0-10
# 3    '17-'20 Agg              3    Sunday  30-40
# 4    '17-'20 Agg              4    Sunday   0-10
# ..           ...            ...       ...    ...
# 835         2020             19  Saturday  30-40
# 836         2020             20  Saturday  40-50
# 837         2020             21  Saturday  10-20
# 838         2020             22  Saturday  10-20
# 839         2020             23  Saturday  30-40
#
# [840 rows x 4 columns]

# %% [markdown]
# **Analysis**
#
# Interpretation: "On Sundays from 2017-2020, crashes between 12:00 am and 1:00 am occurred most frequently between 12:00 am and 12:10 am."
#
# The output of this query does not provide any “surprising” or “shocking” results but provides one of this dataset's most valuable applications. Our initial analysis found the top crash hour by day for only 2020 (i.e., “On Saturdays in 2020, the most prevalent hour for crashes was 11:00 pm”). While this finding alone could be seen as beneficial for emergency services to prepare for the “most dangerous” hours on the road, some light experimentation with SQL led us to realize we could not only easily scale this to all hours of the day but do it for all years (Individually and on an aggregate level) and even identify the 10-minute increment within that top hour when crashes occurred most frequently.
#
# With this output, we aimed to put it into practical use by creating an interactive dashboard that can be filtered by day and year to identify when crashes are most likely to occur by hovering over a point for a given hour. The most useful application would come when filtering for *‘17-’20 Agg* as this derives insights from the most data and provides the most generalized output for a given day and time.
#
# With this dashboard, the vision is for law enforcement to pull it up daily and get an idea of when crashes are most likely to happen so they can optimize their prevention and response efforts. Whether this means getting more officers on an area’s most crash-prone roads or making more EMS available during peak crash windows, a heightened degree of readiness can significantly reduce car crashes and prevent these crashes from turning fatal.
#
# Given that this tool relies on only four years of data, it is not perfect or foolproof. However, continuously adding crash data over time will increase the statistical backing of these findings and make the tool more and more reliable.

# %% [markdown]
# **<font size="3">Crashes by Year 2017-2020</font>**

# %%
# %%bigquery
# SELECT
#   year_of_crash,
#   COUNT(*) AS total_crash_count
# FROM (
#   SELECT '2020' AS year_of_crash
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020`
#   UNION ALL
#   SELECT '2019' AS year_of_crash
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019`
#   UNION ALL
#   SELECT '2018' AS year_of_crash
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018`
#   UNION ALL
#   SELECT '2017' AS year_of_crash
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017`
# )
# GROUP BY
#   year_of_crash
# ORDER BY
#   year_of_crash;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   year_of_crash  total_crash_count
# 0          2017              34299
# 1          2018              33692
# 2          2019              33242
# 3          2020              35451

# %% [markdown]
# **Analysis**
#
# Comparing the total crash counts across years revealed that all years had a similar number of annual crashes, with 2020 having a *slightly* greater number of crashes than the 2017-2019 average. Specifically, 2020 had 1,707 more fatal crashes than the 2017-2019 average, amounting to a 5.06% increase. Statistically, this value does not seem overly notable. However, when taken in context, it is incredibly notable as this entails that at least 1,707 additional people lost their lives with this increase.
# Obviously, 2020 functioned as an outlier year because it was the height of the COVID-19 pandemic. With this, the spike in crashes in 2020 likely resulted from “lockdown fatigue,” which set in starting in May and entailed people no longer staying home, but venturing out in search of stimulus. Given that people were not working as much, this led to more people on the road at all times of the day and more crashes. Increases in alcohol consumption during this time also likely contributed to this, but that is not the focus of this particular analysis.
#
# From this, the broad takeaway is that while an anomaly like the pandemic is not currently foreseeable, one can conclude that roads are more unsafe when there is an abnormal influx of cars on the road. Whether due to major travel holidays, large sporting events/concerts in a city, public transit shutdowns, gas price changes, road construction, etc., emergency services should be on heightened alert when factors that increase road traffic are present.

# %% [markdown]
# **<font size="3">Monthly Crashes by Individual Year (2017-2020)</font>**

# %% [markdown]
# **Refer to Tableau Dashboard 1: Monthly Crash Counts by Year(2017-2020)**

# %%
# %%bigquery
# SELECT
#   month_of_crash_name AS month,
#   SUM(CASE WHEN year_of_crash = '2017' THEN 1 ELSE 0 END) AS crash_count_2017,
#   SUM(CASE WHEN year_of_crash = '2018' THEN 1 ELSE 0 END) AS crash_count_2018,
#   SUM(CASE WHEN year_of_crash = '2019' THEN 1 ELSE 0 END) AS crash_count_2019,
#   SUM(CASE WHEN year_of_crash = '2020' THEN 1 ELSE 0 END) AS crash_count_2020
# FROM (
#   SELECT '2020' AS year_of_crash, month_of_crash_name
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020`
#   UNION ALL
#   SELECT '2019' AS year_of_crash, month_of_crash_name
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019`
#   UNION ALL
#   SELECT '2018' AS year_of_crash, month_of_crash_name
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018`
#   UNION ALL
#   SELECT '2017' AS year_of_crash, month_of_crash_name
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017`
# )
# GROUP BY
#   month_of_crash_name
# ORDER BY
#   CASE month_of_crash_name
#     WHEN 'January' THEN 1
#     WHEN 'February' THEN 2
#     WHEN 'March' THEN 3
#     WHEN 'April' THEN 4
#     WHEN 'May' THEN 5
#     WHEN 'June' THEN 6
#     WHEN 'July' THEN 7
#     WHEN 'August' THEN 8
#     WHEN 'September' THEN 9
#     WHEN 'October' THEN 10
#     WHEN 'November' THEN 11
#     WHEN 'December' THEN 12
#   END;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         month  crash_count_2017  crash_count_2018  crash_count_2019  \
# 0     January              2612              2613              2457
# 1    February              2299              2309              2187
# 2       March              2666              2593              2528
# 3       April              2754              2553              2598
# 4         May              2894              2965              2893
# 5        June              3007              3003              2902
# 6        July              3207              3031              3013
# 7      August              2958              2991              3067
# 8   September              3091              3045              3069
# 9     October              3090              3092              2950
# 10   November              2879              2767              2820
# 11   December              2842              2730              2758
#
# ...

# %% [markdown]
# **Analysis**
#
# When examining this output, it is clear that fatal crashes are at their lowest in the winter months of January and February before increasing steadily until July, plateauing until October, and then steadily decreasing from November on. While 2020’s peak period was more accentuated, it followed roughly the same trend as 2017-2019, indicating that these trends tend to hold, regardless of circumstance.
#
# These results are not surprising, as it is logical that more crashes would occur in the warmer months: People travel more, students are not in school, and the population is generally more inclined to be mobile in pursuit of warm-weather activities unavailable in the winter months. However, the strong definition of these trends is what stands out. The increase in crashes in the summer months is not an anomaly but entirely predictable.
#
# It is likely impossible to stop this trend, but measures should be taken to mitigate it. Whether that be an increased emergency services presence on the road, increased fines for traffic violations (Speeding, DUI, reckless driving, etc.), or increased education/training for new drivers, anything to increase crash response, deter lousy driving, and/or improve driving abilities among the population, would make a positive impact in decreasing fatal crashes.

# %% [markdown]
# ### Relation Between Crashes and Driving Conditions

# %% [markdown]
# **Top Causes of Crashes**

# %% [markdown]
# **Refer to Tableau Dashboard 1: Number of Accidents for Top 10 Causes of Accidents(2017-2020)**

# %%
# %%bigquery
# SELECT
#   Cause_of_Accident,
#     SUM(Number_of_Accidents_2020) AS Number_of_Accidents_2020,
#   SUM(Number_of_Accidents_2019) AS Number_of_Accidents_2019,
#   SUM(Number_of_Accidents_2018) AS Number_of_Accidents_2018,
#   SUM(Number_of_Accidents_2017) AS Number_of_Accidents_2017,
#   SUM(Total_Number_of_Accidents) AS Total_Number_of_Accidents
# FROM ba775-team-project-440113.ba775_project_join_tables.accident_action_combined
# GROUP BY Cause_of_Accident
# LIMIT 10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             Cause_of_Accident  Number_of_Accidents_2020  \
# 0     Ran Off Roadway - Right                      3362
# 1  Motor Vehicle In-Transport                      3180
# 2           Rollover/Overturn                      2665
# 3      Ran Off Roadway - Left                      2539
# 4            Cross Centerline                      2151
# 5        Tree (Standing Only)                      1543
# 6         Re-entering Roadway                       942
# 7  Utility Pole/Light Support                       592
# 8                  Pedestrian                       553
# 9                        Curb                       536
#
#    Number_of_Accidents_2019  Number_of_Accidents_2018  \
# 0                      2862                      2960
# 1                      2887                      2862
# 2                      2233                      2277
# 3                      2210                      2230
# ...

# %%
# %%bigquery
# WITH accidents_by_year AS (
#   SELECT
#     '2017' AS Year,
#     condition_impairment_at_time_of_crash_driver_name AS Driver_Condition,
#     COUNT(consecutive_number) AS Number_of_Accidents
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2017`
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY condition_impairment_at_time_of_crash_driver_name
#
#   UNION ALL
#
#   SELECT
#     '2018' AS Year,
#     condition_impairment_at_time_of_crash_driver_name AS Driver_Condition,
#     COUNT(consecutive_number) AS Number_of_Accidents
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2018`
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY condition_impairment_at_time_of_crash_driver_name
#
#   UNION ALL
#
#   SELECT
#     '2019' AS Year,
#     condition_impairment_at_time_of_crash_driver_name AS Driver_Condition,
#     COUNT(consecutive_number) AS Number_of_Accidents
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2019`
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY condition_impairment_at_time_of_crash_driver_name
#
#   UNION ALL
#
#   SELECT
#     '2020' AS Year,
#     condition_impairment_at_time_of_crash_driver_name AS Driver_Condition,
#     COUNT(consecutive_number) AS Number_of_Accidents
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. drimpair_2020`
#   WHERE condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Not Reported%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%None/%'
#     AND condition_impairment_at_time_of_crash_driver_name NOT LIKE '%Unknown%'
#   GROUP BY condition_impairment_at_time_of_crash_driver_name
# )
#
# SELECT
#   Driver_Condition,
#   SUM(CASE WHEN Year = '2017' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2017,
#   SUM(CASE WHEN Year = '2018' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2018,
#   SUM(CASE WHEN Year = '2019' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2019,
#   SUM(CASE WHEN Year = '2020' THEN Number_of_Accidents ELSE 0 END) AS Number_of_Accidents_2020
# FROM accidents_by_year
# GROUP BY Driver_Condition
# ORDER BY SUM(Number_of_Accidents) DESC
# LIMIT 5;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                     Driver_Condition  \
# 0  Under the Influence of Alcohol, Drugs or Medic...
# 1                                 Asleep or Fatigued
# 2                                      Ill, Blackout
# 3                          Other Physical Impairment
# 4                   Physical Impairment - No Details
#
#    Number_of_Accidents_2017  Number_of_Accidents_2018  \
# 0                      5765                      5407
# 1                       733                       704
# 2                       606                       541
# 3                       499                       319
# 4                       197                       213
#
#    Number_of_Accidents_2019  Number_of_Accidents_2020
# 0                      5293                      6249
# 1                       640                       582
# 2                       621                       596
# ...

# %% [markdown]
# **Analysis**
#
# Three major causes of accidents—running off the roadway (both right and left), motor vehicle in-transport events, and vehicle rollovers or overturns—consistently accounted for a significant number of incidents over the years. For instance, "Ran Off Roadway - Right" accidents increased from 2,862 in 2019 to 3,362 in 2020, while similar patterns are seen in motor vehicle in-transport events and rollovers. Other notable causes include crossing the centerline and collisions with standing objects like trees. A commonality across these incidents is the frequent impairment of drivers due to alcohol, drugs, or medications, which significantly exacerbates these risks. This highlights the urgent need for stricter enforcement against drunk driving, awareness campaigns, and preventive measures. Additionally, enhancing road safety awareness and promoting vehicle stability technologies can help reduce rollover and lane departure incidents, creating safer roads for everyone.

# %% [markdown]
# **Patterns in Occurence of Case of Drunk Driving Fatality**

# %%
# %%bigquery
# SELECT
#   day_of_week_name,
#   SUM(CASE WHEN year = 2017 THEN number_of_drunk_drivers ELSE 0 END) AS drunk_drivers_2017,
#   SUM(CASE WHEN year = 2018 THEN number_of_drunk_drivers ELSE 0 END) AS drunk_drivers_2018,
#   SUM(CASE WHEN year = 2019 THEN number_of_drunk_drivers ELSE 0 END) AS drunk_drivers_2019,
#   SUM(CASE WHEN year = 2020 THEN number_of_drunk_drivers ELSE 0 END) AS drunk_drivers_2020
# FROM (
#   SELECT
#     day_of_week_name, number_of_drunk_drivers, 2017 AS year
#   FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2017`
#   UNION ALL
#   SELECT
#     day_of_week_name, number_of_drunk_drivers, 2018 AS year
#   FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2018`
#   UNION ALL
#   SELECT
#     day_of_week_name, number_of_drunk_drivers, 2019 AS year
#   FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2019`
#   UNION ALL
#   SELECT
#     day_of_week_name, number_of_drunk_drivers, 2020 AS year
#   FROM
#     `bigquery-public-data.nhtsa_traffic_fatalities. accident_2020`
# )
# GROUP BY
#   day_of_week_name
# ORDER BY
#   drunk_drivers_2020 DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   day_of_week_name  drunk_drivers_2017  drunk_drivers_2018  \
# 0         Saturday                2214                2071
# 1           Sunday                2120                1947
# 2           Friday                1458                1341
# 3         Thursday                 995                 940
# 4        Wednesday                 872                 838
# 5           Monday                 932                 961
# 6          Tuesday                 877                 807
#
#    drunk_drivers_2019  drunk_drivers_2020
# 0                2070                2152
# 1                1913                1991
# 2                1366                1413
# 3                 907                1026
# 4                 820                1006
# 5                 868                 945
# 6                 858                 882

# %% [markdown]
# **Analysis**<br>
# The output of this analysis was completely unsurprising but interesting to see. In terms of drunk drivers and total deaths, Saturdays saw the highest number, followed by Sunday, Friday, Thursday, and Wednesday. The only variation in order came between Monday and Tuesday, where Monday saw a higher number of drunk drivers than Tuesday but a slightly lower number of deaths.
#
# In the context of drunk drivers, this result is highly intuitive, as Saturday reached the top spot by accounting for those who drove drunk after their Friday night out that spilled into Saturday morning while also claiming those who drove drunk on Saturday but before Sunday morning. This logic subsequently applies to Sunday, Friday, and Thursday when one understands the social drinking dynamics of the United States, where Saturday and Friday are considered the top drinking nights, followed by Sunday and Thursday as people tend to drink to excess on and around the weekends when the majority of citizens see their work responsibilities lessen or pause until Monday.
#
# The similar order of total death count follows a similar pattern to drunk driving, and with this likely exists a correlation between deaths and drunk drivers. However, this trend in total deaths likely also results from the fact that people are often more likely to travel to unfamiliar places on and around weekends or go to social events in groups that cause additional distractions.

# %% [markdown]
# ### Crash Involvement Characteristics

# %% [markdown]
# **Crash Count by Vehicle Ownership Type(2017-2020)**

# %% [markdown]
# **Refer to Tableau Dashboard 2: Fatal Crashes by Vehicle Owner Type(2017-2020)**

# %%
# %%bigquery
# SELECT
#     year,
#     registered_vehicle_owner_name AS vehicle_owner_type,
#     COUNT(*) AS fatal_crash_count
# FROM
#     `ba775-team-project-440113.ba775_project_join_tables.accident_parkwork_combined`
# WHERE
#     registered_vehicle_owner_name IS NOT NULL
# GROUP BY
#     year, vehicle_owner_type
# ORDER BY
#     year, fatal_crash_count DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year                                 vehicle_owner_type  fatal_crash_count
# 0   2017  Driverless/Motor Vehicle Parked/Stopped Off Ro...               1340
# 1   2017  Vehicle Registered as Business/Company/Governm...                 34
# 2   2017             Not Applicable, Vehicle Not Registered                  6
# 3   2018  Driverless/Motor Vehicle Parked/Stopped Off Ro...               1296
# 4   2018  Vehicle Registered as Business/Company/Governm...                 28
# 5   2018             Not Applicable, Vehicle Not Registered                  4
# 6   2019  Driverless/Motor Vehicle Parked/Stopped Off Ro...               1328
# 7   2019  Vehicle Registered as Business/Company/Governm...                 30
# 8   2019             Not Applicable, Vehicle Not Registered                  6
# 9   2019                                            Unknown                  1
# ...

# %% [markdown]
# **Top 3 Collision Types and Crash Counts for Driverless/Parked Vehicles (2017-2020)**

# %% [markdown]
# **Refer to Tableau Dashboard 2: Crash Count by Collision Type for Driverless Accidents(2017-2020)**

# %%
# %%bigquery
# WITH ranked_collisions AS (
#     SELECT
#         year,
#         collision_type,
#         COUNT(*) AS crash_count,
#         RANK() OVER (PARTITION BY year ORDER BY COUNT(*) DESC) AS rank
#     FROM
#         `ba775-team-project-440113.ba775_project_join_tables.accident_parkwork_combined`
#     WHERE
#         registered_vehicle_owner_name = 'Driverless/Motor Vehicle Parked/Stopped Off Roadway'
#     GROUP BY
#         year, collision_type
# )
# SELECT
#     year,
#     collision_type,
#     crash_count
# FROM
#     ranked_collisions
# WHERE
#     rank <= 3
# ORDER BY
#     year, crash_count DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     year              collision_type  crash_count
# 0   2017        Parked Motor Vehicle          561
# 1   2017  Motor Vehicle In-Transport          331
# 2   2017                  Pedestrian          121
# 3   2018        Parked Motor Vehicle          533
# 4   2018  Motor Vehicle In-Transport          305
# 5   2018                  Pedestrian          124
# 6   2019        Parked Motor Vehicle          602
# 7   2019  Motor Vehicle In-Transport          263
# 8   2019                  Pedestrian          122
# 9   2020        Parked Motor Vehicle          630
# 10  2020  Motor Vehicle In-Transport          345
# 11  2020                  Pedestrian          123

# %% [markdown]
# **Analysis**<br>
# By focusing on crashes involving "Driverless/Motor Vehicle Parked/Stopped Off Roadway," the analysis highlights a surprising trend: parked or stopped vehicles are associated with a substantial number of fatal crashes. The most frequent collision type for these vehicles is "Parked Motor Vehicle," which increased from 561 incidents in 2017 to 630 in 2020. This trend challenges the assumption that fatal accidents primarily involve moving vehicles. Other collision types, such as "Motor Vehicle In-Transport" and "Pedestrian," further reveal risks when parked vehicles interact with active traffic or vulnerable road users. This insight is critical, as it identifies parked vehicles—often overlooked—as significant contributors to fatal accidents. Understanding these risks emphasizes the need for targeted interventions to address hazardous parking behaviors and improve safety near stationary vehicles.
#
# Policymakers should focus on stricter parking regulations, enhanced road design, and increased visibility around parked vehicles to reduce these risks. Additionally, raising awareness of the dangers posed by improperly parked vehicles and collecting more granular crash data can support effective safety initiatives.

# %% [markdown]
# ### Effect of Weather on Number of Accidents

# %% [markdown]
# **Effect of Weather Conditions on Number of Accidents**

# %% [markdown]
# **Refer to Tableau Dashboard 2: Accident Count by Weather Condition and Location Category(2017-2020)**

# %%
# %%bigquery
# SELECT Year,land_use_name as Type_of_Location,COUNT(consecutive_number) as Number_of_Accidents
# FROM ba775-team-project-440113.ba775_project_join_tables.accident_weather_over_years
# GROUP BY Year,land_use_name
# ORDER BY Number_of_Accidents DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     Year                   Type_of_Location  Number_of_Accidents
# 0   2020                              Urban                20123
# 1   2018                              Urban                19306
# 2   2019                              Urban                18683
# 3   2017                              Urban                18661
# 4   2017                              Rural                15555
# 5   2020                              Rural                14845
# 6   2019                              Rural                14454
# 7   2018                              Rural                14290
# 8   2020                       Not Reported                  348
# 9   2019  Trafficway Not in State Inventory                   76
# 10  2020  Trafficway Not in State Inventory                   69
# 11  2020                            Unknown                   66
# ...

# %% [markdown]
# **Analysis**
#
# From the above result, given the range in numbers across locations, we can focus on crashes happening in Rural and Urban areas to check the effect of weather on the number of crashes happening.

# %%
# %%bigquery
# SELECT
#   Year, atmospheric_conditions_1_name as weather_conditions,
#   land_use_name as location_category,
#   COUNT(consecutive_number) AS accident_count
# FROM ba775-team-project-440113.ba775_project_join_tables.accident_weather_over_years
# WHERE (atmospheric_conditions_1_name!='Clear' and land_use_name in ('Urban','Rural'))
# GROUP BY Year, atmospheric_conditions_1_name, land_use_name
# ORDER BY accident_count DESC,Year DESC
# LIMIT 30;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     Year weather_conditions location_category  accident_count
# 0   2018             Cloudy             Urban            2737
# 1   2019             Cloudy             Urban            2625
# 2   2017             Cloudy             Urban            2625
# 3   2020             Cloudy             Urban            2490
# 4   2017             Cloudy             Rural            2348
# 5   2019             Cloudy             Rural            2313
# 6   2018             Cloudy             Rural            2287
# 7   2020             Cloudy             Rural            2047
# 8   2018               Rain             Urban            1521
# 9   2020               Rain             Urban            1452
# 10  2020             Others             Urban            1446
# 11  2019               Rain             Urban            1414
# 12  2018             Others             Urban            1375
# ...

# %% [markdown]
# **Analysis**<br>
# The table highlights that cloudy weather is consistently associated with the highest number of accidents across both rural and urban areas. Year-wise trends show urban areas reporting slightly higher accident counts under cloudy conditions, with accidents decreasing from 2,737 in 2018 to 2,490 in 2020. Similarly, rural areas saw a decline from 2,348 in 2017 to 2,047 in 2020. Rainy conditions also contribute significantly to accident rates, particularly in urban areas, where accidents peaked at 1,521 in 2018 and dropped to 1,452 in 2020. Rural areas followed a similar trend, with accidents under rain decreasing from 1,143 in 2018 to 1,134 in 2020.
#
# Less frequent weather conditions, such as fog, smog, or smoke, are notably impactful in urban settings, potentially due to reduced visibility, while the lowest accident counts are observed during heavy crosswinds, sleet, or hail likely due to their infrequency and the tendency of drivers to avoid travel in such conditions. These trends underscore the importance of enhancing visibility measures and raising driver awareness during adverse weather conditions. Furthermore, focusing on urban accident prevention during common weather events like rain and cloudiness could significantly improve overall safety.

# %%
# %%bigquery
# SELECT
#   Year, light_condition_name as light_conditions,
#   land_use_name as location_category,
#   COUNT(consecutive_number) AS accident_count
# FROM ba775-team-project-440113.ba775_project_join_tables.accident_weather_over_years
# WHERE (atmospheric_conditions_1_name!='Clear' and land_use_name in ('Urban','Rural'))
# GROUP BY Year, light_condition_name, land_use_name
# ORDER BY accident_count DESC,Year DESC
# LIMIT 20;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     Year    light_conditions location_category  accident_count
# 0   2017            Daylight             Rural            2773
# 1   2019            Daylight             Rural            2763
# 2   2018            Daylight             Rural            2726
# 3   2020            Daylight             Rural            2563
# 4   2018            Daylight             Urban            2482
# 5   2019            Daylight             Urban            2216
# 6   2020            Daylight             Urban            2214
# 7   2017            Daylight             Urban            2173
# 8   2018  Dark - Not Lighted             Rural            1914
# 9   2017  Dark - Not Lighted             Rural            1907
# 10  2018      Dark - Lighted             Urban            1842
# 11  2020      Dark - Lighted             Urban            1831
# 12  2019  Dark - Not Lighted             Rural            1808
# ...

# %% [markdown]
# **Analysis**<br>
# The data shows that "Daylight" conditions result in the highest accident counts in both urban and rural areas. Rural areas saw a decline in accident counts, from 2,773 in 2017 to 2,563 in 2020, while urban areas dropped from 2,173 in 2017 to 2,214 in 2020, with a spike to 2,482 in 2018. These changes may reflect improvements in road safety or shifts in traffic patterns. In "Dark - Lighted" urban areas, accident counts rose from 1,695 in 2017 to 1,842 in 2018 but declined slightly to 1,831 by 2020. This suggests that while street lighting helps, reduced nighttime visibility and other factors still contribute to accidents.In "Dark - Not Lighted" conditions, rural areas consistently showed high accident counts, peaking at 1,914 in 2018 before dropping to 1,761 in 2020. Urban areas also saw a decline, from 1,199 in 2017 to 1,204 in 2020, reflecting some stabilization.
#
# Year-wise trends show accidents are most frequent during daylight hours due to high traffic, while nighttime risks remain significant, particularly in poorly lit rural areas. These findings highlight the need for improved infrastructure and safer driving practices across varying light conditions.

# %% [markdown]
# ### Analysis of People Affected by the Crash

# %% [markdown]
# **Refer to Tableau Dashboard 1: Number of Fatalities Across States(2017-2020)**

# %%
# %%bigquery
# SELECT *
# FROM (
#   SELECT
#     '2020' AS Year, state_name, COUNT(state_name) AS Count
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2020`
#   GROUP BY state_name, Year
#
#   UNION ALL
#
#   SELECT
#     '2019' AS Year, state_name, COUNT(state_name) AS Count
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2019`
#   GROUP BY state_name, Year
#
#   UNION ALL
#
#   SELECT
#     '2018' AS Year, state_name, COUNT(state_name) AS Count
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2018`
#   GROUP BY state_name, Year
#
#   UNION ALL
#
#   SELECT
#     '2017' AS Year, state_name, COUNT(state_name) AS Count
#   FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2017`
#   GROUP BY state_name, Year
# )
# ORDER BY Year DESC, Count DESC
# LIMIT 10;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    Year      state_name  Count
# 0  2020      California   1211
# 1  2020         Florida    937
# 2  2020           Texas    854
# 3  2020        New York    319
# 4  2020         Georgia    318
# 5  2020         Arizona    286
# 6  2020  North Carolina    269
# 7  2020        Michigan    230
# 8  2020        Illinois    215
# 9  2020  South Carolina    213

# %% [markdown]
# **Analysis**<br>
# The analysis of year-wise accident data reveals significant trends in accident counts across various states. The top five states with the highest accident totals are California, Florida, Texas, New York, and Georgia, all of which exhibit consistently high accident rates, particularly in California, which reported the highest total of 4881 accidents over the four years. These states, particularly California and Florida, show steady accident counts with slight fluctuations year-over-year, reflecting their larger populations and higher traffic volumes. Texas and New York follow closely, with Texas seeing a consistent but moderate increase in accidents from 2017 to 2020.
# On the other hand, the bottom five states—North Dakota, Vermont, Wyoming, Montana, and Maine—report the lowest accident counts, often under 50 per year. These states have small populations and lower traffic density, which likely contributes to their minimal accident totals. For instance, North Dakota consistently had only 7 to 9 accidents annually, indicating fewer incidents overall. The patterns suggest that more populous and urbanized states tend to experience higher accident rates, while smaller, rural states with less traffic face lower accident counts.

# %% [markdown]
# **Age Groups and Gender of People Most Affected by the Crashes**

# %% [markdown]
# **Refer to Tableau Dashboard 2: People affected by Accidents by Age Group and Gender(2017-2020)**

# %%
# %%bigquery
# SELECT '2020' AS Year,
#        CASE
#            WHEN CAST(age AS INT64) < 18 THEN 'Under 18'
#            WHEN CAST(age AS INT64) BETWEEN 18 AND 25 THEN '18-25'
#            WHEN CAST(age AS INT64) BETWEEN 26 AND 35 THEN '26-35'
#            WHEN CAST(age AS INT64) BETWEEN 36 AND 45 THEN '36-45'
#            WHEN CAST(age AS INT64) BETWEEN 46 AND 60 THEN '46-60'
#            WHEN CAST(age AS INT64) > 60 THEN 'Over 60'
#            ELSE 'Not Reported'
#        END AS age_group,
#        SUM(CASE WHEN sex_name = 'Male' THEN 1 ELSE 0 END) AS male_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Female' THEN 1 ELSE 0 END) AS female_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Not Reported' THEN 1 ELSE 0 END) AS preferNotToSay_fatal_accidents,
#        SUM(CASE WHEN sex_name IN ('Male', 'Female', 'Not Reported') THEN 1 ELSE 0 END) AS total_fatal_accidents
# FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2020`
# WHERE SAFE_CAST(age AS INT64) IS NOT NULL
# GROUP BY age_group
# UNION ALL
# SELECT '2019' AS Year,
#        CASE
#            WHEN CAST(age AS INT64) < 18 THEN 'Under 18'
#            WHEN CAST(age AS INT64) BETWEEN 18 AND 25 THEN '18-25'
#            WHEN CAST(age AS INT64) BETWEEN 26 AND 35 THEN '26-35'
#            WHEN CAST(age AS INT64) BETWEEN 36 AND 45 THEN '36-45'
#            WHEN CAST(age AS INT64) BETWEEN 46 AND 60 THEN '46-60'
#            WHEN CAST(age AS INT64) > 60 THEN 'Over 60'
#            ELSE 'Not Reported'
#        END AS age_group,
#        SUM(CASE WHEN sex_name = 'Male' THEN 1 ELSE 0 END) AS male_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Female' THEN 1 ELSE 0 END) AS female_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Not Reported' THEN 1 ELSE 0 END) AS preferNotToSay_fatal_accidents,
#        SUM(CASE WHEN sex_name IN ('Male', 'Female', 'Not Reported') THEN 1 ELSE 0 END) AS total_fatal_accidents
# FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2019`
# WHERE SAFE_CAST(age AS INT64) IS NOT NULL
# GROUP BY age_group
# UNION ALL
# SELECT '2018' AS Year,
#        CASE
#            WHEN CAST(age AS INT64) < 18 THEN 'Under 18'
#            WHEN CAST(age AS INT64) BETWEEN 18 AND 25 THEN '18-25'
#            WHEN CAST(age AS INT64) BETWEEN 26 AND 35 THEN '26-35'
#            WHEN CAST(age AS INT64) BETWEEN 36 AND 45 THEN '36-45'
#            WHEN CAST(age AS INT64) BETWEEN 46 AND 60 THEN '46-60'
#            WHEN CAST(age AS INT64) > 60 THEN 'Over 60'
#            ELSE 'Not Reported'
#        END AS age_group,
#        SUM(CASE WHEN sex_name = 'Male' THEN 1 ELSE 0 END) AS male_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Female' THEN 1 ELSE 0 END) AS female_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Not Reported' THEN 1 ELSE 0 END) AS preferNotToSay_fatal_accidents,
#        SUM(CASE WHEN sex_name IN ('Male', 'Female', 'Not Reported') THEN 1 ELSE 0 END) AS total_fatal_accidents
# FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2018`
# WHERE SAFE_CAST(age AS INT64) IS NOT NULL
# GROUP BY age_group
# UNION ALL
# SELECT '2017' AS Year,
#        CASE
#            WHEN CAST(age AS INT64) < 18 THEN 'Under 18'
#            WHEN CAST(age AS INT64) BETWEEN 18 AND 25 THEN '18-25'
#            WHEN CAST(age AS INT64) BETWEEN 26 AND 35 THEN '26-35'
#            WHEN CAST(age AS INT64) BETWEEN 36 AND 45 THEN '36-45'
#            WHEN CAST(age AS INT64) BETWEEN 46 AND 60 THEN '46-60'
#            WHEN CAST(age AS INT64) > 60 THEN 'Over 60'
#            ELSE 'Not Reported'
#        END AS age_group,
#        SUM(CASE WHEN sex_name = 'Male' THEN 1 ELSE 0 END) AS male_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Female' THEN 1 ELSE 0 END) AS female_fatal_accidents,
#        SUM(CASE WHEN sex_name = 'Not Reported' THEN 1 ELSE 0 END) AS preferNotToSay_fatal_accidents,
#        SUM(CASE WHEN sex_name IN ('Male', 'Female', 'Not Reported') THEN 1 ELSE 0 END) AS total_fatal_accidents
# FROM `bigquery-public-data.nhtsa_traffic_fatalities. pbtype_2017`
# WHERE SAFE_CAST(age AS INT64) IS NOT NULL
# GROUP BY age_group
# ORDER BY
#     CASE age_group
#         WHEN 'Under 18' THEN 1
#         WHEN '18-25' THEN 2
#         WHEN '26-35' THEN 3
#         WHEN '36-45' THEN 4
#         WHEN '46-60' THEN 5
#         WHEN 'Over 60' THEN 6
#         ELSE 7
#     END;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     Year age_group  male_fatal_accidents  female_fatal_accidents  \
# 0   2017  Under 18                   334                     178
# 1   2018  Under 18                   276                     174
# 2   2019  Under 18                   267                     155
# 3   2020  Under 18                   286                     149
# 4   2017     18-25                   583                     208
# 5   2018     18-25                   623                     226
# 6   2019     18-25                   500                     203
# 7   2020     18-25                   523                     229
# 8   2017     26-35                   781                     297
# 9   2018     26-35                   847                     341
# 10  2019     26-35                   888                     355
# 11  2020     26-35                   956                     370
# ...

# %% [markdown]
# **Analysis**<br>
# The analysis of fatal accident data from 2017 to 2020 shows notable patterns based on age groups and gender. The 46-60 age group consistently reports the highest number of fatalities, with figures rising slightly from 2,125 in 2017 to 2,135 in 2020. Males account for the majority of fatalities in this group, making up around 77% of the total in 2020. Similarly, other age groups such as 26-35 and 36-45 also see high fatality counts, predominantly involving males.
# On the other hand, the Under 18 age group has the least fatalities, with numbers staying below 500 annually. In 2020, the group had 437 total fatalities, with males still accounting for the majority. Across all age groups, males consistently represent a larger share of fatal accidents, especially in older age groups like 46-60 and 26-35.
# In summary, the highest fatal accidents occur in the 46-60 age group, with males being the predominant demographic, while the Under 18 group experiences the least fatalities, highlighting a gendered trend in accident fatalities. (edited)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, our analysis of 2017-2020 traffic accident data provided valuable insights into the factors contributing to road fatalities and actionable recommendations to improve road safety. By expanding the analysis across multiple years, we identified consistent trends in driving conditions, environmental factors, and temporal patterns, confirming our initial hypothesis. Key findings revealed that environmental factors, such as location, lighting, and weather, significantly influence crash severity. Rural areas were particularly vulnerable, facing elevated risks due to poor lighting, harsh weather, and limited emergency services. Temporal trends showed high-risk periods, including late nights and weekends, while regional disparities highlighted the challenges faced by rural states compared to urbanized areas, where public transportation and better infrastructure contribute to safer roads despite higher population densities.
#
# To address these risks, we recommend enhanced police enforcement during identified high-risk times and locations, infrastructure improvements to mitigate rural road hazards and improve lighting, and public awareness campaigns to educate drivers about safe practices, including proper parking and driving during peak seasons. Additionally, future steps should focus on continuous data integration by incorporating new and recent years of data. This approach will refine predictions, improve the reliability of insights, and ensure safety measures remain adaptive to evolving traffic patterns and societal changes.

# %% [markdown]
# ## Challenges

# %% [markdown]
# Data Integration Across Multiple Years:
#
# Combining multi-year datasets posed structural challenges, primarily due to variations in schema and column names between years. This required careful alignment of data fields to ensure consistency across the dataset. While the data itself was relatively clean, differences in formatting and categorical classifications (e.g., naming conventions for vehicle types or collision categories) required thoughtful standardization. Ensuring the datasets were seamlessly integrated was essential for accurate analysis and comparison across years.
#
# Managing Large Volumes of Data:
#
# The dataset spanned thousands of records with numerous columns for each year, making it impractical to analyze everything comprehensively. This required a systematic approach to identify the most relevant variables while ensuring that no critical insights were overlooked. We utilized exploratory data analysis techniques and visualization tools to narrow down the data to key features that aligned with our objectives.
#
# Crafting a Clear Narrative from Complex Data:
#
# With so much data available, one of the biggest challenges was distilling it into a cohesive and impactful narrative. The variety of potential insights required thoughtful prioritization to highlight findings that were both significant and actionable. Striking a balance between technical rigor and accessibility for a wider audience required multiple iterations of interpretation and storytelling.

# %% [markdown]
# ## References

# %% [markdown]
# * [U.S. Traffic Accident 2020 Data: Big Query Dataset ](https://console.cloud.google.com/bigquery?ws=!1m4!1m3!3m2!1sbigquery-public-data!2snhtsa_traffic_fatalities):
# * https://openai.com/index/chatgpt/
# * https://www.census.gov/programs-surveys/popest/technical-documentation/research/evaluation-estimates/2020-evaluation-estimates/2010s-state-total.html
# * Lecture slides and Notebooks
# * Datacamp

# %% [markdown]
# ## Tableau Dashboard

# %% [markdown]
# 1. https://public.tableau.com/views/BA775-A01/AnalyzingFatalU_S_TrafficAccidentPatternsFrom2017-2020InsightsforImprovedRoadSafety1?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link<br>
# 2. https://public.tableau.com/views/BA775-A01/AnalyzingFatalU_S_TrafficAccidentPatternsFrom2017-2020InsightsforImprovedRoadSafety2?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# **Tableau Dashboard 1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tableau Dashboard 2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Generative AI Disclosure

# %% [markdown]
# We utilized Generative AI to assist our project in the following areas:
#
# * Code debugging and optimization: We used ChatGPT to enhance syntax, optimize code, and debug issues during the project.
# * Syntax and language refinement: ChatGPT was used to improve the written report, including spelling checks, grammar corrections, and refining professional expression.
#
# All AI-assisted content was thoroughly reviewed by our group to ensure originality, accuracy, and compliance with academic integrity guidelines.
