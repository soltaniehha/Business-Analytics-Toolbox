# %% [markdown]
# # Exercise 1
# Let's run a few queries on our newly added tables.

# %%
# This cell is to enable the "hint" functionality. After each question there is a cell with either a hint about the correct answer or the solution. 
from IPython.display import Pretty as disp
hint = 'https://raw.githubusercontent.com/soltaniehha/Business-Analytics-Toolbox/master/docs/hints/'  # path to hints on GitHub

# %%
# %%bigquery
# SELECT * FROM `examples.online_retail` LIMIT 5
# Out:
#   InvoiceNo StockCode Description  Quantity               InvoiceDate  \
# 0    536414     22139        None        56 2010-12-01 11:52:00+00:00
# 1    536545     21134        None         1 2010-12-01 14:32:00+00:00
# 2    536546     22145        None         1 2010-12-01 14:33:00+00:00
# 3    536547     37509        None         1 2010-12-01 14:33:00+00:00
# 4    536549    85226A        None         1 2010-12-01 14:34:00+00:00
#
#    UnitPrice  CustomerID         Country
# 0        0.0         NaN  United Kingdom
# 1        0.0         NaN  United Kingdom
# 2        0.0         NaN  United Kingdom
# 3        0.0         NaN  United Kingdom
# 4        0.0         NaN  United Kingdom

# %% [markdown]
# 1. Filter out the rows that have a `UnitPrice` of 0 or less
# 2. Create a new column called `SalesDollar` that contains `Quantity * UnitPrice`
# 3. Store the content of this table into a new table within the `examples` dataset and call it `retail`

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-create-table')

# %% [markdown]
# Using this newly created table find out how many rows/transactions are in the data:

# %%
# Out:
#       f0_
# 0  539392

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-count')

# %% [markdown]
# What is the date range of this dataset? Look up the min and max for the date:

# %%
# Out:
#                       first                      last
# 0 2010-12-01 08:26:00+00:00 2011-12-09 12:50:00+00:00

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-date-range')

# %% [markdown]
# Let's dive in deeper and see if all of these days have transactions in them. This can be done by a GROUP BY on the date, but have in mind that we are working with timestamps, so let's first convert the timestamps to dates and then check how many transactions are in each:

# %%
# Out:
#             day  NumberOfTransactions
# 0    2010-12-01                  3098
# 1    2010-12-02                  2107
# 2    2010-12-03                  2169
# 3    2010-12-05                  2724
# 4    2010-12-06                  3865
# ..          ...                   ...
# 300  2011-12-05                  5323
# 301  2011-12-06                  3362
# 302  2011-12-07                  2419
# 303  2011-12-08                  4934
# 304  2011-12-09                  1632
#
# [305 rows x 2 columns]

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-group-by-date')

# %% [markdown]
# This is a bit difficult to check. Let's create a time series to visually inspect this. Use the same query as above and save this query to be used for visualization. Call it `transactions` and by using `transactions.plot()` create a time series:

# %%
# Out:
# <AxesSubplot:>

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-group-by-date-query-name')

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-time-series')

# %% [markdown]
# Which countries are shoppers from and how many transactions relate to each country? Can you also calculate the revenue generated by visitors from each country and sort the list by this amount?
#
# Bonus: use `round()` function to display the revenue. Default behavior is to round to the closest integer which is good enough for this analysis.

# %%
# Out:
#                  Country  NumberOfTransactions    Revenue
# 0         United Kingdom                492979  8209930.0
# 1            Netherlands                  2367   284662.0
# 2                   EIRE                  8192   263277.0
# 3                Germany                  9493   221698.0
# 4                 France                  8556   197404.0
# 5              Australia                  1256   137077.0
# 6            Switzerland                  2001    56385.0
# 7                  Spain                  2532    54775.0
# 8                Belgium                  2069    40911.0
# 9                 Sweden                   462    36596.0
# 10                 Japan                   358    35341.0
# 11                Norway                  1085    35163.0
# 12              Portugal                  1519    29367.0
# 13               Finland                   695    22327.0
# 14       Channel Islands                   758    20086.0
# 15               Denmark                   389    18768.0
# 16                 Italy                   803    16891.0
# 17                Cyprus                   622    12946.0
# 18               Austria                   401    10154.0
# 19             Hong Kong                   288    10117.0
# 20             Singapore                   229     9120.0
# 21                Israel                   297     7908.0
# 22                Poland                   341     7213.0
# 23           Unspecified                   446     4750.0
# 24                Greece                   146     4711.0
# 25               Iceland                   182     4310.0
# 26                Canada                   151     3666.0
# 27                 Malta                   127     2505.0
# 28  United Arab Emirates                    68     1902.0
# 29                   USA                   291     1731.0
# 30               Lebanon                    45     1694.0
# 31             Lithuania                    35     1661.0
# 32    European Community                    61     1292.0
# 33                Brazil                    32     1144.0
# 34                   RSA                    57     1002.0
# 35        Czech Republic                    30      708.0
# 36               Bahrain                    19      548.0
# 37          Saudi Arabia                    10      131.0

# %%
# SOLUTION: Uncomment and execute the cell below to get help
#disp(hint + '06-01-revenue-per-country')
